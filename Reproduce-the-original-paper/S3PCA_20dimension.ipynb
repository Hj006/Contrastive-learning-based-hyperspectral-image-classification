# %% [markdown]
# 库的导入

# %%
import os
from pathlib import Path
import numpy as np
import skimage.exposure
import warnings
from io import StringIO
from scipy.sparse import coo_matrix
from sklearn.decomposition import PCA
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
import skimage.segmentation

from sklearn.decomposition import PCA

# %%
def _read_roi(path: Path, shape) -> coo_matrix:
    """
    读取 ENVI 软件导出 ROI 文件的 txt 文件，生成一个稀疏矩阵，表示每个像素点的类别标签。
    
    :param path: 文件路径，ENVI ROI 文件的路径
    :param shape: 图像的形状（height, width）
    :return: 一个稀疏矩阵，非零值表示像素点的类别标签
    """
    warnings.simplefilter("ignore", category=UserWarning)  # 忽略 loadtxt 的警告
    data = []
    rows = []
    cols = []
    current_label = 0
    buffer = ""

    with open(path, 'r') as f:
        for line in f:
            # 判断是否为新 ROI 的分割点
            if line.strip() == "" or line.startswith(";") or "ROI" in line:
                if buffer:  # 如果缓冲区有内容，解析为坐标数据
                    roi_data = np.loadtxt(StringIO(buffer), usecols=(2, 1), dtype=int)
                    if roi_data.size > 0:
                        r, c = roi_data.T
                        rows.extend(r)
                        cols.extend(c)
                        data.extend([current_label] * len(r))
                    buffer = ""  # 清空缓冲区
                # 如果遇到 ROI name 行，增加类别标签
                if "ROI name" in line:
                    current_label += 1
            else:
                buffer += line  # 将数据加入缓冲区

        # 处理最后一个 ROI
        if buffer:
            roi_data = np.loadtxt(StringIO(buffer), usecols=(2, 1), dtype=int)
            if roi_data.size > 0:
                r, c = roi_data.T
                rows.extend(r)
                cols.extend(c)
                data.extend([current_label] * len(r))

    warnings.resetwarnings()

    # 创建稀疏矩阵
    img = coo_matrix((data, (rows, cols)), shape=shape, dtype=int)
    return img


def load_houston2013(data_path: Path):
    """
    从本地路径加载 Houston2013 数据集。

    :param data_path: 数据集的根目录路径。
    :return: (casi, lidar, train_truth, test_truth, info)
    """
    FILES_PATH = data_path
    assert FILES_PATH.exists(), f"{FILES_PATH} does not exist. Please check the path."

    # 加载图像数据
    lidar = skimage.io.imread(FILES_PATH / '2013_IEEE_GRSS_DF_Contest_LiDAR.tif')[np.newaxis, :, :]  # (1, 349, 1905)
    casi = skimage.io.imread(FILES_PATH / '2013_IEEE_GRSS_DF_Contest_CASI.tif').transpose(2, 0, 1)   # (144, 349, 1905)

    # 加载训练集和测试集的真值
    train_truth = _read_roi(FILES_PATH / '2013_IEEE_GRSS_DF_Contest_Samples_TR.txt', (349, 1905))
    test_truth = _read_roi(FILES_PATH / '2013_IEEE_GRSS_DF_Contest_Samples_VA.txt', (349, 1905))

    # 数据集元信息
    info = {
        'n_band_casi': 144,
        'n_band_lidar': 1,
        'width': 1905,
        'height': 349,
        'label_dict': {
            1: 'Healthy grass',
            2: 'Stressed grass',
            3: 'Synthetic grass',
            4: 'Trees',
            5: 'Soil',
            6: 'Water',
            7: 'Residential',
            8: 'Commercial',
            9: 'Road',
            10: 'Highway',
            11: 'Railway',
            12: 'Parking Lot 1',
            13: 'Parking Lot 2',
            14: 'Tennis Court',
            15: 'Running Track',
        }
    }

    return casi, lidar, train_truth, test_truth, info

def merge_train_test(train_truth, test_truth, shape):
    """
    合并训练集和测试集稀疏矩阵为一个新的训练集矩阵。
    
    参数:
        train_truth: coo_matrix, 原始训练集稀疏矩阵
        test_truth: coo_matrix, 原始测试集稀疏矩阵
        shape: tuple, 数据的形状 (height, width)
        
    返回:
        merged_truth: coo_matrix, 合并后的训练集稀疏矩阵
    """
    # 合并行、列和数据
    merged_rows = np.concatenate([train_truth.row, test_truth.row])
    merged_cols = np.concatenate([train_truth.col, test_truth.col])
    merged_data = np.concatenate([train_truth.data, test_truth.data])
    
    # 创建新的稀疏矩阵
    merged_truth = coo_matrix((merged_data, (merged_rows, merged_cols)), shape=shape)
    return merged_truth

def apply_pca_train_only(hsi_data, train_truth, num_components=40):
    """
    使用训练区域的光谱数据训练 PCA 模型，并应用到整个数据集。
    
    参数:
        hsi_data: numpy.ndarray, 高光谱图像数据, 形状为 [C, H, W]
        train_truth: coo_array, 训练区域的稀疏矩阵，表示训练样本的位置
        num_components: int, 保留的主成分数量
        
    返回:
        pca_data: numpy.ndarray, PCA 降维后的数据，形状为 [num_components, H, W]
        explained_variance_ratio: PCA 的累计解释方差比
    """
    c, h, w = hsi_data.shape  # 高光谱数据的形状
    rows, cols = train_truth.row, train_truth.col  # 提取训练区域的行列索引
    
    # 提取训练区域的光谱数据 [num_samples, num_channels]
    train_spectra = hsi_data[:, rows, cols].T  # 转置为 [num_samples, num_channels]
    
    # 在训练区域数据上拟合 PCA
    pca = PCA(n_components=num_components)
    pca.fit(train_spectra)  # 仅在训练区域数据上训练 PCA
    
    # 转换整个数据集 [C, H, W] -> [H×W, C]
    reshaped_data = hsi_data.reshape(c, -1).T  # [H×W, C]
    reduced_data = pca.transform(reshaped_data)  # 降维 [H×W, num_components]
    
    # 恢复为原始图像的形状 [num_components, H, W]
    pca_data = reduced_data.T.reshape(num_components, h, w)  # [num_components, H, W]
    
    return pca_data, pca.explained_variance_ratio_

def superpixel_segmentation(hsi_data, num_superpixels=100):
    """
    使用 SLIC 超像素分割对 HSI 进行分割。

    参数:
        hsi_data: numpy.ndarray, 形状为 (C, H, W)
        num_superpixels: 生成的超像素数量
        
    返回:
        labels: 超像素标签矩阵，形状为 (H, W)
    """
    # 先用 PCA 提取第一主成分
    first_pc = PCA(n_components=1).fit_transform(hsi_data.reshape(hsi_data.shape[0], -1).T)
    first_pc = first_pc.reshape(hsi_data.shape[1:])  # 变成 (H, W)

    # 修正错误：复制 3 通道，使其符合 SLIC 需 
    first_pc_rgb = np.stack([first_pc] * 3, axis=-1)  # 变成 (H, W, 3)

    # 正确调用 skimage.segmentation.sli 
    labels = skimage.segmentation.slic(first_pc_rgb, n_segments=num_superpixels, compactness=10, start_label=0, channel_axis=-1)
    
    return labels



def compute_superpixel_pca(hsi_data, superpixel_labels, merged_train_truth, num_components=20):
    """
    仅在训练区域计算每个超像素的局部 PCA，并返回降维后的特征。

    参数:
        hsi_data: numpy.ndarray, 形状为 (B, H, W)
        superpixel_labels: numpy.ndarray, 形状为 (H, W)
        merged_train_truth: coo_matrix, 训练区域掩码
        num_components: int, PCA 维度
        
    返回:
        superpixel_pca_map: numpy.ndarray, 形状为 (num_components, H, W)
    """
    h, w = superpixel_labels.shape
    c = hsi_data.shape[0]
    superpixel_pca_map = np.zeros((num_components, h, w))
    superpixel_pca_dict = {}

    rows, cols = merged_train_truth.row, merged_train_truth.col  # 只取训练区域

    unique_labels = np.unique(superpixel_labels)
    for label in unique_labels:
        mask = (superpixel_labels == label)

        # 只选择该超像素块内，同时在训练区域的像素
        train_mask = np.logical_and(mask, merged_train_truth.toarray() > 0)
        if np.sum(train_mask) == 0:  # 该超像素区域没有训练数据，跳过
            continue

        pixels = hsi_data[:, train_mask].T  # 取出该超像素块的训练样本 (num_samples, num_channels)

        if pixels.shape[0] > num_components:  # 训练样本足够才做 PCA
            pca = PCA(n_components=num_components)
            reduced_pixels = pca.fit_transform(pixels)
            superpixel_pca_dict[label] = reduced_pixels.T  # 存储该超像素的 PCA 变换结果
        
        # 赋值到整个超像素区域
        for i in range(num_components):
            superpixel_pca_map[i, mask] = np.mean(reduced_pixels[:, i])

    return superpixel_pca_map, superpixel_pca_dict




def split_cube(hsi_cube):
    """
    将高光谱立方块沿通道维度均匀切分。
    参数:
        hsi_cube: torch.Tensor, 形状为 [H, W, C]
    返回:
        hsi_cube_a, hsi_cube_b: 两个子立方块
    """
    _, _, c = hsi_cube.shape
    c1 = c // 2  # 每个子块保留一半的通道
    return hsi_cube[:, :, :c1], hsi_cube[:, :, c1:]

def extract_cube(data, x, y, size):
    """
    从高光谱数据中提取局部立方块，并在边界不足时进行填充。
    
    参数:
        data: numpy.ndarray, 形状为 [C, H, W]
        x, y: int, 立方块的中心像素坐标
        size: tuple, 立方块的大小 (s, s)，要求 s 必须是奇数
    
    返回:
        cube: numpy.ndarray, 形状为 [C, s, s]
    """
    assert size[0] % 2 == 1, "立方块大小必须是奇数，以确保中心点对齐。"
    
    c, h, w = data.shape
    half_size = size[0] // 2  # 计算半径

    # 计算提取区域的坐标范围
    x_min, x_max = max(0, x - half_size), min(h, x + half_size + 1)
    y_min, y_max = max(0, y - half_size), min(w, y + half_size + 1)

    # 提取局部数据
    cube = data[:, x_min:x_max, y_min:y_max]

    # 计算需要填充的大小
    pad_x_min, pad_x_max = max(0, half_size - x), max(0, x + half_size + 1 - h)
    pad_y_min, pad_y_max = max(0, half_size - y), max(0, y + half_size + 1 - w)

    # 使用边缘填充，确保输出形状为 (C, size, size)
    pad_width = [
        (0, 0),  # 不填充通道维度
        (pad_x_min, pad_x_max),  # 高度填充
        (pad_y_min, pad_y_max),  # 宽度填充
    ]
    cube = np.pad(cube, pad_width, mode="edge")  # 填充值是边界像素，而不是反射

    return cube


class FeatureExtractor(nn.Module):
    def __init__(self, input_channels=40):
        """
        特征提取网络。
        参数:
            input_channels: 输入的通道数，例如 20。
        """
        super(FeatureExtractor, self).__init__()
        self.conv1 = nn.Conv2d(input_channels, 32, kernel_size=3, padding=1)  # 第一层卷积
        self.bn1 = nn.BatchNorm2d(32)
        
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)  # 第二层卷积
        self.bn2 = nn.BatchNorm2d(64)
        
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)  # 第三层卷积
        self.bn3 = nn.BatchNorm2d(128)
        
        self.pool = nn.MaxPool2d(2, 2)  # 最大池化层
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.pool(self.relu(self.bn1(self.conv1(x))))  # 卷积 + 批归一化 + 激活 + 池化
        x = self.pool(self.relu(self.bn2(self.conv2(x))))
        x = self.pool(self.relu(self.bn3(self.conv3(x))))
        return x.view(x.size(0), -1)  # 展平特征
    

class ProjectionHead(nn.Module):
    def __init__(self, input_dim=128, output_dim=8):
        """
        特征投影模块。
        参数:
            input_dim: 输入特征的维度，例如 128。
            output_dim: 投影后的维度，例如 8。
        """
        super(ProjectionHead, self).__init__()
        self.fc = nn.Linear(input_dim, output_dim)

    def forward(self, x):
        return F.normalize(self.fc(x), dim=1)  # 投影后的特征归一化


def contrastive_loss(features_a, features_b, temperature=1.0):
    """
    计算对比损失。
    参数:
        features_a, features_b: 投影后的特征，形状为 [batch_size, projection_dim]
        temperature: 温度系数
    返回:
        loss: 对比损失值
    """
    batch_size = features_a.size(0)
    features = torch.cat([features_a, features_b], dim=0)  # 拼接特征
    sim_matrix = F.cosine_similarity(features.unsqueeze(1), features.unsqueeze(0), dim=2)  # 计算相似度
    sim_matrix = sim_matrix / temperature

    # 构造标签
    labels = torch.arange(batch_size, device=features_a.device)
    labels = torch.cat([labels, labels], dim=0)

    # 使用交叉熵损失
    loss = F.cross_entropy(sim_matrix, labels)
    return loss

def extract_precise_superpixel_pca(superpixel_pca_dict, superpixel_labels, x, y):
    """
    获取像素 (x, y) 所属超像素的 SuperPCA 特征。
    
    参数:
        superpixel_pca_dict: 字典，存储每个超像素的 PCA 结果
        superpixel_labels: 超像素标签矩阵
        x, y: 目标像素坐标
        
    返回:
        superpixel_features: numpy.ndarray, 形状为 (20,)
    """
    superpixel_label = superpixel_labels[x, y]  # 获取该像素的超像素标签
    
    # 获取该超像素块的所有 PCA 结果
    superpixel_features = superpixel_pca_dict[superpixel_label]  # 形状为 (20, N)，N 是该超像素块内像素数

    # 取所有像素的平均值，确保返回 20 维的特征向量
    superpixel_features = np.mean(superpixel_features, axis=1)  # 形状变为 (20,)

    return superpixel_features



# 自定义数据集类
class S3PCADataset(Dataset):
    def __init__(self, pca_data, superpixel_pca_map, superpixel_pca_dict, superpixel_labels, global_pca, patch_size=11, num_samples=1000):
        """
        S³-PCA 数据集
        :param pca_data: 传统 PCA 处理后的数据 (num_components, H, W)
        :param superpixel_pca_map: 超像素 PCA 结果 (num_components, H, W)
        :param superpixel_pca_dict: 存储每个超像素块 PCA 变换结果的字典
        :param superpixel_labels: 超像素标签 (H, W)
        :param global_pca: 全局 PCA 结果 (num_components, H, W)
        :param patch_size: 立方块大小
        :param num_samples: 训练样本数量
        """
        self.pca_data = pca_data  # 恢复 pca_dat 
        self.superpixel_pca_map = superpixel_pca_map
        self.superpixel_pca_dict = superpixel_pca_dict
        self.superpixel_labels = superpixel_labels
        self.global_pca = global_pca
        self.patch_size = patch_size
        self.num_samples = num_samples
        self.h, self.w = pca_data.shape[1], pca_data.shape[2]

        self.pca_transform = PCA(n_components=20)  # 40 降到 20 维

    def apply_pca(self, cube):
        """
        对 40 维通道的数据进行 PCA 降维到 20 维
        """
        c, h, w = cube.shape  # (40, 11, 11)
        cube_flat = cube.view(c, -1).cpu().numpy()  # 变成 (40, 121)

        # **在通道维度上进行 PCA**
        cube_pca = self.pca_transform.fit_transform(cube_flat.T).T  # (20, 121)

        # 变回 (20, 11, 11)
        cube_pca = torch.tensor(cube_pca, dtype=torch.float32).view(20, h, w).cuda()

        return cube_pca
    
    def __len__(self):
        return self.num_samples  # 确保返回数据集大 
    
    def __getitem__(self, idx):
        x = torch.randint(self.patch_size // 2, self.h - self.patch_size // 2, (1,)).item()
        y = torch.randint(self.patch_size // 2, self.w - self.patch_size // 2, (1,)).item()

        # 提取 PCA 立方块
        pca_patch = extract_cube(self.pca_data, x, y, (self.patch_size, self.patch_size))
        pca_patch = torch.tensor(pca_patch, dtype=torch.float32)  # (40, 11, 11)

        # 拆分 PCA 为两个 20 通道块
        pca_patch_a, pca_patch_b = torch.split(pca_patch, [20, 20], dim=0)  # 确保各自 20 通道

        # 提取 SuperPCA
        superpixel_patch = extract_precise_superpixel_pca(self.superpixel_pca_dict, self.superpixel_labels, x, y)
        superpixel_patch = torch.tensor(superpixel_patch[:, None, None], dtype=torch.float32)  # (20, 1, 1)
        superpixel_patch = superpixel_patch.expand(-1, self.patch_size, self.patch_size)  # (20, 11, 11)

        # 提取 GlobalPCA
        global_patch = extract_cube(self.global_pca, x, y, (self.patch_size, self.patch_size))
        global_patch = torch.tensor(global_patch, dtype=torch.float32)  # (20, 11, 11)

        # 拼接修正
        cube_a = torch.cat([pca_patch_a, superpixel_patch], dim=0)  # (20+20, 11, 11) → (40, 11, 11)
        cube_b = torch.cat([pca_patch_b, global_patch], dim=0)  # (20+20, 11, 11) → (40, 11, 11)
        
        # 🚀 在通道维度上应用 PCA（40 → 20）
        cube_a = self.apply_pca(cube_a)
        cube_b = self.apply_pca(cube_b)



        return cube_a, cube_b



    
def compute_global_pca(hsi_data, merged_train_truth, num_components=20):
    """
    仅在训练区域计算全局 PCA，并应用到整个 HSI。
    
    参数:
        hsi_data: numpy.ndarray, 形状为 (B, H, W)
        merged_train_truth: coo_matrix, 标注的训练区域
        num_components: int, PCA 降维维度
        
    返回:
        global_pca_map: numpy.ndarray, 形状为 (num_components, H, W)
    """
    c, h, w = hsi_data.shape
    rows, cols = merged_train_truth.row, merged_train_truth.col  # 获取训练样本的位置

    # 取出训练区域的数据
    train_spectra = hsi_data[:, rows, cols].T  # (num_samples, num_channels)

    # 在训练数据上拟合 PCA
    pca = PCA(n_components=num_components)
    pca.fit(train_spectra)  # 只在训练数据上拟合

    # 对整个 HSI 应用 PCA 变换
    reshaped_data = hsi_data.reshape(c, -1).T  # (H*W, C)
    reduced_data = pca.transform(reshaped_data)  # (H*W, num_components)

    global_pca_map = reduced_data.T.reshape(num_components, h, w)  # 还原形状
    return global_pca_map

# %%
# 训练集路径
data_path = Path(r"E:\code\-\对比学习\fx\Houston2013\2013_DFTC")

# 加载数据集
casi, lidar, train_truth, test_truth, info = load_houston2013(data_path)

# 合并训练集和测试集
merged_train_truth = merge_train_test(train_truth, test_truth, (349, 1905))

# 应用 PCA 降维
pca_data, explained_variance_ratio = apply_pca_train_only(casi, merged_train_truth, num_components=40)

# 执行超像素分割
superpixel_labels = superpixel_segmentation(casi)

# 计算超像素 PCA（仅使用训练区域）
superpixel_pca_map, superpixel_pca_dict = compute_superpixel_pca(casi, superpixel_labels, merged_train_truth, num_components=20)

# 计算全局 PCA（仅使用训练区域）
global_pca_map = compute_global_pca(casi, merged_train_truth, num_components=20)




# 初始化数据集（正确）
dataset = S3PCADataset(pca_data, superpixel_pca_map, superpixel_pca_dict, superpixel_labels, global_pca_map)


# 创建数据加载器
dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

# 初始化网络
feature_extractor = FeatureExtractor(input_channels=20).cuda()  
projection_head = ProjectionHead(input_dim=128, output_dim=8).cuda()
optimizer = optim.Adam(list(feature_extractor.parameters()) + list(projection_head.parameters()), lr=1e-4)

# 创建保存模型的文件夹
os.makedirs('./pth', exist_ok=True)

# 训练循环
num_epochs = 100
temperature = 1.0
loss_values = []

for epoch in range(num_epochs):
    feature_extractor.train()
    projection_head.train()
    
    epoch_loss = 0
    for batch in dataloader:
        cube_a, cube_b = batch
        cube_a, cube_b = cube_a.cuda(), cube_b.cuda()
        
        features_a = feature_extractor(cube_a)
        features_b = feature_extractor(cube_b)
        
        proj_a = projection_head(features_a)
        proj_b = projection_head(features_b)
        
        loss = contrastive_loss(proj_a, proj_b, temperature)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
    
    avg_loss = epoch_loss / len(dataloader)
    loss_values.append(avg_loss)
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}")

# 仅保存最后一个模型
model_path = 'pth/S3PCA_merge_20d_v1.pth'
torch.save(
    {
        'epoch': num_epochs,
        'feature_extractor_state_dict': feature_extractor.state_dict(),
        'projection_head_state_dict': projection_head.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': loss_values[-1],
    },
    model_path
)
print(f"Final model saved to {model_path}")

# 绘制损失曲线
plt.figure(figsize=(8, 6))
plt.plot(range(1, num_epochs + 1), loss_values, marker='o', label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Curve')
plt.legend()
plt.grid()
plt.savefig('pth/loss_curve_S3PCA_merge_20d_v1.png')
plt.show()
# Out:
# <tifffile.TiffPage 0 @2949772> parsing GDAL_NODATA tag raised ValueError('-3.4028234663852886e+38 is not castable to float32')
# Epoch [1/100], Loss: 4.1911
# Epoch [2/100], Loss: 3.9857
# Epoch [3/100], Loss: 3.9457
# Epoch [4/100], Loss: 3.9306
# Epoch [5/100], Loss: 3.9217
# Epoch [6/100], Loss: 3.9197
# Epoch [7/100], Loss: 3.9142
# Epoch [8/100], Loss: 3.9128
# Epoch [9/100], Loss: 3.9107
# Epoch [10/100], Loss: 3.9098
# Epoch [11/100], Loss: 3.9056
# Epoch [12/100], Loss: 3.9067
# Epoch [13/100], Loss: 3.9062
# Epoch [14/100], Loss: 3.9059
# Epoch [15/100], Loss: 3.9052
# Epoch [16/100], Loss: 3.9043
# Epoch [17/100], Loss: 3.9040
# Epoch [18/100], Loss: 3.9025
# Epoch [19/100], Loss: 3.9043
# Epoch [20/100], Loss: 3.9059
# Epoch [21/100], Loss: 3.9018
# Epoch [22/100], Loss: 3.9029
# Epoch [23/100], Loss: 3.9028
# Epoch [24/100], Loss: 3.9036
# Epoch [25/100], Loss: 3.9014
# Epoch [26/100], Loss: 3.9027
# Epoch [27/100], Loss: 3.9038
# Epoch [28/100], Loss: 3.9007
# Epoch [29/100], Loss: 3.9001
# Epoch [30/100], Loss: 3.9009
# Epoch [31/100], Loss: 3.9033
# Epoch [32/100], Loss: 3.9005
# Epoch [33/100], Loss: 3.9005
# Epoch [34/100], Loss: 3.8996
# Epoch [35/100], Loss: 3.9003
# Epoch [36/100], Loss: 3.9014
# Epoch [37/100], Loss: 3.8990
# Epoch [38/100], Loss: 3.9009
# Epoch [39/100], Loss: 3.8992
# Epoch [40/100], Loss: 3.9005
# Epoch [41/100], Loss: 3.9005
# Epoch [42/100], Loss: 3.9023
# Epoch [43/100], Loss: 3.9016
# Epoch [44/100], Loss: 3.9002
# Epoch [45/100], Loss: 3.9013
# Epoch [46/100], Loss: 3.9002
# Epoch [47/100], Loss: 3.9009
# Epoch [48/100], Loss: 3.9007
# Epoch [49/100], Loss: 3.9004
# Epoch [50/100], Loss: 3.9006
# Epoch [51/100], Loss: 3.9000
# Epoch [52/100], Loss: 3.9002
# Epoch [53/100], Loss: 3.9010
# Epoch [54/100], Loss: 3.9000
# Epoch [55/100], Loss: 3.8985
# Epoch [56/100], Loss: 3.8981
# Epoch [57/100], Loss: 3.8996
# Epoch [58/100], Loss: 3.9006
# Epoch [59/100], Loss: 3.8990
# Epoch [60/100], Loss: 3.8987
# Epoch [61/100], Loss: 3.9009
# Epoch [62/100], Loss: 3.9007
# Epoch [63/100], Loss: 3.8998
# Epoch [64/100], Loss: 3.8985
# Epoch [65/100], Loss: 3.8992
# Epoch [66/100], Loss: 3.9013
# Epoch [67/100], Loss: 3.8981
# Epoch [68/100], Loss: 3.8992
# Epoch [69/100], Loss: 3.8989
# Epoch [70/100], Loss: 3.8985
# Epoch [71/100], Loss: 3.8981
# Epoch [72/100], Loss: 3.9001
# Epoch [73/100], Loss: 3.8992
# Epoch [74/100], Loss: 3.8979
# Epoch [75/100], Loss: 3.8990
# Epoch [76/100], Loss: 3.8987
# Epoch [77/100], Loss: 3.8985
# Epoch [78/100], Loss: 3.8985
# Epoch [79/100], Loss: 3.8999
# Epoch [80/100], Loss: 3.8984
# Epoch [81/100], Loss: 3.8986
# Epoch [82/100], Loss: 3.8972
# Epoch [83/100], Loss: 3.8978
# Epoch [84/100], Loss: 3.8977
# Epoch [85/100], Loss: 3.8995
# Epoch [86/100], Loss: 3.8986
# Epoch [87/100], Loss: 3.8983
# Epoch [88/100], Loss: 3.8983
# Epoch [89/100], Loss: 3.8980
# Epoch [90/100], Loss: 3.9001
# Epoch [91/100], Loss: 3.8977
# Epoch [92/100], Loss: 3.8987
# Epoch [93/100], Loss: 3.8979
# Epoch [94/100], Loss: 3.8982
# Epoch [95/100], Loss: 3.8975
# Epoch [96/100], Loss: 3.8982
# Epoch [97/100], Loss: 3.8987
# Epoch [98/100], Loss: 3.8982
# Epoch [99/100], Loss: 3.8984
# Epoch [100/100], Loss: 3.8982
# Final model saved to pth/S3PCA_merge_20d_v1.pth

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
import numpy as np

# 选择三个主成分作为 R、G、B
r, g, b = 0, 1, 2  # 使用前3个主成分

# 获取 PCA 降维后的图像数据 [num_components, H, W]
rgb_img = np.stack([
    pca_data[r], 
    pca_data[g], 
    pca_data[b]
], axis=-1)  # -> [H, W, 3]

# 归一化到 0~1 区间
norm = Normalize(vmin=rgb_img.min(), vmax=rgb_img.max())
rgb_img_norm = norm(rgb_img)

# 显示并保存
plt.figure(figsize=(6, 4))
plt.imshow(rgb_img_norm)
plt.axis('off')
plt.tight_layout()
plt.savefig("pca_rgb_visual.png", dpi=300, bbox_inches='tight', pad_inches=0)
plt.show()
sample_cube = extract_cube(pca_data, x=100, y=200, size=(11, 11))  # 返回的是 [40, 11, 11]

# 显示第一个主成分的图像
plt.imshow(sample_cube[0], cmap='gray')
plt.title("PCA Channel 1 - 11x11 Patch")
plt.show()

# %%
from collections import Counter
from torch.utils.data import Dataset, DataLoader
import random
from collections import defaultdict
import numpy as np
import torch
from sklearn.decomposition import PCA
import torch
import torch.nn as nn
import torch.optim as optim

# %%
def extract_labels(truth, label_dict):
    """
    从稀疏矩阵中提取标注数据，格式为 [(row, col, label), ...]。
    并将标签值映射到 [0, len(label_dict)-1] 的范围。
    """
    rows, cols, labels = truth.row, truth.col, truth.data
    # 创建从标签值到索引的映射
    label_to_index = {label_value: idx for idx, label_value in enumerate(label_dict.keys())}
    mapped_labels = [label_to_index[label] for label in labels if label in label_to_index]
    return [(row, col, label) for row, col, label in zip(rows, cols, mapped_labels)]


# 提取立方块函数
def extract_cube(data, x, y, size):
    """
    从高光谱图像中提取一个立方块，并在边缘不足时进行填充。
    参数:
        data: 高光谱数据, 形状为 [C, H, W]
        x, y: 中心像素的坐标
        size: 立方块的大小 (s, s)
    返回:
        cube: 提取的立方块, 形状为 [C, s, s]
    """
    c, h, w = data.shape
    half_size = size[0] // 2
    x_min = max(0, x - half_size)
    x_max = min(h, x + half_size + 1)
    y_min = max(0, y - half_size)
    y_max = min(w, y + half_size + 1)
    
    cube = data[:, x_min:x_max, y_min:y_max]

    # 对称填充，确保形状为 (C, s, s)
    pad_width = [
        (0, 0),  # 不填充通道维度
        (max(0, half_size - x), max(0, x + half_size + 1 - h)),  # 高度填充
        (max(0, half_size - y), max(0, y + half_size + 1 - w)),  # 宽度填充
    ]
    cube = np.pad(cube, pad_width, mode="reflect")
    return cube


# PCA 降维函数
def apply_pca_train_only(hsi_data, train_truth, num_components=20):
    """
    使用训练区域的光谱数据训练 PCA 模型，并应用到整个数据集。
    参数:
        hsi_data: 高光谱数据, 形状为 [C, H, W]
        train_truth: coo_array, 训练区域的稀疏矩阵，表示训练样本的位置
        num_components: 保留的主成分数量
    返回:
        pca_data: 降维后的数据, 形状为 [num_components, H, W]
        explained_variance_ratio: PCA 的累计解释方差比
    """
    c, h, w = hsi_data.shape
    rows, cols = train_truth.row, train_truth.col  # 提取训练区域的行列索引

    # 提取训练区域的光谱数据 [num_samples, num_channels]
    train_spectra = hsi_data[:, rows, cols].T  # 转置为 [num_samples, num_channels]

    # 在训练区域数据上拟合 PCA
    pca = PCA(n_components=num_components)
    pca.fit(train_spectra)  # 仅在训练区域数据上训练 PCA

    # 转换整个数据集
    reshaped_data = hsi_data.reshape(c, -1).T  # [H×W, C]
    reduced_data = pca.transform(reshaped_data)  # 降维 [H×W, num_components]

    # 恢复为原始图像的形状
    pca_data = reduced_data.T.reshape(num_components, h, w)  # [num_components, H, W]
    
    return pca_data, pca.explained_variance_ratio_


# 分类数据集定义
class ClassificationDataset(Dataset):
    def __init__(self, data, labels, patch_size=11):
        """
        构造分类数据集。
        参数:
            data: PCA 降维后的数据 [C, H, W]
            labels: [(row, col, label), ...]，标注的样本
            patch_size: 立方块大小 (patch_size, patch_size)
        """
        self.data = data
        self.labels = labels
        self.patch_size = patch_size

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        x, y, label = self.labels[idx]
        cube = extract_cube(self.data, x, y, (self.patch_size, self.patch_size))  # 提取立方块
        cube_tensor = torch.tensor(cube).float()  # 转换为浮点张量
        return cube_tensor, label


# 候选集生成函数
def create_candidate_dataset(train_labels, num_classes, samples_per_class):
    """
    从训练样本中按每类抽取指定数量的样本，构造候选集。
    参数:
        train_labels: 原始训练样本 [(row, col, label), ...]
        num_classes: 类别数量
        samples_per_class: 每个类别抽取的样本数量
    返回:
        candidate_labels: 候选样本 [(row, col, label), ...]
    """
    class_samples = defaultdict(list)
    for sample in train_labels:
        class_samples[sample[2]].append(sample)

    candidate_labels = []
    for cls in range(num_classes):
        if cls in class_samples:
            samples = class_samples[cls]
            if len(samples) < samples_per_class:
                print(f"Warning: Class {cls} has only {len(samples)} samples, less than {samples_per_class}.")
            candidate_labels.extend(random.sample(samples, min(samples_per_class, len(samples))))
        else:
            print(f"Warning: Class {cls} has no samples in training set.")
    return candidate_labels


# 定义特征提取器
class FeatureExtractor(nn.Module):
    def __init__(self, input_channels):
        super().__init__()
        self.conv1 = nn.Conv2d(input_channels, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(128)
        self.pool = nn.MaxPool2d(2, 2)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.pool(self.relu(self.bn1(self.conv1(x))))
        x = self.pool(self.relu(self.bn2(self.conv2(x))))
        x = self.pool(self.relu(self.bn3(self.conv3(x))))
        return x.view(x.size(0), -1)  # Flatten to [batch_size, features]

# %%
num_classes = len(set(train_truth.data))
test_labels = extract_labels(test_truth, info['label_dict'])

test_label_counts = Counter([label for _, _, label in test_labels])


# 应用 PCA 并重新构造数据集
ptest_data, explained_variance_ratio = apply_pca_train_only(casi, test_truth, num_components=20)

test_dataset = ClassificationDataset(ptest_data, test_labels, patch_size=11)
candidate_labels = create_candidate_dataset(test_labels, num_classes=len(info['label_dict']), samples_per_class=10)
candidate_dataset = ClassificationDataset(ptest_data, candidate_labels, patch_size=11)

# 定义数据加载器
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
candidate_loader = DataLoader(candidate_dataset, batch_size=64, shuffle=True)

# 打印样本数量信息
print(f"PCA 降维后的数据形状: {ptest_data.shape}")
print(f"Number of candidate samples: {len(candidate_loader.dataset)}")
print(f"Number of testing samples: {len(test_loader.dataset)}")




# 加载对比学习的模型权重
#checkpoint_path = "./pth/model_epoch_160.pth"  # 修改为对比学习模型的路径
checkpoint_path = "pth/S3PCA_merge_20d_v1.pth"
checkpoint = torch.load(checkpoint_path)

# 确保权重文件中包含特征提取器的权重
if 'feature_extractor_state_dict' not in checkpoint:
    raise KeyError("Checkpoint does not contain 'feature_extractor_state_dict'. Please check the file.")
# Out:
# PCA 降维后的数据形状: (20, 349, 1905)
# Number of candidate samples: 150
# Number of testing samples: 12197

# %%
# 初始化特征提取器（与对比学习阶段一致的输入通道数为 20）
feature_extractor = FeatureExtractor(input_channels=20).cuda()

# 加载所有预训练权重
feature_extractor.load_state_dict(checkpoint['feature_extractor_state_dict'])
print("Loaded pre-trained weights for the entire feature extractor.")

# 检查冻结状态（设置所有层参数为可微调）
for param in feature_extractor.parameters():
    param.requires_grad = True  # 解冻所有参数

# 定义分类头
# 定义分类头
class ClassificationHead(nn.Module):
    def __init__(self, input_dim, num_classes):
        super(ClassificationHead, self).__init__()
        self.fc = nn.Linear(input_dim, num_classes)

    def forward(self, x):
        return self.fc(x)

# 修改输入维度为 128（特征提取器的输出维度）
classification_head = ClassificationHead(input_dim=128, num_classes=15).cuda()


# 定义优化器
optimizer = optim.Adam([
    {"params": feature_extractor.parameters(), "lr": 1e-4},  # 微调特征提取器
    {"params": classification_head.parameters(), "lr": 1e-3},  # 分类头
])

# 定义损失函数
criterion = nn.CrossEntropyLoss()

loss_values = []

def train_classification_model(feature_extractor, classification_head, train_loader, optimizer, criterion, num_epochs=50):
    feature_extractor.train()
    classification_head.train()

    for epoch in range(num_epochs):
        epoch_loss = 0
        for cubes, labels in train_loader:
            cubes, labels = cubes.cuda(), labels.cuda()
            features = feature_extractor(cubes)
            outputs = classification_head(features)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

        avg_loss = epoch_loss / len(train_loader)
        loss_values.append(avg_loss)  # 记录损失值

        #print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}")

# 运行训练函数
train_classification_model(feature_extractor, classification_head, candidate_loader, optimizer, criterion, num_epochs=200)
# Out:
# Loaded pre-trained weights for the entire feature extractor.

# %%
import matplotlib.pyplot as plt

# 取最后 30 轮的 loss
last_30_losses = loss_values[-30:]

# 绘制损失曲线
plt.figure(figsize=(8, 6))
plt.plot(range(len(last_30_losses)), last_30_losses, marker='o', linestyle='-', label='Loss')
plt.xlabel('Epoch (last 30)')
plt.ylabel('Loss')
plt.title('Loss Curve for Last 30 Epochs')
plt.legend()
plt.grid()
plt.show()

# %%
from sklearn.metrics import cohen_kappa_score
import numpy as np

def evaluate_classification_model_with_details(feature_extractor, classification_head, test_loader, num_classes):
    """
    评估分类模型的性能，并输出详细预测结果和分布。

    参数:
        feature_extractor: 冻结的特征提取器
        classification_head: 分类头
        test_loader: 测试数据加载器
        num_classes: 总类别数
    """
    feature_extractor.eval()
    classification_head.eval()

    correct = 0
    total = 0

    # 初始化预测计数，并移动到 GPU
    prediction_counts = torch.zeros(num_classes, dtype=torch.int64).cuda()
    class_correct = torch.zeros(num_classes, dtype=torch.int64).cuda()
    class_total = torch.zeros(num_classes, dtype=torch.int64).cuda()

    all_predictions = []
    all_labels = []

    with torch.no_grad():
        for cubes, labels in test_loader:
            cubes, labels = cubes.cuda(), labels.cuda()

            # 提取特征并进行预测
            features = feature_extractor(cubes)
            outputs = classification_head(features)
            _, predicted = torch.max(outputs, 1)

            # 更新统计信息
            correct += (predicted == labels).sum().item()
            total += labels.size(0)
            prediction_counts += torch.bincount(predicted, minlength=num_classes).cuda()

            for i in range(labels.size(0)):
                label = labels[i].item()
                pred = predicted[i].item()
                class_total[label] += 1
                if label == pred:
                    class_correct[label] += 1

            # 保存详细信息
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Overall Accuracy
    overall_accuracy = correct / total

    # Average Accuracy (每个类别的平均准确率)
    average_accuracy = (class_correct.float() / class_total.float()).mean().item()

    # Kappa 系数
    kappa = cohen_kappa_score(all_labels, all_predictions)

    print(f"Overall Accuracy: {overall_accuracy:.4f}")
    print(f"Average Accuracy: {average_accuracy:.4f}")
    print(f"Kappa Coefficient: {kappa:.4f}")

    print("\nPrediction Distribution:")
    for cls, count in enumerate(prediction_counts.cpu()):  # 将分布从 GPU 移回 CPU
        print(f"Class {cls}: {count} predictions")

    return overall_accuracy, average_accuracy, kappa, all_predictions, all_labels

# 再次评估模型
overall_accuracy, average_accuracy, kappa, all_predictions, all_labels = evaluate_classification_model_with_details(
    feature_extractor, classification_head, test_loader, num_classes=num_classes
)

# 打印所有测试样本的预测类别和真实类别
print("\nDetailed Predictions:")
for idx, (pred, label) in enumerate(zip(all_predictions, all_labels)):
    print(f"Sample {idx}: Predicted={pred}, True={label}")
# Out:
# Overall Accuracy: 0.8305
# Average Accuracy: 0.8596
# Kappa Coefficient: 0.8162
#
# Prediction Distribution:
# Class 0: 884 predictions
# Class 1: 1382 predictions
# Class 2: 504 predictions
# Class 3: 1014 predictions
# Class 4: 1074 predictions
# Class 5: 272 predictions
# Class 6: 865 predictions
# Class 7: 915 predictions
# Class 8: 735 predictions
# Class 9: 1277 predictions
# Class 10: 873 predictions
# Class 11: 1310 predictions
# Class 12: 328 predictions
# Class 13: 263 predictions
# Class 14: 501 predictions
#
# Detailed Predictions:
# Sample 0: Predicted=0, True=0
# Sample 1: Predicted=0, True=0
# Sample 2: Predicted=0, True=0
# Sample 3: Predicted=0, True=0
# Sample 4: Predicted=0, True=0
# Sample 5: Predicted=0, True=0
# Sample 6: Predicted=0, True=0
# Sample 7: Predicted=0, True=0
# Sample 8: Predicted=0, True=0
# Sample 9: Predicted=0, True=0
# Sample 10: Predicted=0, True=0
# Sample 11: Predicted=0, True=0
# Sample 12: Predicted=0, True=0
# Sample 13: Predicted=0, True=0
# Sample 14: Predicted=0, True=0
# Sample 15: Predicted=0, True=0
# Sample 16: Predicted=0, True=0
# Sample 17: Predicted=0, True=0
# Sample 18: Predicted=0, True=0
# Sample 19: Predicted=0, True=0
# Sample 20: Predicted=0, True=0
# Sample 21: Predicted=0, True=0
# Sample 22: Predicted=0, True=0
# Sample 23: Predicted=0, True=0
# Sample 24: Predicted=0, True=0
# Sample 25: Predicted=0, True=0
# Sample 26: Predicted=0, True=0
# Sample 27: Predicted=0, True=0
# Sample 28: Predicted=0, True=0
# Sample 29: Predicted=0, True=0
# Sample 30: Predicted=0, True=0
# Sample 31: Predicted=0, True=0
# Sample 32: Predicted=0, True=0
# Sample 33: Predicted=0, True=0
# Sample 34: Predicted=0, True=0
# Sample 35: Predicted=0, True=0
# Sample 36: Predicted=0, True=0
# Sample 37: Predicted=0, True=0
# Sample 38: Predicted=0, True=0
# Sample 39: Predicted=0, True=0
# Sample 40: Predicted=0, True=0
# Sample 41: Predicted=0, True=0
# Sample 42: Predicted=0, True=0
# Sample 43: Predicted=0, True=0
# Sample 44: Predicted=0, True=0
# Sample 45: Predicted=0, True=0
# Sample 46: Predicted=0, True=0
# Sample 47: Predicted=0, True=0
# Sample 48: Predicted=0, True=0
# Sample 49: Predicted=0, True=0
# Sample 50: Predicted=0, True=0
# Sample 51: Predicted=0, True=0
# Sample 52: Predicted=0, True=0
# Sample 53: Predicted=0, True=0
# Sample 54: Predicted=0, True=0
# Sample 55: Predicted=0, True=0
# Sample 56: Predicted=0, True=0
# Sample 57: Predicted=0, True=0
# Sample 58: Predicted=0, True=0
# Sample 59: Predicted=0, True=0
# Sample 60: Predicted=0, True=0
# Sample 61: Predicted=0, True=0
# Sample 62: Predicted=0, True=0
# Sample 63: Predicted=0, True=0
# Sample 64: Predicted=0, True=0
# Sample 65: Predicted=0, True=0
# Sample 671: Predicted=0, True=0
# Sample 672: Predicted=0, True=0
# Sample 673: Predicted=0, True=0
# Sample 674: Predicted=0, True=0
# Sample 675: Predicted=0, True=0
# Sample 676: Predicted=0, True=0
# Sample 677: Predicted=0, True=0
# Sample 678: Predicted=0, True=0
# Sample 679: Predicted=0, True=0
# Sample 680: Predicted=1, True=0
# Sample 681: Predicted=1, True=0
# Sample 682: Predicted=1, True=0
# Sample 683: Predicted=0, True=0
# Sample 684: Predicted=0, True=0
# Sample 685: Predicted=0, True=0
# Sample 686: Predicted=0, True=0
# Sample 687: Predicted=1, True=0
# Sample 688: Predicted=0, True=0
# Sample 689: Predicted=1, True=0
# Sample 690: Predicted=1, True=0
# Sample 691: Predicted=1, True=0
# Sample 692: Predicted=1, True=0
# Sample 693: Predicted=1, True=0
# Sample 694: Predicted=1, True=0
# Sample 695: Predicted=1, True=0
# Sample 696: Predicted=0, True=0
# Sample 697: Predicted=0, True=0
# Sample 698: Predicted=0, True=0
# Sample 699: Predicted=0, True=0
# Sample 700: Predicted=0, True=0
# Sample 701: Predicted=1, True=0
# Sample 702: Predicted=1, True=0
# Sample 703: Predicted=0, True=0
# Sample 704: Predicted=0, True=0
# Sample 705: Predicted=0, True=0
# Sample 706: Predicted=0, True=0
# Sample 707: Predicted=1, True=0
# Sample 708: Predicted=1, True=0
# Sample 709: Predicted=1, True=0
# Sample 710: Predicted=1, True=0
# Sample 711: Predicted=1, True=0
# Sample 712: Predicted=1, True=0
# Sample 713: Predicted=1, True=0
# Sample 714: Predicted=1, True=0
# Sample 715: Predicted=0, True=0
# Sample 716: Predicted=1, True=0
# Sample 717: Predicted=1, True=0
# Sample 718: Predicted=1, True=0
# Sample 719: Predicted=1, True=0
# Sample 720: Predicted=1, True=0
# Sample 721: Predicted=1, True=0
# Sample 722: Predicted=1, True=0
# Sample 723: Predicted=1, True=0
# Sample 724: Predicted=1, True=0
# Sample 725: Predicted=1, True=0
# Sample 726: Predicted=1, True=0
# Sample 727: Predicted=1, True=0
# Sample 728: Predicted=1, True=0
# Sample 729: Predicted=1, True=0
# Sample 730: Predicted=1, True=0
# Sample 731: Predicted=1, True=0
# Sample 732: Predicted=1, True=0
# Sample 733: Predicted=1, True=0
# Sample 734: Predicted=1, True=0
# Sample 735: Predicted=1, True=0
# Sample 736: Predicted=1, True=0
# Sample 737: Predicted=1, True=0
# Sample 738: Predicted=1, True=0
# Sample 739: Predicted=1, True=0
# Sample 740: Predicted=1, True=0
# Sample 741: Predicted=1, True=0
# Sample 742: Predicted=1, True=0
# Sample 743: Predicted=1, True=0
# Sample 744: Predicted=1, True=0
# Sample 745: Predicted=1, True=0
# Sample 746: Predicted=1, True=0
# Sample 747: Predicted=1, True=0
# Sample 748: Predicted=1, True=0
# Sample 749: Predicted=1, True=0
# Sample 750: Predicted=1, True=0
# Sample 751: Predicted=1, True=0
# Sample 752: Predicted=1, True=0
# Sample 753: Predicted=1, True=0
# Sample 754: Predicted=0, True=0
# Sample 755: Predicted=0, True=0
# Sample 756: Predicted=0, True=0
# Sample 930: Predicted=1, True=0
# Sample 931: Predicted=1, True=0
# Sample 932: Predicted=1, True=0
# Sample 933: Predicted=1, True=0
# Sample 934: Predicted=1, True=0
# Sample 935: Predicted=1, True=0
# Sample 936: Predicted=1, True=0
# Sample 937: Predicted=1, True=0
# Sample 938: Predicted=1, True=0
# Sample 939: Predicted=0, True=0
# Sample 940: Predicted=1, True=0
# Sample 941: Predicted=1, True=0
# Sample 942: Predicted=0, True=0
# Sample 943: Predicted=1, True=0
# Sample 944: Predicted=0, True=0
# Sample 945: Predicted=1, True=0
# Sample 946: Predicted=1, True=0
# Sample 947: Predicted=0, True=0
# Sample 948: Predicted=0, True=0
# Sample 949: Predicted=0, True=0
# Sample 950: Predicted=0, True=0
# Sample 951: Predicted=0, True=0
# Sample 952: Predicted=0, True=0
# Sample 953: Predicted=0, True=0
# Sample 954: Predicted=0, True=0
# Sample 955: Predicted=0, True=0
# Sample 956: Predicted=0, True=0
# Sample 957: Predicted=0, True=0
# Sample 958: Predicted=0, True=0
# Sample 959: Predicted=0, True=0
# Sample 960: Predicted=0, True=0
# Sample 961: Predicted=0, True=0
# Sample 962: Predicted=0, True=0
# Sample 963: Predicted=0, True=0
# Sample 964: Predicted=0, True=0
# Sample 965: Predicted=0, True=0
# Sample 966: Predicted=0, True=0
# Sample 967: Predicted=0, True=0
# Sample 968: Predicted=0, True=0
# Sample 969: Predicted=0, True=0
# Sample 970: Predicted=0, True=0
# Sample 971: Predicted=0, True=0
# Sample 972: Predicted=0, True=0
# Sample 973: Predicted=0, True=0
# Sample 974: Predicted=0, True=0
# Sample 975: Predicted=0, True=0
# Sample 976: Predicted=0, True=0
# Sample 977: Predicted=0, True=0
# Sample 978: Predicted=0, True=0
# Sample 979: Predicted=0, True=0
# Sample 980: Predicted=0, True=0
# Sample 981: Predicted=0, True=0
# Sample 982: Predicted=0, True=0
# Sample 983: Predicted=0, True=0
# Sample 984: Predicted=0, True=0
# Sample 985: Predicted=0, True=0
# Sample 986: Predicted=0, True=0
# Sample 987: Predicted=0, True=0
# Sample 988: Predicted=0, True=0
# Sample 989: Predicted=0, True=0
# Sample 990: Predicted=0, True=0
# Sample 991: Predicted=0, True=0
# Sample 992: Predicted=0, True=0
# Sample 993: Predicted=0, True=0
# Sample 994: Predicted=0, True=0
# Sample 995: Predicted=1, True=0
# Sample 996: Predicted=1, True=0
# Sample 997: Predicted=1, True=0
# Sample 998: Predicted=1, True=0
# Sample 999: Predicted=1, True=0
# Sample 1000: Predicted=1, True=0
# Sample 1001: Predicted=1, True=0
# Sample 1002: Predicted=1, True=0
# Sample 1003: Predicted=1, True=0
# Sample 1004: Predicted=1, True=0
# Sample 1005: Predicted=1, True=0
# Sample 1006: Predicted=1, True=0
# Sample 1007: Predicted=1, True=0
# Sample 1008: Predicted=1, True=0
# Sample 1009: Predicted=1, True=0
# Sample 1010: Predicted=1, True=0
# Sample 1011: Predicted=1, True=0
# Sample 1012: Predicted=1, True=0
# Sample 1013: Predicted=1, True=0
# Sample 1014: Predicted=1, True=0
# Sample 1015: Predicted=1, True=0
# Sample 1016: Predicted=1, True=0
# Sample 1017: Predicted=1, True=0
# Sample 1018: Predicted=1, True=0
# Sample 1019: Predicted=1, True=0
# Sample 1020: Predicted=1, True=0
# Sample 1021: Predicted=1, True=0
# Sample 1022: Predicted=1, True=0
# Sample 1023: Predicted=1, True=0
# Sample 1024: Predicted=1, True=0
# Sample 1025: Predicted=1, True=0
# Sample 1026: Predicted=1, True=0
# Sample 1027: Predicted=1, True=0
# Sample 1028: Predicted=1, True=0
# Sample 1029: Predicted=1, True=0
# Sample 1030: Predicted=1, True=0
# Sample 1031: Predicted=1, True=0
# Sample 1032: Predicted=1, True=0
# Sample 1033: Predicted=1, True=0
# Sample 1034: Predicted=1, True=0
# Sample 1035: Predicted=1, True=0
# Sample 1036: Predicted=1, True=0
# Sample 1037: Predicted=1, True=0
# Sample 1038: Predicted=1, True=0
# Sample 1039: Predicted=1, True=0
# Sample 1040: Predicted=1, True=0
# Sample 1041: Predicted=1, True=0
# Sample 1042: Predicted=1, True=0
# Sample 1043: Predicted=1, True=0
# Sample 1044: Predicted=1, True=0
# Sample 1045: Predicted=1, True=0
# Sample 1046: Predicted=1, True=0
# Sample 1047: Predicted=1, True=0
# Sample 1048: Predicted=1, True=0
# Sample 1049: Predicted=1, True=0
# Sample 1050: Predicted=1, True=0
# Sample 1051: Predicted=1, True=0
# Sample 1052: Predicted=1, True=0
# Sample 1053: Predicted=1, True=1
# Sample 1054: Predicted=1, True=1
# Sample 1055: Predicted=1, True=1
# Sample 1056: Predicted=1, True=1
# Sample 1057: Predicted=1, True=1
# Sample 1058: Predicted=1, True=1
# Sample 1059: Predicted=1, True=1
# Sample 1060: Predicted=1, True=1
# Sample 1061: Predicted=1, True=1
# Sample 1062: Predicted=1, True=1
# Sample 1063: Predicted=1, True=1
# Sample 1064: Predicted=1, True=1
# Sample 1065: Predicted=1, True=1
# Sample 1066: Predicted=1, True=1
# Sample 1067: Predicted=1, True=1
# Sample 1068: Predicted=1, True=1
# Sample 1069: Predicted=1, True=1
# Sample 1070: Predicted=1, True=1
# Sample 1071: Predicted=1, True=1
# Sample 1072: Predicted=1, True=1
# Sample 1073: Predicted=1, True=1
# Sample 1074: Predicted=1, True=1
# Sample 1075: Predicted=1, True=1
# Sample 1076: Predicted=1, True=1
# Sample 1077: Predicted=1, True=1
# Sample 1078: Predicted=1, True=1
# Sample 1079: Predicted=1, True=1
# Sample 1080: Predicted=1, True=1
# Sample 1081: Predicted=1, True=1
# Sample 1082: Predicted=1, True=1
# Sample 1083: Predicted=1, True=1
# Sample 1084: Predicted=1, True=1
# Sample 1085: Predicted=1, True=1
# Sample 1086: Predicted=1, True=1
# Sample 1087: Predicted=1, True=1
# Sample 1088: Predicted=1, True=1
# Sample 1089: Predicted=1, True=1
# Sample 1090: Predicted=1, True=1
# Sample 1091: Predicted=1, True=1
# Sample 1092: Predicted=1, True=1
# Sample 1093: Predicted=1, True=1
# Sample 1094: Predicted=1, True=1
# Sample 1095: Predicted=1, True=1
# Sample 1096: Predicted=1, True=1
# Sample 1097: Predicted=1, True=1
# Sample 1098: Predicted=1, True=1
# Sample 1099: Predicted=1, True=1
# Sample 1100: Predicted=1, True=1
# Sample 1101: Predicted=1, True=1
# Sample 1102: Predicted=1, True=1
# Sample 1103: Predicted=1, True=1
# Sample 1104: Predicted=1, True=1
# Sample 1105: Predicted=1, True=1
# Sample 1106: Predicted=1, True=1
# Sample 1107: Predicted=1, True=1
# Sample 1108: Predicted=1, True=1
# Sample 1109: Predicted=1, True=1
# Sample 1110: Predicted=1, True=1
# Sample 1111: Predicted=1, True=1
# Sample 1112: Predicted=1, True=1
# Sample 1113: Predicted=1, True=1
# Sample 1114: Predicted=1, True=1
# Sample 1115: Predicted=1, True=1
# Sample 1116: Predicted=1, True=1
# Sample 1117: Predicted=1, True=1
# Sample 1118: Predicted=1, True=1
# Sample 1119: Predicted=1, True=1
# Sample 1120: Predicted=1, True=1
# Sample 1121: Predicted=1, True=1
# Sample 1122: Predicted=1, True=1
# Sample 1123: Predicted=1, True=1
# Sample 1124: Predicted=1, True=1
# Sample 1125: Predicted=1, True=1
# Sample 1126: Predicted=1, True=1
# Sample 1127: Predicted=1, True=1
# Sample 1128: Predicted=1, True=1
# Sample 1129: Predicted=1, True=1
# Sample 1130: Predicted=1, True=1
# Sample 1131: Predicted=1, True=1
# Sample 1132: Predicted=1, True=1
# Sample 1133: Predicted=1, True=1
# Sample 1134: Predicted=1, True=1
# Sample 1135: Predicted=1, True=1
# Sample 1136: Predicted=1, True=1
# Sample 1137: Predicted=1, True=1
# Sample 1138: Predicted=1, True=1
# Sample 1139: Predicted=1, True=1
# Sample 1140: Predicted=1, True=1
# Sample 1141: Predicted=1, True=1
# Sample 1142: Predicted=1, True=1
# Sample 1143: Predicted=1, True=1
# Sample 1144: Predicted=1, True=1
# Sample 1145: Predicted=1, True=1
# Sample 1146: Predicted=1, True=1
# Sample 1147: Predicted=1, True=1
# Sample 1148: Predicted=1, True=1
# Sample 1149: Predicted=1, True=1
# Sample 1150: Predicted=1, True=1
# Sample 1151: Predicted=1, True=1
# Sample 1152: Predicted=1, True=1
# Sample 1153: Predicted=1, True=1
# Sample 1154: Predicted=1, True=1
# Sample 1155: Predicted=1, True=1
# Sample 1156: Predicted=1, True=1
# Sample 1157: Predicted=1, True=1
# Sample 1158: Predicted=1, True=1
# Sample 1159: Predicted=1, True=1
# Sample 1160: Predicted=1, True=1
# Sample 1161: Predicted=1, True=1
# Sample 1162: Predicted=1, True=1
# Sample 1163: Predicted=1, True=1
# Sample 1164: Predicted=1, True=1
# Sample 1165: Predicted=1, True=1
# Sample 1166: Predicted=1, True=1
# Sample 1167: Predicted=1, True=1
# Sample 1168: Predicted=1, True=1
# Sample 1169: Predicted=1, True=1
# Sample 1170: Predicted=1, True=1
# Sample 1171: Predicted=1, True=1
# Sample 1172: Predicted=1, True=1
# Sample 1173: Predicted=1, True=1
# Sample 1174: Predicted=1, True=1
# Sample 1175: Predicted=1, True=1
# Sample 1176: Predicted=1, True=1
# Sample 1177: Predicted=1, True=1
# Sample 1178: Predicted=1, True=1
# Sample 1179: Predicted=1, True=1
# Sample 1180: Predicted=1, True=1
# Sample 1181: Predicted=1, True=1
# Sample 1182: Predicted=1, True=1
# Sample 1183: Predicted=1, True=1
# Sample 1184: Predicted=1, True=1
# Sample 1185: Predicted=1, True=1
# Sample 1186: Predicted=1, True=1
# Sample 1187: Predicted=1, True=1
# Sample 1188: Predicted=1, True=1
# Sample 1189: Predicted=1, True=1
# Sample 1190: Predicted=1, True=1
# Sample 1191: Predicted=1, True=1
# Sample 1192: Predicted=1, True=1
# Sample 1193: Predicted=1, True=1
# Sample 1194: Predicted=1, True=1
# Sample 1195: Predicted=1, True=1
# Sample 1196: Predicted=1, True=1
# Sample 1197: Predicted=1, True=1
# Sample 1198: Predicted=1, True=1
# Sample 1199: Predicted=1, True=1
# Sample 1200: Predicted=1, True=1
# Sample 1201: Predicted=1, True=1
# Sample 1202: Predicted=1, True=1
# Sample 1203: Predicted=1, True=1
# Sample 1204: Predicted=1, True=1
# Sample 1205: Predicted=1, True=1
# Sample 1206: Predicted=1, True=1
# Sample 1207: Predicted=1, True=1
# Sample 1208: Predicted=1, True=1
# Sample 1209: Predicted=1, True=1
# Sample 1210: Predicted=1, True=1
# Sample 1211: Predicted=1, True=1
# Sample 1212: Predicted=1, True=1
# Sample 1213: Predicted=1, True=1
# Sample 1214: Predicted=1, True=1
# Sample 1215: Predicted=1, True=1
# Sample 1216: Predicted=1, True=1
# Sample 1217: Predicted=1, True=1
# Sample 1218: Predicted=1, True=1
# Sample 1219: Predicted=1, True=1
# Sample 1220: Predicted=1, True=1
# Sample 1221: Predicted=1, True=1
# Sample 1222: Predicted=1, True=1
# Sample 1223: Predicted=1, True=1
# Sample 1224: Predicted=1, True=1
# Sample 1225: Predicted=1, True=1
# Sample 1226: Predicted=1, True=1
# Sample 1227: Predicted=1, True=1
# Sample 1228: Predicted=1, True=1
# Sample 1229: Predicted=1, True=1
# Sample 1230: Predicted=1, True=1
# Sample 1231: Predicted=1, True=1
# Sample 1232: Predicted=1, True=1
# Sample 1233: Predicted=3, True=1
# Sample 1234: Predicted=1, True=1
# Sample 1235: Predicted=1, True=1
# Sample 1236: Predicted=1, True=1
# Sample 1237: Predicted=1, True=1
# Sample 1238: Predicted=1, True=1
# Sample 1239: Predicted=1, True=1
# Sample 1240: Predicted=1, True=1
# Sample 1241: Predicted=1, True=1
# Sample 1242: Predicted=1, True=1
# Sample 1243: Predicted=1, True=1
# Sample 1244: Predicted=1, True=1
# Sample 1245: Predicted=1, True=1
# Sample 1246: Predicted=1, True=1
# Sample 1247: Predicted=1, True=1
# Sample 1248: Predicted=1, True=1
# Sample 1249: Predicted=1, True=1
# Sample 1250: Predicted=1, True=1
# Sample 1251: Predicted=1, True=1
# Sample 1252: Predicted=1, True=1
# Sample 1253: Predicted=1, True=1
# Sample 1254: Predicted=1, True=1
# Sample 1255: Predicted=1, True=1
# Sample 1256: Predicted=1, True=1
# Sample 1257: Predicted=1, True=1
# Sample 1258: Predicted=1, True=1
# Sample 1259: Predicted=1, True=1
# Sample 1260: Predicted=1, True=1
# Sample 1261: Predicted=1, True=1
# Sample 1262: Predicted=1, True=1
# Sample 1263: Predicted=1, True=1
# Sample 1264: Predicted=1, True=1
# Sample 1265: Predicted=1, True=1
# Sample 1266: Predicted=1, True=1
# Sample 1267: Predicted=1, True=1
# Sample 1268: Predicted=1, True=1
# Sample 1269: Predicted=1, True=1
# Sample 1270: Predicted=1, True=1
# Sample 1271: Predicted=1, True=1
# Sample 1272: Predicted=1, True=1
# Sample 1273: Predicted=1, True=1
# Sample 1274: Predicted=1, True=1
# Sample 1275: Predicted=1, True=1
# Sample 1276: Predicted=1, True=1
# Sample 1277: Predicted=1, True=1
# Sample 1278: Predicted=1, True=1
# Sample 1279: Predicted=1, True=1
# Sample 1280: Predicted=1, True=1
# Sample 1281: Predicted=1, True=1
# Sample 1282: Predicted=1, True=1
# Sample 1283: Predicted=1, True=1
# Sample 1284: Predicted=1, True=1
# Sample 1285: Predicted=1, True=1
# Sample 1286: Predicted=1, True=1
# Sample 1287: Predicted=1, True=1
# Sample 1288: Predicted=1, True=1
# Sample 1289: Predicted=1, True=1
# Sample 1290: Predicted=1, True=1
# Sample 1291: Predicted=1, True=1
# Sample 1292: Predicted=1, True=1
# Sample 1293: Predicted=1, True=1
# Sample 1294: Predicted=1, True=1
# Sample 1295: Predicted=1, True=1
# Sample 1296: Predicted=1, True=1
# Sample 1297: Predicted=1, True=1
# Sample 1298: Predicted=1, True=1
# Sample 1299: Predicted=1, True=1
# Sample 1300: Predicted=1, True=1
# Sample 1301: Predicted=1, True=1
# Sample 1302: Predicted=1, True=1
# Sample 1303: Predicted=1, True=1
# Sample 1304: Predicted=1, True=1
# Sample 1305: Predicted=1, True=1
# Sample 1306: Predicted=1, True=1
# Sample 1307: Predicted=1, True=1
# Sample 1308: Predicted=1, True=1
# Sample 1309: Predicted=1, True=1
# Sample 1310: Predicted=1, True=1
# Sample 1311: Predicted=1, True=1
# Sample 1312: Predicted=1, True=1
# Sample 1313: Predicted=1, True=1
# Sample 1314: Predicted=1, True=1
# Sample 1315: Predicted=1, True=1
# Sample 1316: Predicted=1, True=1
# Sample 1317: Predicted=1, True=1
# Sample 1318: Predicted=1, True=1
# Sample 1319: Predicted=1, True=1
# Sample 1320: Predicted=1, True=1
# Sample 1321: Predicted=1, True=1
# Sample 1322: Predicted=1, True=1
# Sample 1323: Predicted=0, True=1
# Sample 1324: Predicted=0, True=1
# Sample 1325: Predicted=1, True=1
# Sample 1326: Predicted=1, True=1
# Sample 1327: Predicted=1, True=1
# Sample 1328: Predicted=1, True=1
# Sample 1329: Predicted=1, True=1
# Sample 1330: Predicted=0, True=1
# Sample 1331: Predicted=0, True=1
# Sample 1332: Predicted=1, True=1
# Sample 1333: Predicted=1, True=1
# Sample 1334: Predicted=1, True=1
# Sample 1335: Predicted=1, True=1
# Sample 1336: Predicted=1, True=1
# Sample 1337: Predicted=1, True=1
# Sample 1338: Predicted=1, True=1
# Sample 1339: Predicted=1, True=1
# Sample 1340: Predicted=1, True=1
# Sample 1341: Predicted=1, True=1
# Sample 1342: Predicted=1, True=1
# Sample 1343: Predicted=1, True=1
# Sample 1344: Predicted=1, True=1
# Sample 1345: Predicted=1, True=1
# Sample 1346: Predicted=1, True=1
# Sample 1347: Predicted=1, True=1
# Sample 1348: Predicted=1, True=1
# Sample 1349: Predicted=1, True=1
# Sample 1350: Predicted=1, True=1
# Sample 1351: Predicted=1, True=1
# Sample 1352: Predicted=1, True=1
# Sample 1353: Predicted=1, True=1
# Sample 1354: Predicted=1, True=1
# Sample 1355: Predicted=1, True=1
# Sample 1356: Predicted=1, True=1
# Sample 1357: Predicted=1, True=1
# Sample 1358: Predicted=1, True=1
# Sample 1359: Predicted=1, True=1
# Sample 1360: Predicted=1, True=1
# Sample 1361: Predicted=1, True=1
# Sample 1362: Predicted=1, True=1
# Sample 1363: Predicted=1, True=1
# Sample 1364: Predicted=1, True=1
# Sample 1365: Predicted=1, True=1
# Sample 1366: Predicted=1, True=1
# Sample 1367: Predicted=1, True=1
# Sample 1368: Predicted=1, True=1
# Sample 1369: Predicted=1, True=1
# Sample 1370: Predicted=1, True=1
# Sample 1371: Predicted=1, True=1
# Sample 1372: Predicted=1, True=1
# Sample 1373: Predicted=1, True=1
# Sample 1374: Predicted=1, True=1
# Sample 1375: Predicted=1, True=1
# Sample 1376: Predicted=1, True=1
# Sample 1377: Predicted=1, True=1
# Sample 1378: Predicted=1, True=1
# Sample 1379: Predicted=1, True=1
# Sample 1380: Predicted=1, True=1
# Sample 1381: Predicted=1, True=1
# Sample 1382: Predicted=1, True=1
# Sample 1383: Predicted=1, True=1
# Sample 1384: Predicted=1, True=1
# Sample 1385: Predicted=1, True=1
# Sample 1386: Predicted=1, True=1
# Sample 1387: Predicted=1, True=1
# Sample 1388: Predicted=1, True=1
# Sample 1389: Predicted=1, True=1
# Sample 1390: Predicted=1, True=1
# Sample 1391: Predicted=1, True=1
# Sample 1392: Predicted=1, True=1
# Sample 1393: Predicted=1, True=1
# Sample 1394: Predicted=1, True=1
# Sample 1395: Predicted=1, True=1
# Sample 1396: Predicted=1, True=1
# Sample 1397: Predicted=1, True=1
# Sample 1398: Predicted=1, True=1
# Sample 1399: Predicted=1, True=1
# Sample 1400: Predicted=1, True=1
# Sample 1401: Predicted=1, True=1
# Sample 1402: Predicted=1, True=1
# Sample 1403: Predicted=1, True=1
# Sample 1404: Predicted=1, True=1
# Sample 1405: Predicted=1, True=1
# Sample 1406: Predicted=1, True=1
# Sample 1407: Predicted=1, True=1
# Sample 1408: Predicted=1, True=1
# Sample 1409: Predicted=1, True=1
# Sample 1410: Predicted=1, True=1
# Sample 1411: Predicted=1, True=1
# Sample 1412: Predicted=1, True=1
# Sample 1413: Predicted=1, True=1
# Sample 1414: Predicted=1, True=1
# Sample 1415: Predicted=1, True=1
# Sample 1416: Predicted=1, True=1
# Sample 1417: Predicted=1, True=1
# Sample 1418: Predicted=1, True=1
# Sample 1419: Predicted=1, True=1
# Sample 1420: Predicted=1, True=1
# Sample 1421: Predicted=1, True=1
# Sample 1422: Predicted=1, True=1
# Sample 1423: Predicted=1, True=1
# Sample 1424: Predicted=1, True=1
# Sample 1425: Predicted=1, True=1
# Sample 1426: Predicted=1, True=1
# Sample 1427: Predicted=1, True=1
# Sample 1428: Predicted=1, True=1
# Sample 1429: Predicted=1, True=1
# Sample 1430: Predicted=1, True=1
# Sample 1431: Predicted=1, True=1
# Sample 1432: Predicted=1, True=1
# Sample 1433: Predicted=1, True=1
# Sample 1434: Predicted=1, True=1
# Sample 1435: Predicted=1, True=1
# Sample 1436: Predicted=1, True=1
# Sample 1437: Predicted=1, True=1
# Sample 1438: Predicted=1, True=1
# Sample 1439: Predicted=1, True=1
# Sample 1440: Predicted=1, True=1
# Sample 1441: Predicted=1, True=1
# Sample 1442: Predicted=1, True=1
# Sample 1443: Predicted=1, True=1
# Sample 1444: Predicted=1, True=1
# Sample 1445: Predicted=1, True=1
# Sample 1446: Predicted=1, True=1
# Sample 1447: Predicted=1, True=1
# Sample 1448: Predicted=1, True=1
# Sample 1449: Predicted=1, True=1
# Sample 1450: Predicted=1, True=1
# Sample 1451: Predicted=1, True=1
# Sample 1452: Predicted=1, True=1
# Sample 1453: Predicted=1, True=1
# Sample 1454: Predicted=1, True=1
# Sample 1455: Predicted=1, True=1
# Sample 1456: Predicted=1, True=1
# Sample 1457: Predicted=1, True=1
# Sample 1458: Predicted=1, True=1
# Sample 1459: Predicted=1, True=1
# Sample 1460: Predicted=1, True=1
# Sample 1461: Predicted=1, True=1
# Sample 1462: Predicted=1, True=1
# Sample 1463: Predicted=1, True=1
# Sample 1464: Predicted=1, True=1
# Sample 1465: Predicted=1, True=1
# Sample 1466: Predicted=1, True=1
# Sample 1467: Predicted=1, True=1
# Sample 1468: Predicted=1, True=1
# Sample 1469: Predicted=1, True=1
# Sample 1470: Predicted=1, True=1
# Sample 1471: Predicted=1, True=1
# ...
# Sample 11753: Predicted=14, True=14
# Sample 11754: Predicted=14, True=14
# Sample 11755: Predicted=14, True=14
# Sample 11756: Predicted=14, True=14
# Sample 11757: Predicted=14, True=14
# Sample 11758: Predicted=13, True=14
# Sample 11759: Predicted=14, True=14
# Sample 11760: Predicted=14, True=14
# Sample 11761: Predicted=14, True=14
# Sample 11762: Predicted=14, True=14
# Sample 11763: Predicted=14, True=14
# Sample 11764: Predicted=14, True=14
# Sample 11765: Predicted=14, True=14
# Sample 11766: Predicted=14, True=14
# Sample 11767: Predicted=14, True=14
# Sample 11768: Predicted=14, True=14
# Sample 11769: Predicted=14, True=14
# Sample 11770: Predicted=14, True=14
# Sample 11771: Predicted=14, True=14
# Sample 11772: Predicted=14, True=14
# Sample 11773: Predicted=14, True=14
# Sample 11774: Predicted=14, True=14
# Sample 11775: Predicted=14, True=14
# Sample 11776: Predicted=14, True=14
# Sample 11777: Predicted=14, True=14
# Sample 11778: Predicted=14, True=14
# Sample 11779: Predicted=14, True=14
# Sample 11780: Predicted=14, True=14
# Sample 11781: Predicted=14, True=14
# Sample 11782: Predicted=14, True=14
# Sample 11783: Predicted=14, True=14
# Sample 11784: Predicted=14, True=14
# Sample 11785: Predicted=14, True=14
# Sample 11786: Predicted=14, True=14
# Sample 11787: Predicted=14, True=14
# Sample 11788: Predicted=14, True=14
# Sample 11789: Predicted=14, True=14
# Sample 11790: Predicted=14, True=14
# Sample 11791: Predicted=14, True=14
# Sample 11792: Predicted=14, True=14
# Sample 11793: Predicted=14, True=14
# Sample 11794: Predicted=14, True=14
# Sample 11795: Predicted=14, True=14
# Sample 11796: Predicted=14, True=14
# Sample 11797: Predicted=14, True=14
# Sample 11798: Predicted=14, True=14
# Sample 11799: Predicted=14, True=14
# Sample 11800: Predicted=14, True=14
# Sample 11801: Predicted=14, True=14
# Sample 11802: Predicted=14, True=14
# Sample 11803: Predicted=14, True=14
# Sample 11804: Predicted=14, True=14
# Sample 11805: Predicted=14, True=14
# Sample 11806: Predicted=14, True=14
# Sample 11807: Predicted=14, True=14
# Sample 11808: Predicted=14, True=14
# Sample 11809: Predicted=14, True=14
# Sample 11810: Predicted=14, True=14
# Sample 11811: Predicted=14, True=14
# Sample 11812: Predicted=14, True=14
# Sample 11813: Predicted=14, True=14
# Sample 11814: Predicted=14, True=14
# Sample 11815: Predicted=14, True=14
# Sample 11816: Predicted=14, True=14
# Sample 11817: Predicted=14, True=14
# Sample 11818: Predicted=14, True=14
# Sample 11819: Predicted=14, True=14
# Sample 11820: Predicted=14, True=14
# Sample 11821: Predicted=14, True=14
# Sample 11822: Predicted=14, True=14
# Sample 11823: Predicted=14, True=14
# Sample 11824: Predicted=14, True=14
# Sample 11825: Predicted=14, True=14
# Sample 11826: Predicted=14, True=14
# Sample 11827: Predicted=14, True=14
# Sample 11828: Predicted=14, True=14
# Sample 11829: Predicted=14, True=14
# Sample 11830: Predicted=14, True=14
# Sample 11831: Predicted=14, True=14
# Sample 11832: Predicted=14, True=14
# Sample 11833: Predicted=14, True=14
# Sample 11834: Predicted=14, True=14
# Sample 11835: Predicted=14, True=14
# Sample 11836: Predicted=14, True=14
# Sample 11837: Predicted=14, True=14
# Sample 11838: Predicted=14, True=14
# Sample 11839: Predicted=14, True=14
# Sample 11840: Predicted=14, True=14
# Sample 11841: Predicted=14, True=14
# Sample 11842: Predicted=14, True=14
# Sample 11843: Predicted=14, True=14
# Sample 11844: Predicted=14, True=14
# Sample 11845: Predicted=14, True=14
# Sample 11846: Predicted=14, True=14
# Sample 11847: Predicted=14, True=14
# Sample 11848: Predicted=14, True=14
# Sample 11849: Predicted=14, True=14
# Sample 11850: Predicted=14, True=14
# Sample 11851: Predicted=14, True=14
# Sample 11852: Predicted=14, True=14
# Sample 11853: Predicted=14, True=14
# Sample 11854: Predicted=14, True=14
# Sample 11855: Predicted=14, True=14
# Sample 11856: Predicted=14, True=14
# Sample 11857: Predicted=14, True=14
# Sample 11858: Predicted=14, True=14
# Sample 11859: Predicted=14, True=14
# Sample 11860: Predicted=14, True=14
# Sample 11861: Predicted=14, True=14
# Sample 11862: Predicted=14, True=14
# Sample 11863: Predicted=14, True=14
# Sample 11864: Predicted=14, True=14
# Sample 11865: Predicted=14, True=14
# Sample 11866: Predicted=14, True=14
# Sample 11867: Predicted=14, True=14
# Sample 11868: Predicted=14, True=14
# Sample 11869: Predicted=14, True=14
# Sample 11870: Predicted=14, True=14
# Sample 11871: Predicted=14, True=14
# Sample 11872: Predicted=14, True=14
# Sample 11873: Predicted=14, True=14
# Sample 11874: Predicted=14, True=14
# Sample 11875: Predicted=14, True=14
# Sample 11876: Predicted=14, True=14
# Sample 11877: Predicted=14, True=14
# Sample 11878: Predicted=14, True=14
# Sample 11879: Predicted=14, True=14
# Sample 11880: Predicted=14, True=14
# Sample 11881: Predicted=14, True=14
# Sample 11882: Predicted=14, True=14
# Sample 11883: Predicted=14, True=14
# Sample 11884: Predicted=14, True=14
# Sample 11885: Predicted=14, True=14
# Sample 11886: Predicted=14, True=14
# Sample 11887: Predicted=14, True=14
# Sample 11888: Predicted=14, True=14
# Sample 11889: Predicted=14, True=14
# Sample 11890: Predicted=14, True=14
# Sample 11891: Predicted=14, True=14
# Sample 11892: Predicted=14, True=14
# Sample 11893: Predicted=14, True=14
# Sample 11894: Predicted=14, True=14
# Sample 11895: Predicted=14, True=14
# Sample 11896: Predicted=14, True=14
# Sample 11897: Predicted=14, True=14
# Sample 11898: Predicted=14, True=14
# Sample 11899: Predicted=14, True=14
# Sample 11900: Predicted=14, True=14
# Sample 11901: Predicted=14, True=14
# Sample 11902: Predicted=14, True=14
# Sample 11903: Predicted=14, True=14
# Sample 11904: Predicted=14, True=14
# Sample 11905: Predicted=14, True=14
# Sample 11906: Predicted=14, True=14
# Sample 11907: Predicted=14, True=14
# Sample 11908: Predicted=14, True=14
# Sample 11909: Predicted=14, True=14
# Sample 11910: Predicted=14, True=14
# Sample 11911: Predicted=14, True=14
# Sample 11912: Predicted=14, True=14
# Sample 11913: Predicted=14, True=14
# Sample 11914: Predicted=14, True=14
# Sample 11915: Predicted=14, True=14
# Sample 11916: Predicted=14, True=14
# Sample 11917: Predicted=14, True=14
# Sample 11918: Predicted=14, True=14
# Sample 11919: Predicted=14, True=14
# Sample 11920: Predicted=14, True=14
# Sample 11921: Predicted=14, True=14
# Sample 11922: Predicted=14, True=14
# Sample 11923: Predicted=14, True=14
# Sample 11924: Predicted=14, True=14
# Sample 11925: Predicted=14, True=14
# Sample 11926: Predicted=14, True=14
# Sample 11927: Predicted=14, True=14
# Sample 11928: Predicted=14, True=14
# Sample 11929: Predicted=14, True=14
# Sample 11930: Predicted=14, True=14
# Sample 11931: Predicted=14, True=14
# Sample 11932: Predicted=14, True=14
# Sample 11933: Predicted=14, True=14
# Sample 11934: Predicted=14, True=14
# Sample 11935: Predicted=14, True=14
# Sample 11936: Predicted=14, True=14
# Sample 11937: Predicted=14, True=14
# Sample 11938: Predicted=14, True=14
# Sample 11939: Predicted=14, True=14
# Sample 11940: Predicted=14, True=14
# Sample 11941: Predicted=14, True=14
# Sample 11942: Predicted=14, True=14
# Sample 11943: Predicted=14, True=14
# Sample 11944: Predicted=14, True=14
# Sample 11945: Predicted=14, True=14
# Sample 11946: Predicted=14, True=14
# Sample 11947: Predicted=14, True=14
# Sample 11948: Predicted=14, True=14
# Sample 11949: Predicted=14, True=14
# Sample 11950: Predicted=14, True=14
# Sample 11951: Predicted=14, True=14
# Sample 11952: Predicted=14, True=14
# Sample 11953: Predicted=14, True=14
# Sample 11954: Predicted=14, True=14
# Sample 11955: Predicted=14, True=14
# Sample 11956: Predicted=14, True=14
# Sample 11957: Predicted=14, True=14
# Sample 11958: Predicted=14, True=14
# Sample 11959: Predicted=14, True=14
# Sample 11960: Predicted=14, True=14
# Sample 11961: Predicted=14, True=14
# Sample 11962: Predicted=14, True=14
# Sample 11963: Predicted=14, True=14
# Sample 11964: Predicted=14, True=14
# Sample 11965: Predicted=14, True=14
# Sample 11966: Predicted=14, True=14
# Sample 11967: Predicted=14, True=14
# Sample 11968: Predicted=14, True=14
# Sample 11969: Predicted=14, True=14
# Sample 11970: Predicted=14, True=14
# Sample 11971: Predicted=14, True=14
# Sample 11972: Predicted=14, True=14
# Sample 11973: Predicted=14, True=14
# Sample 11974: Predicted=14, True=14
# Sample 11975: Predicted=14, True=14
# Sample 11976: Predicted=14, True=14
# Sample 11977: Predicted=14, True=14
# Sample 11978: Predicted=14, True=14
# Sample 11979: Predicted=14, True=14
# Sample 11980: Predicted=14, True=14
# Sample 11981: Predicted=14, True=14
# Sample 11982: Predicted=14, True=14
# Sample 11983: Predicted=14, True=14
# Sample 11984: Predicted=14, True=14
# Sample 11985: Predicted=14, True=14
# Sample 11986: Predicted=14, True=14
# Sample 11987: Predicted=14, True=14
# Sample 11988: Predicted=14, True=14
# Sample 11989: Predicted=14, True=14
# Sample 11990: Predicted=14, True=14
# Sample 11991: Predicted=14, True=14
# Sample 11992: Predicted=14, True=14
# Sample 11993: Predicted=14, True=14
# Sample 11994: Predicted=14, True=14
# Sample 11995: Predicted=14, True=14
# Sample 11996: Predicted=14, True=14
# Sample 11997: Predicted=14, True=14
# Sample 11998: Predicted=14, True=14
# Sample 11999: Predicted=14, True=14
# Sample 12000: Predicted=14, True=14
# Sample 12001: Predicted=14, True=14
# Sample 12002: Predicted=14, True=14
# Sample 12003: Predicted=14, True=14
# Sample 12004: Predicted=14, True=14
# Sample 12005: Predicted=14, True=14
# Sample 12006: Predicted=14, True=14
# Sample 12007: Predicted=14, True=14
# Sample 12008: Predicted=14, True=14
# Sample 12009: Predicted=14, True=14
# Sample 12010: Predicted=14, True=14
# Sample 12011: Predicted=14, True=14
# Sample 12012: Predicted=14, True=14
# Sample 12013: Predicted=14, True=14
# Sample 12014: Predicted=14, True=14
# Sample 12015: Predicted=14, True=14
# Sample 12016: Predicted=14, True=14
# Sample 12017: Predicted=14, True=14
# Sample 12018: Predicted=14, True=14
# Sample 12019: Predicted=14, True=14
# Sample 12020: Predicted=14, True=14
# Sample 12021: Predicted=14, True=14
# Sample 12022: Predicted=14, True=14
# Sample 12023: Predicted=14, True=14
# Sample 12024: Predicted=14, True=14
# Sample 12025: Predicted=14, True=14
# Sample 12026: Predicted=14, True=14
# Sample 12027: Predicted=14, True=14
# Sample 12028: Predicted=14, True=14
# Sample 12029: Predicted=14, True=14
# Sample 12030: Predicted=14, True=14
# Sample 12031: Predicted=14, True=14
# Sample 12032: Predicted=14, True=14
# Sample 12033: Predicted=14, True=14
# Sample 12034: Predicted=14, True=14
# Sample 12035: Predicted=14, True=14
# Sample 12036: Predicted=14, True=14
# Sample 12037: Predicted=14, True=14
# Sample 12038: Predicted=14, True=14
# Sample 12039: Predicted=14, True=14
# Sample 12040: Predicted=14, True=14
# Sample 12041: Predicted=14, True=14
# Sample 12042: Predicted=14, True=14
# Sample 12043: Predicted=14, True=14
# Sample 12044: Predicted=14, True=14
# Sample 12045: Predicted=14, True=14
# Sample 12046: Predicted=14, True=14
# Sample 12047: Predicted=14, True=14
# Sample 12048: Predicted=14, True=14
# Sample 12049: Predicted=14, True=14
# Sample 12050: Predicted=14, True=14
# Sample 12051: Predicted=14, True=14
# Sample 12052: Predicted=14, True=14
# Sample 12053: Predicted=14, True=14
# Sample 12054: Predicted=14, True=14
# Sample 12055: Predicted=14, True=14
# Sample 12056: Predicted=14, True=14
# Sample 12057: Predicted=14, True=14
# Sample 12058: Predicted=14, True=14
# Sample 12059: Predicted=14, True=14
# Sample 12060: Predicted=14, True=14
# Sample 12061: Predicted=14, True=14
# Sample 12062: Predicted=14, True=14
# Sample 12063: Predicted=14, True=14
# Sample 12064: Predicted=14, True=14
# Sample 12065: Predicted=14, True=14
# Sample 12066: Predicted=14, True=14
# Sample 12067: Predicted=14, True=14
# Sample 12068: Predicted=14, True=14
# Sample 12069: Predicted=14, True=14
# Sample 12070: Predicted=14, True=14
# Sample 12071: Predicted=14, True=14
# Sample 12072: Predicted=14, True=14
# Sample 12073: Predicted=14, True=14
# Sample 12074: Predicted=14, True=14
# Sample 12075: Predicted=14, True=14
# Sample 12076: Predicted=14, True=14
# Sample 12077: Predicted=14, True=14
# Sample 12078: Predicted=14, True=14
# Sample 12079: Predicted=14, True=14
# Sample 12080: Predicted=14, True=14
# Sample 12081: Predicted=14, True=14
# Sample 12082: Predicted=14, True=14
# Sample 12083: Predicted=14, True=14
# Sample 12084: Predicted=14, True=14
# Sample 12085: Predicted=14, True=14
# Sample 12086: Predicted=14, True=14
# Sample 12087: Predicted=14, True=14
# Sample 12088: Predicted=14, True=14
# Sample 12089: Predicted=14, True=14
# Sample 12090: Predicted=14, True=14
# Sample 12091: Predicted=14, True=14
# Sample 12092: Predicted=14, True=14
# Sample 12093: Predicted=14, True=14
# Sample 12094: Predicted=14, True=14
# Sample 12095: Predicted=14, True=14
# Sample 12096: Predicted=14, True=14
# Sample 12097: Predicted=14, True=14
# Sample 12098: Predicted=14, True=14
# Sample 12099: Predicted=14, True=14
# Sample 12100: Predicted=14, True=14
# Sample 12101: Predicted=14, True=14
# Sample 12102: Predicted=14, True=14
# Sample 12103: Predicted=14, True=14
# Sample 12104: Predicted=14, True=14
# Sample 12105: Predicted=14, True=14
# Sample 12106: Predicted=14, True=14
# Sample 12107: Predicted=14, True=14
# Sample 12108: Predicted=14, True=14
# Sample 12109: Predicted=14, True=14
# Sample 12110: Predicted=14, True=14
# Sample 12111: Predicted=14, True=14
# Sample 12112: Predicted=14, True=14
# Sample 12113: Predicted=14, True=14
# Sample 12114: Predicted=14, True=14
# Sample 12115: Predicted=14, True=14
# Sample 12116: Predicted=14, True=14
# Sample 12117: Predicted=14, True=14
# Sample 12118: Predicted=14, True=14
# Sample 12119: Predicted=14, True=14
# Sample 12120: Predicted=14, True=14
# Sample 12121: Predicted=14, True=14
# Sample 12122: Predicted=14, True=14
# Sample 12123: Predicted=14, True=14
# Sample 12124: Predicted=14, True=14
# Sample 12125: Predicted=14, True=14
# Sample 12126: Predicted=14, True=14
# Sample 12127: Predicted=14, True=14
# Sample 12128: Predicted=14, True=14
# Sample 12129: Predicted=14, True=14
# Sample 12130: Predicted=14, True=14
# Sample 12131: Predicted=14, True=14
# Sample 12132: Predicted=14, True=14
# Sample 12133: Predicted=14, True=14
# Sample 12134: Predicted=14, True=14
# Sample 12135: Predicted=14, True=14
# Sample 12136: Predicted=14, True=14
# Sample 12137: Predicted=14, True=14
# Sample 12138: Predicted=14, True=14
# Sample 12139: Predicted=14, True=14
# Sample 12140: Predicted=14, True=14
# Sample 12141: Predicted=14, True=14
# Sample 12142: Predicted=14, True=14
# Sample 12143: Predicted=14, True=14
# Sample 12144: Predicted=14, True=14
# Sample 12145: Predicted=14, True=14
# Sample 12146: Predicted=14, True=14
# Sample 12147: Predicted=14, True=14
# Sample 12148: Predicted=14, True=14
# Sample 12149: Predicted=14, True=14
# Sample 12150: Predicted=14, True=14
# Sample 12151: Predicted=14, True=14
# Sample 12152: Predicted=14, True=14
# Sample 12153: Predicted=14, True=14
# Sample 12154: Predicted=14, True=14
# Sample 12155: Predicted=14, True=14
# Sample 12156: Predicted=14, True=14
# Sample 12157: Predicted=14, True=14
# Sample 12158: Predicted=14, True=14
# Sample 12159: Predicted=14, True=14
# Sample 12160: Predicted=14, True=14
# Sample 12161: Predicted=14, True=14
# Sample 12162: Predicted=14, True=14
# Sample 12163: Predicted=14, True=14
# Sample 12164: Predicted=14, True=14
# Sample 12165: Predicted=14, True=14
# Sample 12166: Predicted=14, True=14
# Sample 12167: Predicted=14, True=14
# Sample 12168: Predicted=14, True=14
# Sample 12169: Predicted=14, True=14
# Sample 12170: Predicted=14, True=14
# Sample 12171: Predicted=14, True=14
# Sample 12172: Predicted=14, True=14
# Sample 12173: Predicted=14, True=14
# Sample 12174: Predicted=14, True=14
# Sample 12175: Predicted=14, True=14
# Sample 12176: Predicted=14, True=14
# Sample 12177: Predicted=14, True=14
# Sample 12178: Predicted=14, True=14
# Sample 12179: Predicted=14, True=14
# Sample 12180: Predicted=14, True=14
# Sample 12181: Predicted=14, True=14
# Sample 12182: Predicted=14, True=14
# Sample 12183: Predicted=14, True=14
# Sample 12184: Predicted=14, True=14
# Sample 12185: Predicted=14, True=14
# Sample 12186: Predicted=14, True=14
# Sample 12187: Predicted=14, True=14
# Sample 12188: Predicted=14, True=14
# Sample 12189: Predicted=14, True=14
# Sample 12190: Predicted=14, True=14
# Sample 12191: Predicted=14, True=14
# Sample 12192: Predicted=14, True=14
# Sample 12193: Predicted=14, True=14
# Sample 12194: Predicted=14, True=14
# Sample 12195: Predicted=14, True=14
# Sample 12196: Predicted=14, True=14
