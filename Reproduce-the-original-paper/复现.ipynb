# %% [markdown]
# 数据集： Ｈｏｕｓｔｏｎ２０１３、Ｐａｖｉａ Ｕｎｉｖｅｒｓｉｔｙ和 ＷＨＵ－Ｈｉ－Ｌｏｎｇｋｏｕ

# %% [markdown]
# 特征提取模块由３个卷积层构成。每个卷积 层包 含 卷 积、批 归 一 化、非 线 性 激 活 层 ＲｅＬＵ 和 最大 池 化 ４ 个 操 作。

# %% [markdown]
# 25/01/16 第一次 会议总结：
#
# 1. 存在的问题
#
# 1.1  正负样本构建的问题:
#
#     当前对比学习的正样本仅由拆分出的一个视图构成，其余全部作为负样本。这导致模型对正负样本的区分能力不足，可能引入大量错误负样本， 这次会议反映出我对 正负样本构建不了解。
#
#     t-SNE 可视化结果显示，学习后的特征类别数远多于实际类别数，学习到的特征嵌入存在问题。
#
# 1.2  对比学习损失函数的理解不足:
#
#     对于 InfoNCE 损失以及其他对比损失的计算公式并不理解。
#
# 2. 需要学习的内容
#
# 2.1  传统自监督学习方法:
#
#     基于对比学习的方法: SimCLR等主流对比学习框架的正负样本构建策略。
#
#     基于生成的自监督学习: MAE（Masked Autoencoder）：通过遮掩预测重建输入。
#
# 2.2  数据增强策略的学习
#
#
# 2.3  对比学习中的正负样本构建和损失函数计算:
#
#     平衡正负样本数量的方法
#
#     损失函数计算:
#
#         InfoNCE 损失的数学公式和梯度优化。
#         了解其他的。

# %%
import os
from pathlib import Path
import numpy as np
from scipy.sparse import coo_array
import skimage.exposure
from scipy.sparse import coo_matrix
import warnings
from io import StringIO

def _read_roi(path: Path, shape) -> coo_matrix:
    """
    读取 ENVI 软件导出 ROI 文件的 txt 文件，生成一个稀疏矩阵，表示每个像素点的类别标签。
    
    :param path: 文件路径，ENVI ROI 文件的路径
    :param shape: 图像的形状（height, width）
    :return: 一个稀疏矩阵，非零值表示像素点的类别标签
    """
    warnings.simplefilter("ignore", category=UserWarning)  # 忽略 loadtxt 的警告
    data = []
    rows = []
    cols = []
    current_label = 0
    buffer = ""

    with open(path, 'r') as f:
        for line in f:
            # 判断是否为新 ROI 的分割点
            if line.strip() == "" or line.startswith(";") or "ROI" in line:
                if buffer:  # 如果缓冲区有内容，解析为坐标数据
                    roi_data = np.loadtxt(StringIO(buffer), usecols=(2, 1), dtype=int)
                    if roi_data.size > 0:
                        r, c = roi_data.T
                        rows.extend(r)
                        cols.extend(c)
                        data.extend([current_label] * len(r))
                    buffer = ""  # 清空缓冲区
                # 如果遇到 ROI name 行，增加类别标签
                if "ROI name" in line:
                    current_label += 1
            else:
                buffer += line  # 将数据加入缓冲区

        # 处理最后一个 ROI
        if buffer:
            roi_data = np.loadtxt(StringIO(buffer), usecols=(2, 1), dtype=int)
            if roi_data.size > 0:
                r, c = roi_data.T
                rows.extend(r)
                cols.extend(c)
                data.extend([current_label] * len(r))

    warnings.resetwarnings()

    # 创建稀疏矩阵
    img = coo_matrix((data, (rows, cols)), shape=shape, dtype=int)
    return img


def load_houston2013(data_path: Path):
    """
    从本地路径加载 Houston2013 数据集。

    :param data_path: 数据集的根目录路径。
    :return: (casi, lidar, train_truth, test_truth, info)
    """
    FILES_PATH = data_path
    assert FILES_PATH.exists(), f"{FILES_PATH} does not exist. Please check the path."

    # 加载图像数据
    lidar = skimage.io.imread(FILES_PATH / '2013_IEEE_GRSS_DF_Contest_LiDAR.tif')[np.newaxis, :, :]  # (1, 349, 1905)
    casi = skimage.io.imread(FILES_PATH / '2013_IEEE_GRSS_DF_Contest_CASI.tif').transpose(2, 0, 1)   # (144, 349, 1905)

    # 加载训练集和测试集的真值
    train_truth = _read_roi(FILES_PATH / '2013_IEEE_GRSS_DF_Contest_Samples_TR.txt', (349, 1905))
    test_truth = _read_roi(FILES_PATH / '2013_IEEE_GRSS_DF_Contest_Samples_VA.txt', (349, 1905))

    # 数据集元信息
    info = {
        'n_band_casi': 144,
        'n_band_lidar': 1,
        'width': 1905,
        'height': 349,
        'label_dict': {
            1: 'Healthy grass',
            2: 'Stressed grass',
            3: 'Synthetic grass',
            4: 'Trees',
            5: 'Soil',
            6: 'Water',
            7: 'Residential',
            8: 'Commercial',
            9: 'Road',
            10: 'Highway',
            11: 'Railway',
            12: 'Parking Lot 1',
            13: 'Parking Lot 2',
            14: 'Tennis Court',
            15: 'Running Track',
        }
    }

    return casi, lidar, train_truth, test_truth, info


# 指定数据集路径
data_path = Path(r"E:\code\-\对比学习\fx\Houston2013\2013_DFTC")

# 加载数据集
casi, lidar, train_truth, test_truth, info = load_houston2013(data_path)

# 打印数据集基本信息
print(f"CASI shape: {casi.shape}")   # 高光谱图像 (144, 349, 1905)
print(f"LiDAR shape: {lidar.shape}")  # LiDAR 数据 (1, 349, 1905)
print(f"Train truth non-zero: {train_truth.count_nonzero()}")  # 训练集非零样本数
print(f"Test truth non-zero: {test_truth.count_nonzero()}")    # 测试集非零样本数
print(f"Label dictionary: {info['label_dict']}")
# Out:
# <tifffile.TiffPage 0 @2949772> parsing GDAL_NODATA tag raised ValueError('-3.4028234663852886e+38 is not castable to float32')
# CASI shape: (144, 349, 1905)
# LiDAR shape: (1, 349, 1905)
# Train truth non-zero: 2832
# Test truth non-zero: 12197
# Label dictionary: {1: 'Healthy grass', 2: 'Stressed grass', 3: 'Synthetic grass', 4: 'Trees', 5: 'Soil', 6: 'Water', 7: 'Residential', 8: 'Commercial', 9: 'Road', 10: 'Highway', 11: 'Railway', 12: 'Parking Lot 1', 13: 'Parking Lot 2', 14: 'Tennis Court', 15: 'Running Track'}

# %%
# 统计 train_truth 中的类别数量（非零值的唯一值数量）
num_classes = len(set(train_truth.data))
num_classes
# Out:
# 15

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![e40283efa3ff60b604f7319d014c2b39.png](attachment:e40283efa3ff60b604f7319d014c2b39.png)

# %% [markdown]
# 训练集是 2832个 样本 对应的变量是 train_truth ， pca_data 是降维结果

# %% [markdown]
# 沃日，怎么是训练集以及测试样本都做训练？？？

# %% [markdown]
# 这里 之前使用 train_truth 作为训练集 大概最后 oa 有0.38 ，现在按照论文使用全部  0.7142

# %% [markdown]
# 现在是微调分类头的所有层

# %%
from scipy.sparse import coo_matrix

def merge_train_test(train_truth, test_truth, shape):
    """
    合并训练集和测试集稀疏矩阵为一个新的训练集矩阵。
    
    参数:
        train_truth: coo_matrix, 原始训练集稀疏矩阵
        test_truth: coo_matrix, 原始测试集稀疏矩阵
        shape: tuple, 数据的形状 (height, width)
        
    返回:
        merged_truth: coo_matrix, 合并后的训练集稀疏矩阵
    """
    # 合并行、列和数据
    merged_rows = np.concatenate([train_truth.row, test_truth.row])
    merged_cols = np.concatenate([train_truth.col, test_truth.col])
    merged_data = np.concatenate([train_truth.data, test_truth.data])
    
    # 创建新的稀疏矩阵
    merged_truth = coo_matrix((merged_data, (merged_rows, merged_cols)), shape=shape)
    return merged_truth

# 合并训练集和测试集为新的训练集
merged_train_truth = merge_train_test(train_truth, test_truth, (349, 1905))
merged_train_truth
# Out:
# <349x1905 sparse matrix of type '<class 'numpy.int32'>'
# 	with 15029 stored elements in COOrdinate format>

# %%
from sklearn.decomposition import PCA
import numpy as np

def apply_pca_train_only(hsi_data, train_truth, num_components=40):
    """
    使用训练区域的光谱数据训练 PCA 模型，并应用到整个数据集。
    
    参数:
        hsi_data: numpy.ndarray, 高光谱图像数据, 形状为 [C, H, W]
        train_truth: coo_array, 训练区域的稀疏矩阵，表示训练样本的位置
        num_components: int, 保留的主成分数量
        
    返回:
        pca_data: numpy.ndarray, PCA 降维后的数据，形状为 [num_components, H, W]
        explained_variance_ratio: PCA 的累计解释方差比
    """
    c, h, w = hsi_data.shape  # 高光谱数据的形状
    rows, cols = train_truth.row, train_truth.col  # 提取训练区域的行列索引
    
    # 提取训练区域的光谱数据 [num_samples, num_channels]
    train_spectra = hsi_data[:, rows, cols].T  # 转置为 [num_samples, num_channels]
    
    # 在训练区域数据上拟合 PCA
    pca = PCA(n_components=num_components)
    pca.fit(train_spectra)  # 仅在训练区域数据上训练 PCA
    
    # 转换整个数据集 [C, H, W] -> [H×W, C]
    reshaped_data = hsi_data.reshape(c, -1).T  # [H×W, C]
    reduced_data = pca.transform(reshaped_data)  # 降维 [H×W, num_components]
    
    # 恢复为原始图像的形状 [num_components, H, W]
    pca_data = reduced_data.T.reshape(num_components, h, w)  # [num_components, H, W]
    
    return pca_data, pca.explained_variance_ratio_

# 应用 PCA 降维
pca_data, explained_variance_ratio = apply_pca_train_only(casi, merged_train_truth, num_components=40)

print(f"PCA 降维后的数据形状: {pca_data.shape}")  # (40, 349, 1905)
print(f"PCA 累计解释方差比: {np.sum(explained_variance_ratio):.4f}")  

# 获取训练区域的光谱数据降维结果
def extract_pca_train_samples(pca_data, merged_train_truth):
    rows, cols = merged_train_truth.row, merged_train_truth.col  # 提取训练样本位置
    train_samples_pca = pca_data[:, rows, cols].T  # 提取训练样本并转置
    return train_samples_pca

# 提取降维后的训练集样本
train_samples_pca = extract_pca_train_samples(pca_data, merged_train_truth)

# 输出训练集样本数量和降维后形状
print(f"降维后训练集样本数量: {train_samples_pca.shape[0]}")  # 样本数量
print(f"降维后训练集样本形状: {train_samples_pca.shape}")    # 样本形状
# Out:
# PCA 降维后的数据形状: (40, 349, 1905)
# PCA 累计解释方差比: 1.0000
# 降维后训练集样本数量: 15029
# 降维后训练集样本形状: (15029, 40)

# %%
import torch
def split_cube(hsi_cube):
    """
    将高光谱立方块沿通道维度均匀切分。
    参数:
        hsi_cube: torch.Tensor, 形状为 [H, W, C]
    返回:
        hsi_cube_a, hsi_cube_b: 两个子立方块
    """
    _, _, c = hsi_cube.shape
    c1 = c // 2  # 每个子块保留一半的通道
    return hsi_cube[:, :, :c1], hsi_cube[:, :, c1:]

# 提取 11x11 的立方块
s = 11  # 立方块的宽和高
patch_size = (s, s)

def extract_cube(data, x, y, size):
    """
    从高光谱图像中提取一个立方块，并在边缘不足时进行填充。
    参数:
        data: 高光谱数据, 形状为 [C, H, W]
        x, y: 中心像素的坐标
        size: 立方块的大小 (s, s)
    返回:
        cube: 提取的立方块, 形状为 [C, s, s]
    """
    c, h, w = data.shape
    half_size = size[0] // 2
    x_min = max(0, x - half_size)
    x_max = min(h, x + half_size + 1)
    y_min = max(0, y - half_size)
    y_max = min(w, y + half_size + 1)
    
    cube = data[:, x_min:x_max, y_min:y_max]

    # 进行对称填充，确保形状为 (C, s, s)
    pad_width = [
        (0, 0),  # 不填充通道维度
        (max(0, half_size - x), max(0, x + half_size + 1 - h)),  # 高度填充
        (max(0, half_size - y), max(0, y + half_size + 1 - w)),  # 宽度填充
    ]
    cube = np.pad(cube, pad_width, mode="reflect")
    return cube

# 提取某像素点周围的立方块
x, y = 100, 100  # 中心像素位置
cube = extract_cube(pca_data, x, y, patch_size)
print("提取的立方块形状:", cube.shape)  # (40, 11, 11)
# 切分通道
cube_tensor = torch.tensor(cube).permute(1, 2, 0)  # 转换为 [H, W, C]
cube_a, cube_b = split_cube(cube_tensor)

print("子立方块 A 形状:", cube_a.shape)  # (11, 11, 20)
print("子立方块 B 形状:", cube_b.shape)  # (11, 11, 20)
# Out:
# 提取的立方块形状: (40, 11, 11)
# 子立方块 A 形状: torch.Size([11, 11, 20])
# 子立方块 B 形状: torch.Size([11, 11, 20])

# %% [markdown]
# 存在的问题：
#
# 将 cube_a 和 cube_b 作为正样本对，而将同一批次中的其他样本全部视为负样本。
#
# 略了在全局语义空间中样本之间可能存在的类别关联。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 如上图， 这是这篇文章清晰的描述， 一个批次只有一对正样本

# %%
print(torch.cuda.is_available())  # 如果为 False，CUDA 不可用
print(torch.cuda.current_device())  # 当前设备编号
print(torch.cuda.get_device_name(0))  # 查看设备名称
# Out:
# True
# 0
# NVIDIA GeForce RTX 3050 Laptop GPU

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import torch.nn as nn
import torch.nn.functional as F

class FeatureExtractor(nn.Module):
    def __init__(self, input_channels=20):
        """
        特征提取网络。
        参数:
            input_channels: 输入的通道数，例如 20。
        """
        super(FeatureExtractor, self).__init__()
        self.conv1 = nn.Conv2d(input_channels, 32, kernel_size=3, padding=1)  # 第一层卷积
        self.bn1 = nn.BatchNorm2d(32)
        
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)  # 第二层卷积
        self.bn2 = nn.BatchNorm2d(64)
        
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)  # 第三层卷积
        self.bn3 = nn.BatchNorm2d(128)
        
        self.pool = nn.MaxPool2d(2, 2)  # 最大池化层
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.pool(self.relu(self.bn1(self.conv1(x))))  # 卷积 + 批归一化 + 激活 + 池化
        x = self.pool(self.relu(self.bn2(self.conv2(x))))
        x = self.pool(self.relu(self.bn3(self.conv3(x))))
        return x.view(x.size(0), -1)  # 展平特征

# %% [markdown]
# 将子立方块
# 𝑋
# 𝑖
# 𝑎
#   和
# 𝑋
# 𝑖
# 𝑏
# 输入特征提取网络，并输出高维特征

# %%
print(cube_a.dtype, cube_a.device)
print(cube_b.dtype, cube_b.device)
# Out:
# torch.float64 cpu
# torch.float64 cpu

# %%
# 初始化特征提取网络
feature_extractor = FeatureExtractor(input_channels=20).cuda()

# 输入子立方块
cube_a = cube_a.permute(2, 0, 1).unsqueeze(0).float().cuda()  # 转换为 [batch_size, channels, height, width]
cube_b = cube_b.permute(2, 0, 1).unsqueeze(0).float().cuda()

# 提取特征
features_a = feature_extractor(cube_a)  # 子块 A 的特征
features_b = feature_extractor(cube_b)  # 子块 B 的特征

print(f"Features A Shape: {features_a.shape}")  # 输出特征形状，例如 [batch_size, feature_dim]
print(f"Features B Shape: {features_b.shape}")
# Out:
# Features A Shape: torch.Size([1, 128])
# Features B Shape: torch.Size([1, 128])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class ProjectionHead(nn.Module):
    def __init__(self, input_dim=128, output_dim=8):
        """
        特征投影模块。
        参数:
            input_dim: 输入特征的维度，例如 128。
            output_dim: 投影后的维度，例如 8。
        """
        super(ProjectionHead, self).__init__()
        self.fc = nn.Linear(input_dim, output_dim)

    def forward(self, x):
        return F.normalize(self.fc(x), dim=1)  # 投影后的特征归一化


def contrastive_loss(features_a, features_b, temperature=1.0):
    """
    计算对比损失。
    参数:
        features_a, features_b: 投影后的特征，形状为 [batch_size, projection_dim]
        temperature: 温度系数
    返回:
        loss: 对比损失值
    """
    batch_size = features_a.size(0)
    features = torch.cat([features_a, features_b], dim=0)  # 拼接特征
    sim_matrix = F.cosine_similarity(features.unsqueeze(1), features.unsqueeze(0), dim=2)  # 计算相似度
    sim_matrix = sim_matrix / temperature

    # 构造标签
    labels = torch.arange(batch_size, device=features_a.device)
    labels = torch.cat([labels, labels], dim=0)

    # 使用交叉熵损失
    loss = F.cross_entropy(sim_matrix, labels)
    return loss

# %%
# 初始化网络
projection_head = ProjectionHead(input_dim=128, output_dim=8).cuda()

# 投影特征
proj_a = projection_head(features_a)  # 子块 A 的投影特征
proj_b = projection_head(features_b)  # 子块 B 的投影特征

# 计算对比损失
temperature = 1.0
loss = contrastive_loss(proj_a, proj_b, temperature)

print(f"Contrastive Loss: {loss.item()}")  # 打印损失值
# Out:
# Contrastive Loss: 0.6933977007865906

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt

# 自定义数据集类
class HyperspectralDataset(Dataset):
    def __init__(self, pca_data, patch_size=11, num_samples=1000):
        self.data = pca_data  # PCA 降维后的高光谱数据
        self.patch_size = patch_size
        self.num_samples = num_samples
        self.h, self.w = pca_data.shape[1], pca_data.shape[2]

    def __len__(self):
        return self.num_samples

    def __getitem__(self, idx):
        x = torch.randint(self.patch_size // 2, self.h - self.patch_size // 2, (1,)).item()
        y = torch.randint(self.patch_size // 2, self.w - self.patch_size // 2, (1,)).item()
        
        cube = extract_cube(self.data, x, y, (self.patch_size, self.patch_size))
        cube_tensor = torch.tensor(cube).permute(1, 2, 0)
        
        cube_a, cube_b = split_cube(cube_tensor)
        cube_a = cube_a.permute(2, 0, 1)
        cube_b = cube_b.permute(2, 0, 1)
        
        return cube_a, cube_b

# 初始化数据集和数据加载器
pca_data_tensor = torch.tensor(pca_data).float()
dataset = HyperspectralDataset(pca_data_tensor)
dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

# 初始化网络和优化器
feature_extractor = FeatureExtractor(input_channels=20).cuda()
projection_head = ProjectionHead(input_dim=128, output_dim=8).cuda()
optimizer = optim.Adam(list(feature_extractor.parameters()) + list(projection_head.parameters()), lr=1e-4)

# 创建保存模型的文件夹
os.makedirs('./pth', exist_ok=True)

# 初始化变量用于保存损失值
loss_values = []

# 训练循环
num_epochs = 100
temperature = 1.0

for epoch in range(num_epochs):
    feature_extractor.train()
    projection_head.train()
    
    epoch_loss = 0
    for batch in dataloader:
        cube_a, cube_b = batch
        cube_a, cube_b = cube_a.cuda(), cube_b.cuda()
        
        features_a = feature_extractor(cube_a)
        features_b = feature_extractor(cube_b)
        
        proj_a = projection_head(features_a)
        proj_b = projection_head(features_b)
        
        loss = contrastive_loss(proj_a, proj_b, temperature)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
    
    avg_loss = epoch_loss / len(dataloader)
    loss_values.append(avg_loss)
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}")

# 仅保存最后一个模型
model_path = 'pth/original.pth'
torch.save(
    {
        'epoch': num_epochs,
        'feature_extractor_state_dict': feature_extractor.state_dict(),
        'projection_head_state_dict': projection_head.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': loss_values[-1],
    },
    model_path
)
print(f"Final model saved to {model_path}")

# 绘制损失值曲线
plt.figure(figsize=(8, 6))
plt.plot(range(1, num_epochs + 1), loss_values, marker='o', label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Curve')
plt.legend()
plt.grid()
plt.savefig('pth/loss_curve.png')
plt.show()
# Out:
# Epoch [1/100], Loss: 4.5033
# Epoch [2/100], Loss: 4.3404
# Epoch [3/100], Loss: 4.2824
# Epoch [4/100], Loss: 4.2618
# Epoch [5/100], Loss: 4.2323
# Epoch [6/100], Loss: 4.2445
# Epoch [7/100], Loss: 4.2274
# Epoch [8/100], Loss: 4.1838
# Epoch [9/100], Loss: 4.1842
# Epoch [10/100], Loss: 4.1866
# Epoch [11/100], Loss: 4.1713
# Epoch [12/100], Loss: 4.1580
# Epoch [13/100], Loss: 4.1464
# Epoch [14/100], Loss: 4.1393
# Epoch [15/100], Loss: 4.1321
# Epoch [16/100], Loss: 4.1167
# Epoch [17/100], Loss: 4.1302
# Epoch [18/100], Loss: 4.1186
# Epoch [19/100], Loss: 4.1025
# Epoch [20/100], Loss: 4.1214
# Epoch [21/100], Loss: 4.0997
# Epoch [22/100], Loss: 4.0833
# Epoch [23/100], Loss: 4.1138
# Epoch [24/100], Loss: 4.1054
# Epoch [25/100], Loss: 4.0961
# Epoch [26/100], Loss: 4.0823
# Epoch [27/100], Loss: 4.0782
# Epoch [28/100], Loss: 4.1065
# Epoch [29/100], Loss: 4.0840
# Epoch [30/100], Loss: 4.0755
# Epoch [31/100], Loss: 4.0923
# Epoch [32/100], Loss: 4.0626
# Epoch [33/100], Loss: 4.0677
# Epoch [34/100], Loss: 4.0628
# Epoch [35/100], Loss: 4.0684
# Epoch [36/100], Loss: 4.0670
# Epoch [37/100], Loss: 4.0635
# Epoch [38/100], Loss: 4.0585
# Epoch [39/100], Loss: 4.0519
# Epoch [40/100], Loss: 4.0478
# Epoch [41/100], Loss: 4.0493
# Epoch [42/100], Loss: 4.0519
# Epoch [43/100], Loss: 4.0572
# Epoch [44/100], Loss: 4.0443
# Epoch [45/100], Loss: 4.0560
# Epoch [46/100], Loss: 4.0632
# Epoch [47/100], Loss: 4.0588
# Epoch [48/100], Loss: 4.0561
# Epoch [49/100], Loss: 4.0377
# Epoch [50/100], Loss: 4.0344
# Epoch [51/100], Loss: 4.0451
# Epoch [52/100], Loss: 4.0364
# Epoch [53/100], Loss: 4.0274
# Epoch [54/100], Loss: 4.0355
# Epoch [55/100], Loss: 4.0351
# Epoch [56/100], Loss: 4.0371
# Epoch [57/100], Loss: 4.0284
# Epoch [58/100], Loss: 4.0349
# Epoch [59/100], Loss: 4.0314
# Epoch [60/100], Loss: 4.0242
# Epoch [61/100], Loss: 4.0239
# Epoch [62/100], Loss: 4.0312
# Epoch [63/100], Loss: 4.0278
# Epoch [64/100], Loss: 4.0348
# Epoch [65/100], Loss: 4.0247
# Epoch [66/100], Loss: 4.0215
# Epoch [67/100], Loss: 4.0304
# Epoch [68/100], Loss: 4.0258
# Epoch [69/100], Loss: 4.0222
# Epoch [70/100], Loss: 4.0240
# Epoch [71/100], Loss: 4.0291
# Epoch [72/100], Loss: 4.0282
# Epoch [73/100], Loss: 4.0163
# Epoch [74/100], Loss: 4.0124
# Epoch [75/100], Loss: 4.0126
# Epoch [76/100], Loss: 4.0108
# Epoch [77/100], Loss: 4.0136
# Epoch [78/100], Loss: 4.0148
# Epoch [79/100], Loss: 4.0159
# Epoch [80/100], Loss: 4.0077
# Epoch [81/100], Loss: 4.0062
# Epoch [82/100], Loss: 4.0106
# Epoch [83/100], Loss: 4.0184
# Epoch [84/100], Loss: 4.0158
# Epoch [85/100], Loss: 4.0086
# Epoch [86/100], Loss: 4.0132
# Epoch [87/100], Loss: 4.0196
# Epoch [88/100], Loss: 4.0142
# Epoch [89/100], Loss: 4.0173
# Epoch [90/100], Loss: 4.0083
# Epoch [91/100], Loss: 4.0111
# Epoch [92/100], Loss: 4.0008
# Epoch [93/100], Loss: 3.9987
# Epoch [94/100], Loss: 4.0040
# Epoch [95/100], Loss: 4.0054
# Epoch [96/100], Loss: 4.0041
# Epoch [97/100], Loss: 4.0005
# Epoch [98/100], Loss: 4.0029
# Epoch [99/100], Loss: 4.0002
# Epoch [100/100], Loss: 3.9971
# Final model saved to pth/original.pth

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt


# 自定义数据集类
class HyperspectralDataset(Dataset):
    def __init__(self, pca_data, patch_size=11, num_samples=1000):
        self.data = pca_data  # PCA 降维后的高光谱数据
        self.patch_size = patch_size
        self.num_samples = num_samples
        self.h, self.w = pca_data.shape[1], pca_data.shape[2]

    def __len__(self):
        return self.num_samples

    def __getitem__(self, idx):
        # 随机采样一个中心点
        x = torch.randint(self.patch_size // 2, self.h - self.patch_size // 2, (1,)).item()
        y = torch.randint(self.patch_size // 2, self.w - self.patch_size // 2, (1,)).item()
        
        # 提取立方块
        cube = extract_cube(self.data, x, y, (self.patch_size, self.patch_size))
        cube_tensor = torch.tensor(cube).permute(1, 2, 0)  # 转换为 [H, W, C]
        
        # 分割为子块
        cube_a, cube_b = split_cube(cube_tensor)
        cube_a = cube_a.permute(2, 0, 1)  # 转换为 [C, H, W]
        cube_b = cube_b.permute(2, 0, 1)  # 转换为 [C, H, W]
        
        return cube_a, cube_b

# 初始化数据集和数据加载器
pca_data_tensor = torch.tensor(pca_data).float()
dataset = HyperspectralDataset(pca_data_tensor)
dataloader = DataLoader(dataset, batch_size=256, shuffle=True)

# 初始化网络和优化器
feature_extractor = FeatureExtractor(input_channels=20).cuda()
projection_head = ProjectionHead(input_dim=128, output_dim=8).cuda()
optimizer = optim.Adam(list(feature_extractor.parameters()) + list(projection_head.parameters()), lr=1e-3)

# 定义学习率预热调度器和余弦退火调度器
warmup_epochs = 20  # 预热的 epoch 数
total_epochs = 160  # 总的训练 epoch 数
base_lr = 1e-5      # 预热的起始学习率
max_lr = 3e-4       # 最大学习率
min_lr = 1e-4       # 最小学习率

# Warm-up 调度器：前 warmup_epochs 将学习率从 base_lr 线性增加到 max_lr
def warmup_lambda(epoch):
    if epoch < warmup_epochs:
        return (epoch + 1) / warmup_epochs  # 线性增长
    else:
        return 1

warmup_scheduler = optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=warmup_lambda)

# Cosine Annealing 调度器：从第 warmup_epochs 开始余弦退火
cosine_scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=(total_epochs - warmup_epochs), eta_min=min_lr)

# 创建保存模型的文件夹
os.makedirs('./pth', exist_ok=True)

# 初始化变量用于保存损失值
loss_values = []

# 训练循环
num_epochs = total_epochs
temperature = 1

for epoch in range(num_epochs):
    feature_extractor.train()
    projection_head.train()
    
    epoch_loss = 0
    for batch in dataloader:
        cube_a, cube_b = batch  # 获取子立方块
        cube_a, cube_b = cube_a.cuda(), cube_b.cuda()
        
        # 提取特征
        features_a = feature_extractor(cube_a)
        features_b = feature_extractor(cube_b)
        
        # 投影到嵌入空间
        proj_a = projection_head(features_a)
        proj_b = projection_head(features_b)
        
        # 计算对比损失
        loss = contrastive_loss(proj_a, proj_b, temperature)
        
        # 反向传播和优化
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
    
    # 更新学习率：先使用 Warm-up，后使用 CosineAnnealing
    if epoch < warmup_epochs:
        warmup_scheduler.step()
    else:
        cosine_scheduler.step()
    
    # 平均损失
    avg_loss = epoch_loss / len(dataloader)
    loss_values.append(avg_loss)  # 保存当前 epoch 的平均损失
    
    # 每 100 个 epoch 保存一次模型
    if (epoch + 1) % 40 == 0:
        torch.save(
            {
                'epoch': epoch + 1,
                'feature_extractor_state_dict': feature_extractor.state_dict(),
                'projection_head_state_dict': projection_head.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': avg_loss,
            },
            f'pth/model_epoch_{epoch + 1}.pth'
        )
        print(f"Model saved to pth/model_epoch_{epoch + 1}.pth")
    
    # 输出当前 epoch 的损失和学习率
    current_lr = optimizer.param_groups[0]['lr']
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, LR: {current_lr:.6f}")

# 绘制损失值曲线
plt.figure(figsize=(8, 6))
plt.plot(range(1, num_epochs + 1), loss_values, marker='o', label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Curve')
plt.legend()
plt.grid()
plt.savefig('pth/loss_curve.png')  # 保存损失曲线图
plt.show()
# Out:
# Epoch [1/160], Loss: 6.0143, LR: 0.000100
# Epoch [2/160], Loss: 5.8968, LR: 0.000150
# Epoch [3/160], Loss: 5.7930, LR: 0.000200
# Epoch [4/160], Loss: 5.7271, LR: 0.000250
# Epoch [5/160], Loss: 5.7342, LR: 0.000300
# Epoch [6/160], Loss: 5.6754, LR: 0.000350
# Epoch [7/160], Loss: 5.6532, LR: 0.000400
# Epoch [8/160], Loss: 5.6373, LR: 0.000450
# Epoch [9/160], Loss: 5.6154, LR: 0.000500
# Epoch [10/160], Loss: 5.6176, LR: 0.000550
# Epoch [11/160], Loss: 5.5958, LR: 0.000600
# Epoch [12/160], Loss: 5.5834, LR: 0.000650
# Epoch [13/160], Loss: 5.5770, LR: 0.000700
# Epoch [14/160], Loss: 5.5639, LR: 0.000750
# Epoch [15/160], Loss: 5.5400, LR: 0.000800
# Epoch [16/160], Loss: 5.5234, LR: 0.000850
# Epoch [17/160], Loss: 5.5237, LR: 0.000900
# Epoch [18/160], Loss: 5.5188, LR: 0.000950
# Epoch [19/160], Loss: 5.4975, LR: 0.001000
# Epoch [20/160], Loss: 5.5329, LR: 0.001000
# Epoch [21/160], Loss: 5.5183, LR: 0.001000
# Epoch [22/160], Loss: 5.4900, LR: 0.001000
# Epoch [23/160], Loss: 5.4711, LR: 0.000999
# Epoch [24/160], Loss: 5.4626, LR: 0.000998
# Epoch [25/160], Loss: 5.4585, LR: 0.000997
# Epoch [26/160], Loss: 5.4505, LR: 0.000996
# Epoch [27/160], Loss: 5.4390, LR: 0.000994
# Epoch [28/160], Loss: 5.4500, LR: 0.000993
# Epoch [29/160], Loss: 5.4303, LR: 0.000991
# Epoch [30/160], Loss: 5.4443, LR: 0.000989
# Epoch [31/160], Loss: 5.4327, LR: 0.000986
# Epoch [32/160], Loss: 5.4708, LR: 0.000984
# Epoch [33/160], Loss: 5.4351, LR: 0.000981
# Epoch [34/160], Loss: 5.4116, LR: 0.000978
# Epoch [35/160], Loss: 5.4396, LR: 0.000975
# Epoch [36/160], Loss: 5.4178, LR: 0.000971
# Epoch [37/160], Loss: 5.4135, LR: 0.000968
# Epoch [38/160], Loss: 5.4023, LR: 0.000964
# Epoch [39/160], Loss: 5.4151, LR: 0.000960
# Model saved to pth/model_epoch_40.pth
# Epoch [40/160], Loss: 5.3995, LR: 0.000955
# Epoch [41/160], Loss: 5.3898, LR: 0.000951
# Epoch [42/160], Loss: 5.3908, LR: 0.000946
# Epoch [43/160], Loss: 5.3942, LR: 0.000941
# Epoch [44/160], Loss: 5.4068, LR: 0.000936
# Epoch [45/160], Loss: 5.3963, LR: 0.000931
# Epoch [46/160], Loss: 5.3980, LR: 0.000926
# Epoch [47/160], Loss: 5.3894, LR: 0.000920
# Epoch [48/160], Loss: 5.4103, LR: 0.000914
# Epoch [49/160], Loss: 5.4005, LR: 0.000908
# Epoch [50/160], Loss: 5.3926, LR: 0.000902
# Epoch [51/160], Loss: 5.3907, LR: 0.000895
# Epoch [52/160], Loss: 5.3906, LR: 0.000889
# Epoch [53/160], Loss: 5.3924, LR: 0.000882
# Epoch [54/160], Loss: 5.3778, LR: 0.000875
# Epoch [55/160], Loss: 5.3787, LR: 0.000868
# Epoch [56/160], Loss: 5.3795, LR: 0.000861
# Epoch [57/160], Loss: 5.3709, LR: 0.000854
# Epoch [58/160], Loss: 5.3792, LR: 0.000846
# Epoch [59/160], Loss: 5.3746, LR: 0.000838
# Epoch [60/160], Loss: 5.3749, LR: 0.000831
# Epoch [61/160], Loss: 5.3866, LR: 0.000823
# Epoch [62/160], Loss: 5.3804, LR: 0.000815
# Epoch [63/160], Loss: 5.3867, LR: 0.000806
# Epoch [64/160], Loss: 5.3734, LR: 0.000798
# Epoch [65/160], Loss: 5.3711, LR: 0.000789
# Epoch [66/160], Loss: 5.3717, LR: 0.000781
# Epoch [67/160], Loss: 5.3688, LR: 0.000772
# Epoch [68/160], Loss: 5.3736, LR: 0.000763
# Epoch [69/160], Loss: 5.3624, LR: 0.000754
# Epoch [70/160], Loss: 5.3669, LR: 0.000745
# Epoch [71/160], Loss: 5.3619, LR: 0.000736
# Epoch [72/160], Loss: 5.3682, LR: 0.000727
# Epoch [73/160], Loss: 5.3620, LR: 0.000718
# Epoch [74/160], Loss: 5.3668, LR: 0.000708
# Epoch [75/160], Loss: 5.3802, LR: 0.000699
# Epoch [76/160], Loss: 5.3685, LR: 0.000689
# Epoch [77/160], Loss: 5.3665, LR: 0.000679
# Epoch [78/160], Loss: 5.3657, LR: 0.000670
# Epoch [79/160], Loss: 5.3686, LR: 0.000660
# Model saved to pth/model_epoch_80.pth
# Epoch [80/160], Loss: 5.3601, LR: 0.000650
# Epoch [81/160], Loss: 5.3593, LR: 0.000640
# Epoch [82/160], Loss: 5.3639, LR: 0.000630
# Epoch [83/160], Loss: 5.3668, LR: 0.000620
# Epoch [84/160], Loss: 5.3564, LR: 0.000610
# Epoch [85/160], Loss: 5.3642, LR: 0.000600
# Epoch [86/160], Loss: 5.3577, LR: 0.000590
# Epoch [87/160], Loss: 5.3559, LR: 0.000580
# Epoch [88/160], Loss: 5.3556, LR: 0.000570
# Epoch [89/160], Loss: 5.3580, LR: 0.000560
# Epoch [90/160], Loss: 5.3526, LR: 0.000550
# Epoch [91/160], Loss: 5.3606, LR: 0.000540
# Epoch [92/160], Loss: 5.3564, LR: 0.000530
# Epoch [93/160], Loss: 5.3545, LR: 0.000520
# Epoch [94/160], Loss: 5.3544, LR: 0.000510
# Epoch [95/160], Loss: 5.3526, LR: 0.000500
# Epoch [96/160], Loss: 5.3547, LR: 0.000490
# Epoch [97/160], Loss: 5.3544, LR: 0.000480
# Epoch [98/160], Loss: 5.3530, LR: 0.000470
# Epoch [99/160], Loss: 5.3465, LR: 0.000460
# Epoch [100/160], Loss: 5.3497, LR: 0.000450
# Epoch [101/160], Loss: 5.3479, LR: 0.000440
# Epoch [102/160], Loss: 5.3531, LR: 0.000430
# Epoch [103/160], Loss: 5.3481, LR: 0.000421
# Epoch [104/160], Loss: 5.3486, LR: 0.000411
# Epoch [105/160], Loss: 5.3485, LR: 0.000401
# Epoch [106/160], Loss: 5.3508, LR: 0.000392
# Epoch [107/160], Loss: 5.3482, LR: 0.000382
# Epoch [108/160], Loss: 5.3490, LR: 0.000373
# Epoch [109/160], Loss: 5.3479, LR: 0.000364
# Epoch [110/160], Loss: 5.3512, LR: 0.000355
# Epoch [111/160], Loss: 5.3499, LR: 0.000346
# Epoch [112/160], Loss: 5.3534, LR: 0.000337
# Epoch [113/160], Loss: 5.3511, LR: 0.000328
# Epoch [114/160], Loss: 5.3482, LR: 0.000319
# Epoch [115/160], Loss: 5.3536, LR: 0.000311
# Epoch [116/160], Loss: 5.3442, LR: 0.000302
# Epoch [117/160], Loss: 5.3497, LR: 0.000294
# Epoch [118/160], Loss: 5.3485, LR: 0.000285
# Epoch [119/160], Loss: 5.3493, LR: 0.000277
# Model saved to pth/model_epoch_120.pth
# Epoch [120/160], Loss: 5.3498, LR: 0.000269
# Epoch [121/160], Loss: 5.3447, LR: 0.000262
# Epoch [122/160], Loss: 5.3473, LR: 0.000254
# Epoch [123/160], Loss: 5.3489, LR: 0.000246
# Epoch [124/160], Loss: 5.3481, LR: 0.000239
# Epoch [125/160], Loss: 5.3453, LR: 0.000232
# Epoch [126/160], Loss: 5.3486, LR: 0.000225
# Epoch [127/160], Loss: 5.3451, LR: 0.000218
# Epoch [128/160], Loss: 5.3470, LR: 0.000211
# Epoch [129/160], Loss: 5.3472, LR: 0.000205
# Epoch [130/160], Loss: 5.3464, LR: 0.000198
# Epoch [131/160], Loss: 5.3450, LR: 0.000192
# Epoch [132/160], Loss: 5.3465, LR: 0.000186
# Epoch [133/160], Loss: 5.3450, LR: 0.000180
# Epoch [134/160], Loss: 5.3422, LR: 0.000174
# Epoch [135/160], Loss: 5.3464, LR: 0.000169
# Epoch [136/160], Loss: 5.3460, LR: 0.000164
# Epoch [137/160], Loss: 5.3441, LR: 0.000159
# Epoch [138/160], Loss: 5.3469, LR: 0.000154
# Epoch [139/160], Loss: 5.3437, LR: 0.000149
# Epoch [140/160], Loss: 5.3432, LR: 0.000145
# Epoch [141/160], Loss: 5.3466, LR: 0.000140
# Epoch [142/160], Loss: 5.3436, LR: 0.000136
# Epoch [143/160], Loss: 5.3429, LR: 0.000132
# Epoch [144/160], Loss: 5.3418, LR: 0.000129
# Epoch [145/160], Loss: 5.3442, LR: 0.000125
# Epoch [146/160], Loss: 5.3426, LR: 0.000122
# Epoch [147/160], Loss: 5.3428, LR: 0.000119
# Epoch [148/160], Loss: 5.3456, LR: 0.000116
# Epoch [149/160], Loss: 5.3420, LR: 0.000114
# Epoch [150/160], Loss: 5.3428, LR: 0.000111
# Epoch [151/160], Loss: 5.3465, LR: 0.000109
# Epoch [152/160], Loss: 5.3478, LR: 0.000107
# Epoch [153/160], Loss: 5.3415, LR: 0.000106
# Epoch [154/160], Loss: 5.3419, LR: 0.000104
# Epoch [155/160], Loss: 5.3400, LR: 0.000103
# Epoch [156/160], Loss: 5.3444, LR: 0.000102
# Epoch [157/160], Loss: 5.3455, LR: 0.000101
# Epoch [158/160], Loss: 5.3479, LR: 0.000100
# Epoch [159/160], Loss: 5.3476, LR: 0.000100
# Model saved to pth/model_epoch_160.pth
# Epoch [160/160], Loss: 5.3389, LR: 0.000100

# %%
# 定义测试数据集和加载器
test_dataset = HyperspectralDataset(pca_data_tensor, patch_size=11, num_samples=500)  # 500 作为测试样本数量
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# 提取测试数据的特征
features, labels = [], []
feature_extractor.eval()  # 固定特征提取器
with torch.no_grad():
    for batch in test_loader:
        cube_a, cube_b = batch  # 获取子块
        cube_a, cube_b = cube_a.cuda(), cube_b.cuda()

        # 提取特征（这里只用 cube_a，也可以用 cube_b 或两者拼接）
        batch_features = feature_extractor(cube_a)
        features.append(batch_features.cpu())
        # 如果数据集有标签，可以添加 labels，否则假设没有标签
        labels.append(torch.arange(batch_features.size(0)))  # 假设 batch_size 个类别

# 将所有特征和标签合并
features = torch.cat(features, dim=0)  # [num_samples, feature_dim]
labels = torch.cat(labels, dim=0)  # [num_samples]

# 使用 t-SNE 可视化特征分布
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
reduced_features = tsne.fit_transform(features.numpy())

# 绘制 t-SNE 图
plt.figure(figsize=(10, 10))
for label in torch.unique(labels):
    idx = labels == label
    plt.scatter(reduced_features[idx, 0], reduced_features[idx, 1], label=f"Class {label.item()}")
plt.legend()
plt.title("t-SNE Visualization of Features")
plt.show()

# %% [markdown]
# 这个上面的图显示这对比学习的存在问题

# %% [markdown]
#  加载标注数据，假设 train_labels 和 test_labels 已经包含标注数据
#
#  train_labels 和 test_labels 格式为 [(x, y, label), ...]

# %%
def extract_labels(truth, label_dict):
    """
    从稀疏矩阵中提取标注数据，格式为 [(row, col, label), ...]。
    并将标签值映射到 [0, len(label_dict)-1] 的范围。
    """
    rows, cols, labels = truth.row, truth.col, truth.data
    # 创建从标签值到索引的映射
    label_to_index = {label_value: idx for idx, label_value in enumerate(label_dict.keys())}
    mapped_labels = [label_to_index[label] for label in labels if label in label_to_index]
    return [(row, col, label) for row, col, label in zip(rows, cols, mapped_labels)]


test_labels = extract_labels(test_truth, info['label_dict'])


print(f"Number of testing samples: {len(test_labels)}")
# Out:
# Number of testing samples: 12197

# %%
print(test_labels[:5])
# Out:
# [(285, 3, 6), (286, 3, 6), (284, 4, 6), (285, 4, 6), (286, 4, 6)]

# %%
from collections import Counter


test_label_counts = Counter([label for _, _, label in test_labels])


print("Testing label distribution:", test_label_counts)
# Out:
# Testing label distribution: Counter({6: 1072, 1: 1064, 8: 1059, 3: 1056, 4: 1056, 10: 1054, 0: 1053, 7: 1053, 11: 1041, 9: 1036, 2: 505, 14: 473, 12: 285, 13: 247, 5: 143})

# %% [markdown]
# 构建分类任务的数据加载器
# 数据加载器需要根据 train_labels 和 test_labels 创建：
#
# 对于每个 (row, col, label) 样本，从降维后的高光谱图像（pca_data）中提取相应的立方块作为输入。
# 标签（label）作为输出。

# %%
from torch.utils.data import Dataset, DataLoader
import random
from collections import defaultdict
import numpy as np
import torch
from sklearn.decomposition import PCA

# 提取立方块函数
def extract_cube(data, x, y, size):
    """
    从高光谱图像中提取一个立方块，并在边缘不足时进行填充。
    参数:
        data: 高光谱数据, 形状为 [C, H, W]
        x, y: 中心像素的坐标
        size: 立方块的大小 (s, s)
    返回:
        cube: 提取的立方块, 形状为 [C, s, s]
    """
    c, h, w = data.shape
    half_size = size[0] // 2
    x_min = max(0, x - half_size)
    x_max = min(h, x + half_size + 1)
    y_min = max(0, y - half_size)
    y_max = min(w, y + half_size + 1)
    
    cube = data[:, x_min:x_max, y_min:y_max]

    # 对称填充，确保形状为 (C, s, s)
    pad_width = [
        (0, 0),  # 不填充通道维度
        (max(0, half_size - x), max(0, x + half_size + 1 - h)),  # 高度填充
        (max(0, half_size - y), max(0, y + half_size + 1 - w)),  # 宽度填充
    ]
    cube = np.pad(cube, pad_width, mode="reflect")
    return cube


# PCA 降维函数
def apply_pca_train_only(hsi_data, train_truth, num_components=20):
    """
    使用训练区域的光谱数据训练 PCA 模型，并应用到整个数据集。
    参数:
        hsi_data: 高光谱数据, 形状为 [C, H, W]
        train_truth: coo_array, 训练区域的稀疏矩阵，表示训练样本的位置
        num_components: 保留的主成分数量
    返回:
        pca_data: 降维后的数据, 形状为 [num_components, H, W]
        explained_variance_ratio: PCA 的累计解释方差比
    """
    c, h, w = hsi_data.shape
    rows, cols = train_truth.row, train_truth.col  # 提取训练区域的行列索引

    # 提取训练区域的光谱数据 [num_samples, num_channels]
    train_spectra = hsi_data[:, rows, cols].T  # 转置为 [num_samples, num_channels]

    # 在训练区域数据上拟合 PCA
    pca = PCA(n_components=num_components)
    pca.fit(train_spectra)  # 仅在训练区域数据上训练 PCA

    # 转换整个数据集
    reshaped_data = hsi_data.reshape(c, -1).T  # [H×W, C]
    reduced_data = pca.transform(reshaped_data)  # 降维 [H×W, num_components]

    # 恢复为原始图像的形状
    pca_data = reduced_data.T.reshape(num_components, h, w)  # [num_components, H, W]
    
    return pca_data, pca.explained_variance_ratio_


# 分类数据集定义
class ClassificationDataset(Dataset):
    def __init__(self, data, labels, patch_size=11):
        """
        构造分类数据集。
        参数:
            data: PCA 降维后的数据 [C, H, W]
            labels: [(row, col, label), ...]，标注的样本
            patch_size: 立方块大小 (patch_size, patch_size)
        """
        self.data = data
        self.labels = labels
        self.patch_size = patch_size

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        x, y, label = self.labels[idx]
        cube = extract_cube(self.data, x, y, (self.patch_size, self.patch_size))  # 提取立方块
        cube_tensor = torch.tensor(cube).float()  # 转换为浮点张量
        return cube_tensor, label


# 候选集生成函数
def create_candidate_dataset(train_labels, num_classes, samples_per_class):
    """
    从训练样本中按每类抽取指定数量的样本，构造候选集。
    参数:
        train_labels: 原始训练样本 [(row, col, label), ...]
        num_classes: 类别数量
        samples_per_class: 每个类别抽取的样本数量
    返回:
        candidate_labels: 候选样本 [(row, col, label), ...]
    """
    class_samples = defaultdict(list)
    for sample in train_labels:
        class_samples[sample[2]].append(sample)

    candidate_labels = []
    for cls in range(num_classes):
        if cls in class_samples:
            samples = class_samples[cls]
            if len(samples) < samples_per_class:
                print(f"Warning: Class {cls} has only {len(samples)} samples, less than {samples_per_class}.")
            candidate_labels.extend(random.sample(samples, min(samples_per_class, len(samples))))
        else:
            print(f"Warning: Class {cls} has no samples in training set.")
    return candidate_labels


# 应用 PCA 并重新构造数据集
ptest_data, explained_variance_ratio = apply_pca_train_only(casi, test_truth, num_components=20)

test_dataset = ClassificationDataset(ptest_data, test_labels, patch_size=11)
candidate_labels = create_candidate_dataset(test_labels, num_classes=len(info['label_dict']), samples_per_class=10)
candidate_dataset = ClassificationDataset(ptest_data, candidate_labels, patch_size=11)

# 定义数据加载器
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
candidate_loader = DataLoader(candidate_dataset, batch_size=64, shuffle=True)

# 打印样本数量信息
print(f"PCA 降维后的数据形状: {ptest_data.shape}")
print(f"Number of candidate samples: {len(candidate_loader.dataset)}")
print(f"Number of testing samples: {len(test_loader.dataset)}")
# Out:
# PCA 降维后的数据形状: (20, 349, 1905)
# Number of candidate samples: 150
# Number of testing samples: 12197

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import torch
print(torch.cuda.is_available())  # True 表示 CUDA 可用
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
# Out:
# True

# %% [markdown]
# 加载对比学习训练的模型权重

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# 定义特征提取器
class FeatureExtractor(nn.Module):
    def __init__(self, input_channels):
        super().__init__()
        self.conv1 = nn.Conv2d(input_channels, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(128)
        self.pool = nn.MaxPool2d(2, 2)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.pool(self.relu(self.bn1(self.conv1(x))))
        x = self.pool(self.relu(self.bn2(self.conv2(x))))
        x = self.pool(self.relu(self.bn3(self.conv3(x))))
        return x.view(x.size(0), -1)  # Flatten to [batch_size, features]

# 加载对比学习的模型权重
#checkpoint_path = "./pth/model_epoch_160.pth"  # 修改为对比学习模型的路径
checkpoint_path = "pth/23_5_batch256_epoch400.pth"
checkpoint = torch.load(checkpoint_path)

# 确保权重文件中包含特征提取器的权重
if 'feature_extractor_state_dict' not in checkpoint:
    raise KeyError("Checkpoint does not contain 'feature_extractor_state_dict'. Please check the file.")

# %% [markdown]
# 冻结特征提取器
#
# 对于分类任务，只需训练分类头，而特征提取器的参数保持冻结状态。

# %% [markdown]
# 初始化分类头
#
# 定义一个简单的全连接层作为分类头。
# 输入维度是特征提取器的输出维度（128），输出维度是类别数量（如 15）。

# %% [markdown]
# 构建数据加载器
#
# 准备 train_loader 和 test_loader，确保训练和测试数据可以被模型读取。

# %% [markdown]
# 训练分类头
#
# 定义损失函数（如交叉熵损失）和优化器（如 Adam）。
# 使用训练数据优化分类头。

# %% [markdown]
# 评估分类任务
#
# 使用测试数据评估分类头的性能（如准确率）。

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 初始化特征提取器（与对比学习阶段一致的输入通道数为 20）
feature_extractor = FeatureExtractor(input_channels=20).cuda()

# 加载所有预训练权重
feature_extractor.load_state_dict(checkpoint['feature_extractor_state_dict'])
print("Loaded pre-trained weights for the entire feature extractor.")

# 检查冻结状态（设置所有层参数为可微调）
for param in feature_extractor.parameters():
    param.requires_grad = True  # 解冻所有参数

# 定义分类头
# 定义分类头
class ClassificationHead(nn.Module):
    def __init__(self, input_dim, num_classes):
        super(ClassificationHead, self).__init__()
        self.fc = nn.Linear(input_dim, num_classes)

    def forward(self, x):
        return self.fc(x)

# 修改输入维度为 128（特征提取器的输出维度）
classification_head = ClassificationHead(input_dim=128, num_classes=15).cuda()


# 定义优化器
optimizer = optim.Adam([
    {"params": feature_extractor.parameters(), "lr": 1e-5},  # 微调特征提取器
    {"params": classification_head.parameters(), "lr": 1e-3},  # 分类头
])

# 定义损失函数
criterion = nn.CrossEntropyLoss()

# 训练分类头和特征提取器
def train_classification_model(feature_extractor, classification_head, train_loader, optimizer, criterion, num_epochs=50):
    feature_extractor.train()  # 微调特征提取器
    classification_head.train()  # 训练分类头

    for epoch in range(num_epochs):
        epoch_loss = 0
        for cubes, labels in train_loader:
            cubes, labels = cubes.cuda(), labels.cuda()

            # 提取特征
            features = feature_extractor(cubes)

            # 分类头进行训练
            outputs = classification_head(features)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss/len(train_loader):.4f}")

# 运行训练函数
train_classification_model(feature_extractor, classification_head, candidate_loader, optimizer, criterion, num_epochs=200)
# Out:
# Loaded pre-trained weights for the entire feature extractor.
# Epoch [1/200], Loss: 2.8834
# Epoch [2/200], Loss: 2.7014
# Epoch [3/200], Loss: 2.5939
# Epoch [4/200], Loss: 2.5169
# Epoch [5/200], Loss: 2.4297
# Epoch [6/200], Loss: 2.3699
# Epoch [7/200], Loss: 2.3009
# Epoch [8/200], Loss: 2.2455
# Epoch [9/200], Loss: 2.1953
# Epoch [10/200], Loss: 2.1572
# Epoch [11/200], Loss: 2.0942
# Epoch [12/200], Loss: 2.0625
# Epoch [13/200], Loss: 1.9927
# Epoch [14/200], Loss: 1.9495
# Epoch [15/200], Loss: 1.9228
# Epoch [16/200], Loss: 1.8604
# Epoch [17/200], Loss: 1.8465
# Epoch [18/200], Loss: 1.8151
# Epoch [19/200], Loss: 1.7284
# Epoch [20/200], Loss: 1.7087
# Epoch [21/200], Loss: 1.7234
# Epoch [22/200], Loss: 1.6778
# Epoch [23/200], Loss: 1.6447
# Epoch [24/200], Loss: 1.5984
# Epoch [25/200], Loss: 1.5345
# Epoch [26/200], Loss: 1.5486
# Epoch [27/200], Loss: 1.4992
# Epoch [28/200], Loss: 1.4790
# Epoch [29/200], Loss: 1.4621
# Epoch [30/200], Loss: 1.4005
# Epoch [31/200], Loss: 1.4231
# Epoch [32/200], Loss: 1.4204
# Epoch [33/200], Loss: 1.4099
# Epoch [34/200], Loss: 1.3553
# Epoch [35/200], Loss: 1.3681
# Epoch [36/200], Loss: 1.3579
# Epoch [37/200], Loss: 1.2767
# Epoch [38/200], Loss: 1.3306
# Epoch [39/200], Loss: 1.2172
# Epoch [40/200], Loss: 1.1975
# Epoch [41/200], Loss: 1.2245
# Epoch [42/200], Loss: 1.2031
# Epoch [43/200], Loss: 1.1933
# Epoch [44/200], Loss: 1.1774
# Epoch [45/200], Loss: 1.0901
# Epoch [46/200], Loss: 1.1351
# Epoch [47/200], Loss: 1.0850
# Epoch [48/200], Loss: 1.0829
# Epoch [49/200], Loss: 1.0710
# Epoch [50/200], Loss: 1.0767
# Epoch [51/200], Loss: 1.0529
# Epoch [52/200], Loss: 1.0291
# Epoch [53/200], Loss: 1.0527
# Epoch [54/200], Loss: 1.0132
# Epoch [55/200], Loss: 1.0077
# Epoch [56/200], Loss: 0.9824
# Epoch [57/200], Loss: 0.9742
# Epoch [58/200], Loss: 0.9619
# Epoch [59/200], Loss: 0.9409
# Epoch [60/200], Loss: 1.0347
# Epoch [61/200], Loss: 0.9131
# Epoch [62/200], Loss: 0.8839
# Epoch [63/200], Loss: 0.9063
# Epoch [64/200], Loss: 0.8678
# Epoch [65/200], Loss: 0.8856
# Epoch [66/200], Loss: 0.8882
# Epoch [67/200], Loss: 0.8807
# Epoch [68/200], Loss: 0.8330
# Epoch [69/200], Loss: 0.8319
# Epoch [70/200], Loss: 0.8233
# Epoch [71/200], Loss: 0.8278
# Epoch [72/200], Loss: 0.8146
# Epoch [73/200], Loss: 0.8194
# Epoch [74/200], Loss: 0.8267
# Epoch [75/200], Loss: 0.7521
# Epoch [76/200], Loss: 0.8239
# Epoch [77/200], Loss: 0.7543
# Epoch [78/200], Loss: 0.7642
# Epoch [79/200], Loss: 0.7734
# Epoch [80/200], Loss: 0.7166
# Epoch [81/200], Loss: 0.7395
# Epoch [82/200], Loss: 0.7034
# Epoch [83/200], Loss: 0.7361
# Epoch [84/200], Loss: 0.7060
# Epoch [85/200], Loss: 0.6502
# Epoch [86/200], Loss: 0.6610
# Epoch [87/200], Loss: 0.6519
# Epoch [88/200], Loss: 0.6852
# Epoch [89/200], Loss: 0.6952
# Epoch [90/200], Loss: 0.6695
# Epoch [91/200], Loss: 0.6416
# Epoch [92/200], Loss: 0.7375
# Epoch [93/200], Loss: 0.7048
# Epoch [94/200], Loss: 0.6396
# Epoch [95/200], Loss: 0.6229
# Epoch [96/200], Loss: 0.6409
# Epoch [97/200], Loss: 0.5993
# Epoch [98/200], Loss: 0.6386
# Epoch [99/200], Loss: 0.6347
# Epoch [100/200], Loss: 0.5912
# Epoch [101/200], Loss: 0.5857
# Epoch [102/200], Loss: 0.6007
# Epoch [103/200], Loss: 0.5726
# Epoch [104/200], Loss: 0.6318
# Epoch [105/200], Loss: 0.5512
# Epoch [106/200], Loss: 0.5424
# Epoch [107/200], Loss: 0.6180
# Epoch [108/200], Loss: 0.5373
# Epoch [109/200], Loss: 0.5581
# Epoch [110/200], Loss: 0.5447
# Epoch [111/200], Loss: 0.5498
# Epoch [112/200], Loss: 0.5398
# Epoch [113/200], Loss: 0.5497
# Epoch [114/200], Loss: 0.5355
# Epoch [115/200], Loss: 0.6022
# Epoch [116/200], Loss: 0.5299
# Epoch [117/200], Loss: 0.5644
# Epoch [118/200], Loss: 0.5418
# Epoch [119/200], Loss: 0.4712
# Epoch [120/200], Loss: 0.5368
# Epoch [121/200], Loss: 0.6059
# Epoch [122/200], Loss: 0.5359
# Epoch [123/200], Loss: 0.4665
# Epoch [124/200], Loss: 0.5212
# Epoch [125/200], Loss: 0.4773
# Epoch [126/200], Loss: 0.4630
# Epoch [127/200], Loss: 0.4834
# Epoch [128/200], Loss: 0.4415
# Epoch [129/200], Loss: 0.4437
# Epoch [130/200], Loss: 0.4984
# Epoch [131/200], Loss: 0.4408
# Epoch [132/200], Loss: 0.4495
# Epoch [133/200], Loss: 0.4474
# Epoch [134/200], Loss: 0.4236
# Epoch [135/200], Loss: 0.4079
# Epoch [136/200], Loss: 0.4725
# Epoch [137/200], Loss: 0.5480
# Epoch [138/200], Loss: 0.4874
# Epoch [139/200], Loss: 0.4775
# Epoch [140/200], Loss: 0.4097
# Epoch [141/200], Loss: 0.4030
# Epoch [142/200], Loss: 0.3896
# Epoch [143/200], Loss: 0.4274
# Epoch [144/200], Loss: 0.4638
# Epoch [145/200], Loss: 0.5018
# Epoch [146/200], Loss: 0.5282
# Epoch [147/200], Loss: 0.3826
# Epoch [148/200], Loss: 0.3847
# Epoch [149/200], Loss: 0.4399
# Epoch [150/200], Loss: 0.4147
# Epoch [151/200], Loss: 0.3760
# Epoch [152/200], Loss: 0.4138
# Epoch [153/200], Loss: 0.3540
# Epoch [154/200], Loss: 0.3986
# Epoch [155/200], Loss: 0.3847
# Epoch [156/200], Loss: 0.3814
# Epoch [157/200], Loss: 0.4205
# Epoch [158/200], Loss: 0.3941
# Epoch [159/200], Loss: 0.3768
# Epoch [160/200], Loss: 0.4044
# Epoch [161/200], Loss: 0.3755
# Epoch [162/200], Loss: 0.3786
# Epoch [163/200], Loss: 0.3624
# Epoch [164/200], Loss: 0.3820
# Epoch [165/200], Loss: 0.3446
# Epoch [166/200], Loss: 0.3666
# Epoch [167/200], Loss: 0.3390
# Epoch [168/200], Loss: 0.4077
# Epoch [169/200], Loss: 0.3807
# Epoch [170/200], Loss: 0.3342
# Epoch [171/200], Loss: 0.3699
# Epoch [172/200], Loss: 0.3157
# Epoch [173/200], Loss: 0.3363
# Epoch [174/200], Loss: 0.3433
# Epoch [175/200], Loss: 0.3548
# Epoch [176/200], Loss: 0.3941
# Epoch [177/200], Loss: 0.3426
# Epoch [178/200], Loss: 0.3473
# Epoch [179/200], Loss: 0.3999
# Epoch [180/200], Loss: 0.3610
# Epoch [181/200], Loss: 0.3755
# Epoch [182/200], Loss: 0.3017
# Epoch [183/200], Loss: 0.2977
# Epoch [184/200], Loss: 0.3054
# Epoch [185/200], Loss: 0.2828
# Epoch [186/200], Loss: 0.3291
# Epoch [187/200], Loss: 0.3509
# Epoch [188/200], Loss: 0.3026
# Epoch [189/200], Loss: 0.3275
# Epoch [190/200], Loss: 0.3045
# Epoch [191/200], Loss: 0.2835
# Epoch [192/200], Loss: 0.2783
# Epoch [193/200], Loss: 0.3684
# Epoch [194/200], Loss: 0.2811
# Epoch [195/200], Loss: 0.2843
# Epoch [196/200], Loss: 0.3126
# Epoch [197/200], Loss: 0.2965
# Epoch [198/200], Loss: 0.2718
# Epoch [199/200], Loss: 0.3180
# Epoch [200/200], Loss: 0.3449

# %%
from sklearn.metrics import cohen_kappa_score
import numpy as np

def evaluate_classification_model_with_details(feature_extractor, classification_head, test_loader, num_classes):
    """
    评估分类模型的性能，并输出详细预测结果和分布。

    参数:
        feature_extractor: 冻结的特征提取器
        classification_head: 分类头
        test_loader: 测试数据加载器
        num_classes: 总类别数
    """
    feature_extractor.eval()
    classification_head.eval()

    correct = 0
    total = 0

    # 初始化预测计数，并移动到 GPU
    prediction_counts = torch.zeros(num_classes, dtype=torch.int64).cuda()
    class_correct = torch.zeros(num_classes, dtype=torch.int64).cuda()
    class_total = torch.zeros(num_classes, dtype=torch.int64).cuda()

    all_predictions = []
    all_labels = []

    with torch.no_grad():
        for cubes, labels in test_loader:
            cubes, labels = cubes.cuda(), labels.cuda()

            # 提取特征并进行预测
            features = feature_extractor(cubes)
            outputs = classification_head(features)
            _, predicted = torch.max(outputs, 1)

            # 更新统计信息
            correct += (predicted == labels).sum().item()
            total += labels.size(0)
            prediction_counts += torch.bincount(predicted, minlength=num_classes).cuda()

            for i in range(labels.size(0)):
                label = labels[i].item()
                pred = predicted[i].item()
                class_total[label] += 1
                if label == pred:
                    class_correct[label] += 1

            # 保存详细信息
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Overall Accuracy
    overall_accuracy = correct / total

    # Average Accuracy (每个类别的平均准确率)
    average_accuracy = (class_correct.float() / class_total.float()).mean().item()

    # Kappa 系数
    kappa = cohen_kappa_score(all_labels, all_predictions)

    print(f"Overall Accuracy: {overall_accuracy:.4f}")
    print(f"Average Accuracy: {average_accuracy:.4f}")
    print(f"Kappa Coefficient: {kappa:.4f}")

    print("\nPrediction Distribution:")
    for cls, count in enumerate(prediction_counts.cpu()):  # 将分布从 GPU 移回 CPU
        print(f"Class {cls}: {count} predictions")

    return overall_accuracy, average_accuracy, kappa, all_predictions, all_labels

# 再次评估模型
overall_accuracy, average_accuracy, kappa, all_predictions, all_labels = evaluate_classification_model_with_details(
    feature_extractor, classification_head, test_loader, num_classes=num_classes
)

# 打印所有测试样本的预测类别和真实类别
print("\nDetailed Predictions:")
for idx, (pred, label) in enumerate(zip(all_predictions, all_labels)):
    print(f"Sample {idx}: Predicted={pred}, True={label}")
# Out:
# Overall Accuracy: 0.7075
# Average Accuracy: 0.7344
# Kappa Coefficient: 0.6830
#
# Prediction Distribution:
# Class 0: 870 predictions
# Class 1: 828 predictions
# Class 2: 420 predictions
# Class 3: 1453 predictions
# Class 4: 1094 predictions
# Class 5: 131 predictions
# Class 6: 763 predictions
# Class 7: 1044 predictions
# Class 8: 860 predictions
# Class 9: 775 predictions
# Class 10: 1020 predictions
# Class 11: 1537 predictions
# Class 12: 493 predictions
# Class 13: 420 predictions
# Class 14: 489 predictions
#
# Detailed Predictions:
# Sample 0: Predicted=6, True=6
# Sample 1: Predicted=6, True=6
# Sample 2: Predicted=6, True=6
# Sample 3: Predicted=6, True=6
# Sample 4: Predicted=6, True=6
# Sample 5: Predicted=6, True=6
# Sample 6: Predicted=6, True=6
# Sample 7: Predicted=6, True=6
# Sample 8: Predicted=6, True=6
# Sample 9: Predicted=6, True=6
# Sample 10: Predicted=6, True=6
# Sample 11: Predicted=6, True=6
# Sample 12: Predicted=6, True=6
# Sample 13: Predicted=6, True=6
# Sample 14: Predicted=6, True=6
# Sample 15: Predicted=8, True=8
# Sample 16: Predicted=8, True=8
# Sample 17: Predicted=8, True=8
# Sample 18: Predicted=8, True=8
# Sample 19: Predicted=8, True=8
# Sample 20: Predicted=8, True=8
# Sample 21: Predicted=6, True=6
# Sample 22: Predicted=6, True=6
# Sample 23: Predicted=6, True=6
# Sample 24: Predicted=8, True=8
# Sample 25: Predicted=8, True=8
# Sample 26: Predicted=8, True=8
# Sample 27: Predicted=6, True=6
# Sample 28: Predicted=6, True=6
# Sample 29: Predicted=6, True=6
# Sample 30: Predicted=6, True=6
# Sample 31: Predicted=6, True=6
# Sample 32: Predicted=3, True=6
# Sample 33: Predicted=3, True=6
# Sample 34: Predicted=8, True=8
# Sample 35: Predicted=8, True=8
# Sample 36: Predicted=6, True=6
# Sample 37: Predicted=6, True=6
# Sample 38: Predicted=6, True=6
# Sample 39: Predicted=6, True=6
# Sample 40: Predicted=6, True=6
# Sample 41: Predicted=6, True=6
# Sample 42: Predicted=6, True=6
# Sample 43: Predicted=6, True=6
# Sample 44: Predicted=8, True=8
# Sample 45: Predicted=8, True=8
# Sample 46: Predicted=6, True=6
# Sample 47: Predicted=6, True=6
# Sample 48: Predicted=6, True=6
# Sample 49: Predicted=13, True=6
# Sample 50: Predicted=6, True=6
# Sample 51: Predicted=6, True=6
# Sample 52: Predicted=8, True=8
# Sample 53: Predicted=8, True=8
# Sample 54: Predicted=8, True=8
# Sample 55: Predicted=6, True=6
# Sample 56: Predicted=6, True=6
# Sample 57: Predicted=8, True=8
# Sample 58: Predicted=8, True=8
# Sample 59: Predicted=8, True=8
# Sample 60: Predicted=8, True=8
# Sample 61: Predicted=10, True=8
# Sample 62: Predicted=10, True=8
# Sample 63: Predicted=8, True=8
# Sample 64: Predicted=8, True=8
# Sample 65: Predicted=8, True=8
# Sample 66: Predicted=8, True=8
# Sample 67: Predicted=6, True=6
# Sample 68: Predicted=13, True=6
# Sample 69: Predicted=6, True=6
# Sample 70: Predicted=6, True=6
# Sample 71: Predicted=6, True=6
# Sample 72: Predicted=13, True=6
# Sample 73: Predicted=6, True=6
# Sample 74: Predicted=6, True=6
# Sample 75: Predicted=6, True=6
# Sample 76: Predicted=6, True=6
# Sample 77: Predicted=6, True=6
# Sample 78: Predicted=6, True=6
# Sample 79: Predicted=6, True=6
# Sample 80: Predicted=6, True=6
# Sample 81: Predicted=3, True=3
# Sample 82: Predicted=3, True=3
# Sample 83: Predicted=10, True=6
# Sample 84: Predicted=6, True=6
# Sample 85: Predicted=6, True=6
# Sample 86: Predicted=6, True=6
# Sample 87: Predicted=6, True=6
# Sample 88: Predicted=6, True=6
# Sample 89: Predicted=3, True=3
# Sample 90: Predicted=3, True=3
# Sample 91: Predicted=3, True=3
# Sample 92: Predicted=3, True=3
# Sample 93: Predicted=3, True=3
# Sample 94: Predicted=3, True=3
# Sample 95: Predicted=10, True=6
# Sample 96: Predicted=6, True=6
# Sample 97: Predicted=6, True=6
# Sample 98: Predicted=6, True=6
# Sample 99: Predicted=3, True=3
# Sample 100: Predicted=3, True=3
# Sample 101: Predicted=3, True=3
# Sample 102: Predicted=3, True=3
# Sample 103: Predicted=3, True=3
# Sample 104: Predicted=3, True=3
# Sample 105: Predicted=3, True=3
# Sample 106: Predicted=3, True=3
# Sample 107: Predicted=6, True=6
# Sample 108: Predicted=6, True=6
# Sample 109: Predicted=3, True=3
# Sample 110: Predicted=3, True=3
# Sample 111: Predicted=3, True=3
# Sample 112: Predicted=3, True=3
# Sample 113: Predicted=3, True=3
# Sample 114: Predicted=3, True=3
# Sample 115: Predicted=3, True=3
# Sample 116: Predicted=3, True=3
# Sample 117: Predicted=3, True=3
# Sample 118: Predicted=3, True=3
# Sample 119: Predicted=3, True=3
# Sample 120: Predicted=3, True=3
# Sample 121: Predicted=3, True=3
# Sample 122: Predicted=3, True=3
# Sample 123: Predicted=3, True=3
# Sample 124: Predicted=3, True=3
# Sample 125: Predicted=3, True=3
# Sample 126: Predicted=3, True=3
# Sample 127: Predicted=3, True=3
# Sample 128: Predicted=3, True=3
# Sample 129: Predicted=3, True=3
# Sample 130: Predicted=3, True=3
# Sample 131: Predicted=3, True=3
# Sample 132: Predicted=3, True=3
# Sample 133: Predicted=3, True=3
# Sample 134: Predicted=3, True=3
# Sample 135: Predicted=3, True=3
# Sample 136: Predicted=8, True=8
# Sample 137: Predicted=8, True=8
# Sample 138: Predicted=8, True=8
# Sample 139: Predicted=8, True=8
# Sample 140: Predicted=8, True=8
# Sample 141: Predicted=3, True=3
# Sample 142: Predicted=3, True=3
# Sample 143: Predicted=3, True=3
# Sample 144: Predicted=3, True=3
# Sample 145: Predicted=3, True=3
# Sample 146: Predicted=3, True=3
# Sample 147: Predicted=3, True=3
# Sample 148: Predicted=3, True=3
# Sample 149: Predicted=3, True=3
# Sample 150: Predicted=3, True=3
# Sample 151: Predicted=10, True=8
# Sample 152: Predicted=8, True=8
# Sample 153: Predicted=8, True=8
# Sample 154: Predicted=8, True=8
# Sample 155: Predicted=8, True=8
# Sample 156: Predicted=8, True=8
# Sample 157: Predicted=8, True=8
# Sample 158: Predicted=3, True=3
# Sample 159: Predicted=3, True=3
# Sample 160: Predicted=3, True=3
# Sample 161: Predicted=3, True=3
# Sample 162: Predicted=3, True=3
# Sample 163: Predicted=3, True=3
# Sample 164: Predicted=3, True=3
# Sample 165: Predicted=3, True=3
# Sample 166: Predicted=10, True=8
# Sample 167: Predicted=10, True=8
# Sample 168: Predicted=8, True=8
# Sample 169: Predicted=8, True=8
# Sample 170: Predicted=7, True=8
# Sample 171: Predicted=8, True=8
# Sample 172: Predicted=8, True=8
# Sample 173: Predicted=8, True=8
# Sample 174: Predicted=8, True=8
# Sample 175: Predicted=3, True=3
# Sample 176: Predicted=3, True=3
# Sample 177: Predicted=3, True=3
# Sample 178: Predicted=6, True=6
# Sample 179: Predicted=6, True=6
# Sample 180: Predicted=10, True=8
# Sample 181: Predicted=10, True=8
# Sample 182: Predicted=10, True=8
# Sample 183: Predicted=8, True=8
# Sample 184: Predicted=6, True=6
# Sample 185: Predicted=6, True=6
# Sample 186: Predicted=6, True=6
# Sample 187: Predicted=6, True=6
# Sample 188: Predicted=8, True=8
# Sample 189: Predicted=8, True=8
# Sample 190: Predicted=8, True=8
# Sample 191: Predicted=8, True=8
# Sample 192: Predicted=6, True=6
# Sample 193: Predicted=6, True=6
# Sample 194: Predicted=6, True=6
# Sample 195: Predicted=6, True=6
# Sample 196: Predicted=6, True=6
# Sample 197: Predicted=6, True=6
# Sample 198: Predicted=8, True=8
# Sample 199: Predicted=8, True=8
# Sample 200: Predicted=8, True=8
# Sample 201: Predicted=7, True=8
# Sample 202: Predicted=5, True=6
# Sample 203: Predicted=6, True=6
# Sample 204: Predicted=6, True=6
# Sample 205: Predicted=6, True=6
# Sample 206: Predicted=12, True=6
# Sample 207: Predicted=6, True=6
# Sample 208: Predicted=6, True=6
# Sample 209: Predicted=8, True=8
# Sample 210: Predicted=8, True=8
# Sample 211: Predicted=8, True=8
# Sample 212: Predicted=8, True=8
# Sample 213: Predicted=5, True=6
# Sample 214: Predicted=5, True=6
# Sample 215: Predicted=6, True=6
# Sample 216: Predicted=6, True=6
# Sample 217: Predicted=6, True=6
# Sample 218: Predicted=8, True=8
# Sample 219: Predicted=8, True=8
# Sample 220: Predicted=8, True=8
# Sample 221: Predicted=7, True=8
# Sample 222: Predicted=5, True=6
# Sample 223: Predicted=6, True=6
# Sample 224: Predicted=6, True=6
# Sample 225: Predicted=8, True=8
# Sample 226: Predicted=8, True=8
# Sample 227: Predicted=6, True=6
# Sample 228: Predicted=10, True=8
# Sample 229: Predicted=10, True=8
# Sample 230: Predicted=8, True=8
# Sample 231: Predicted=10, True=8
# Sample 232: Predicted=8, True=8
# Sample 233: Predicted=8, True=8
# Sample 234: Predicted=1, True=1
# Sample 235: Predicted=1, True=1
# Sample 236: Predicted=1, True=1
# Sample 237: Predicted=10, True=8
# Sample 238: Predicted=8, True=8
# Sample 239: Predicted=7, True=8
# Sample 240: Predicted=8, True=8
# Sample 241: Predicted=8, True=8
# Sample 242: Predicted=13, True=1
# Sample 243: Predicted=1, True=1
# Sample 244: Predicted=1, True=1
# Sample 245: Predicted=1, True=1
# Sample 246: Predicted=1, True=1
# Sample 247: Predicted=1, True=1
# Sample 248: Predicted=8, True=8
# Sample 249: Predicted=8, True=8
# Sample 250: Predicted=13, True=1
# Sample 251: Predicted=13, True=1
# Sample 252: Predicted=1, True=1
# Sample 253: Predicted=1, True=1
# Sample 254: Predicted=1, True=1
# Sample 255: Predicted=1, True=1
# Sample 256: Predicted=1, True=1
# Sample 257: Predicted=1, True=1
# Sample 258: Predicted=13, True=1
# Sample 259: Predicted=0, True=1
# Sample 260: Predicted=1, True=1
# Sample 261: Predicted=1, True=1
# Sample 262: Predicted=1, True=1
# Sample 263: Predicted=0, True=1
# Sample 264: Predicted=1, True=1
# Sample 265: Predicted=0, True=1
# Sample 266: Predicted=1, True=1
# Sample 267: Predicted=1, True=1
# Sample 268: Predicted=0, True=1
# Sample 269: Predicted=1, True=1
# Sample 270: Predicted=10, True=8
# Sample 271: Predicted=10, True=8
# Sample 272: Predicted=13, True=8
# Sample 273: Predicted=10, True=8
# Sample 274: Predicted=10, True=8
# Sample 275: Predicted=10, True=8
# Sample 276: Predicted=13, True=8
# Sample 277: Predicted=10, True=8
# Sample 278: Predicted=10, True=8
# Sample 279: Predicted=10, True=8
# Sample 280: Predicted=3, True=6
# Sample 281: Predicted=3, True=6
# Sample 282: Predicted=3, True=6
# Sample 283: Predicted=13, True=8
# Sample 284: Predicted=10, True=8
# Sample 285: Predicted=10, True=8
# Sample 286: Predicted=10, True=8
# Sample 287: Predicted=10, True=6
# Sample 288: Predicted=3, True=6
# Sample 289: Predicted=3, True=6
# Sample 290: Predicted=13, True=8
# Sample 291: Predicted=10, True=8
# Sample 292: Predicted=10, True=8
# Sample 293: Predicted=8, True=8
# Sample 294: Predicted=10, True=6
# Sample 295: Predicted=3, True=6
# Sample 296: Predicted=3, True=6
# Sample 297: Predicted=10, True=8
# Sample 298: Predicted=10, True=8
# Sample 299: Predicted=10, True=8
# Sample 300: Predicted=8, True=8
# Sample 301: Predicted=8, True=8
# Sample 302: Predicted=8, True=8
# Sample 303: Predicted=8, True=8
# Sample 304: Predicted=8, True=8
# Sample 305: Predicted=8, True=8
# Sample 306: Predicted=8, True=8
# Sample 307: Predicted=6, True=6
# Sample 308: Predicted=6, True=6
# Sample 309: Predicted=6, True=6
# Sample 310: Predicted=10, True=8
# Sample 311: Predicted=10, True=6
# Sample 312: Predicted=6, True=6
# Sample 313: Predicted=6, True=6
# Sample 314: Predicted=10, True=8
# Sample 315: Predicted=10, True=8
# Sample 316: Predicted=10, True=8
# Sample 317: Predicted=10, True=6
# Sample 318: Predicted=6, True=6
# Sample 319: Predicted=6, True=6
# Sample 320: Predicted=8, True=8
# Sample 321: Predicted=8, True=8
# Sample 322: Predicted=8, True=8
# Sample 323: Predicted=8, True=8
# Sample 324: Predicted=8, True=8
# Sample 325: Predicted=8, True=8
# Sample 326: Predicted=8, True=8
# Sample 327: Predicted=8, True=8
# Sample 328: Predicted=8, True=8
# Sample 329: Predicted=8, True=8
# Sample 330: Predicted=8, True=8
# Sample 331: Predicted=8, True=8
# Sample 332: Predicted=8, True=8
# Sample 333: Predicted=8, True=8
# Sample 334: Predicted=8, True=8
# Sample 335: Predicted=8, True=8
# Sample 336: Predicted=8, True=8
# Sample 337: Predicted=8, True=8
# Sample 338: Predicted=8, True=8
# Sample 339: Predicted=8, True=8
# Sample 340: Predicted=8, True=8
# Sample 341: Predicted=8, True=8
# Sample 342: Predicted=10, True=8
# Sample 343: Predicted=8, True=8
# Sample 344: Predicted=7, True=8
# Sample 345: Predicted=7, True=8
# Sample 346: Predicted=6, True=6
# Sample 347: Predicted=6, True=6
# Sample 348: Predicted=3, True=6
# Sample 349: Predicted=3, True=3
# Sample 350: Predicted=3, True=3
# Sample 351: Predicted=3, True=3
# Sample 352: Predicted=3, True=3
# Sample 353: Predicted=3, True=3
# Sample 354: Predicted=6, True=6
# Sample 355: Predicted=6, True=6
# Sample 356: Predicted=3, True=6
# Sample 357: Predicted=3, True=3
# Sample 358: Predicted=3, True=3
# Sample 359: Predicted=3, True=3
# Sample 360: Predicted=3, True=3
# Sample 361: Predicted=3, True=3
# Sample 362: Predicted=6, True=6
# Sample 363: Predicted=6, True=6
# Sample 364: Predicted=6, True=6
# Sample 365: Predicted=3, True=3
# Sample 366: Predicted=3, True=3
# Sample 367: Predicted=3, True=3
# Sample 368: Predicted=3, True=3
# Sample 369: Predicted=3, True=3
# Sample 370: Predicted=6, True=6
# Sample 371: Predicted=6, True=6
# Sample 372: Predicted=6, True=6
# Sample 373: Predicted=3, True=3
# Sample 374: Predicted=3, True=3
# Sample 375: Predicted=3, True=3
# Sample 376: Predicted=3, True=3
# Sample 377: Predicted=3, True=3
# Sample 378: Predicted=3, True=3
# Sample 379: Predicted=3, True=3
# Sample 380: Predicted=3, True=3
# Sample 381: Predicted=3, True=3
# Sample 382: Predicted=3, True=3
# Sample 383: Predicted=6, True=8
# Sample 384: Predicted=6, True=8
# Sample 385: Predicted=6, True=8
# Sample 386: Predicted=6, True=8
# Sample 387: Predicted=6, True=8
# Sample 388: Predicted=8, True=8
# Sample 389: Predicted=6, True=8
# Sample 390: Predicted=6, True=8
# Sample 391: Predicted=6, True=8
# Sample 392: Predicted=8, True=8
# Sample 393: Predicted=6, True=6
# Sample 394: Predicted=6, True=6
# Sample 395: Predicted=6, True=6
# Sample 396: Predicted=6, True=6
# Sample 397: Predicted=6, True=6
# Sample 398: Predicted=6, True=8
# Sample 399: Predicted=6, True=8
# Sample 400: Predicted=8, True=8
# Sample 401: Predicted=8, True=8
# Sample 402: Predicted=6, True=6
# Sample 403: Predicted=6, True=6
# Sample 404: Predicted=6, True=6
# Sample 405: Predicted=6, True=6
# Sample 406: Predicted=6, True=6
# Sample 407: Predicted=8, True=8
# Sample 408: Predicted=8, True=8
# Sample 409: Predicted=8, True=8
# Sample 410: Predicted=8, True=8
# Sample 411: Predicted=6, True=6
# Sample 412: Predicted=6, True=6
# Sample 413: Predicted=6, True=6
# Sample 414: Predicted=6, True=6
# Sample 415: Predicted=6, True=6
# Sample 416: Predicted=6, True=6
# Sample 417: Predicted=8, True=8
# Sample 418: Predicted=8, True=8
# Sample 419: Predicted=8, True=8
# Sample 420: Predicted=6, True=6
# Sample 421: Predicted=6, True=6
# Sample 422: Predicted=6, True=6
# Sample 423: Predicted=6, True=6
# Sample 424: Predicted=8, True=8
# Sample 425: Predicted=8, True=8
# Sample 426: Predicted=8, True=8
# Sample 427: Predicted=12, True=6
# Sample 428: Predicted=12, True=6
# Sample 429: Predicted=6, True=6
# Sample 430: Predicted=6, True=6
# Sample 431: Predicted=6, True=6
# Sample 432: Predicted=6, True=6
# Sample 433: Predicted=8, True=8
# Sample 434: Predicted=8, True=8
# Sample 435: Predicted=8, True=8
# Sample 436: Predicted=12, True=6
# Sample 437: Predicted=6, True=6
# Sample 438: Predicted=6, True=6
# Sample 439: Predicted=6, True=6
# Sample 440: Predicted=6, True=6
# Sample 441: Predicted=6, True=6
# Sample 442: Predicted=8, True=8
# Sample 443: Predicted=6, True=6
# Sample 444: Predicted=6, True=6
# Sample 445: Predicted=6, True=6
# Sample 446: Predicted=6, True=6
# Sample 447: Predicted=6, True=6
# Sample 448: Predicted=11, True=11
# Sample 449: Predicted=11, True=11
# Sample 450: Predicted=11, True=11
# Sample 451: Predicted=11, True=11
# Sample 452: Predicted=11, True=11
# Sample 453: Predicted=11, True=11
# Sample 454: Predicted=11, True=11
# Sample 455: Predicted=11, True=11
# Sample 456: Predicted=11, True=11
# Sample 457: Predicted=11, True=11
# Sample 458: Predicted=11, True=11
# Sample 459: Predicted=11, True=11
# Sample 460: Predicted=11, True=11
# Sample 461: Predicted=11, True=11
# Sample 462: Predicted=11, True=11
# Sample 463: Predicted=11, True=11
# Sample 464: Predicted=11, True=11
# Sample 465: Predicted=11, True=11
# Sample 466: Predicted=11, True=11
# Sample 467: Predicted=11, True=11
# Sample 468: Predicted=11, True=11
# Sample 469: Predicted=11, True=11
# Sample 470: Predicted=11, True=11
# Sample 471: Predicted=11, True=11
# Sample 472: Predicted=11, True=11
# Sample 473: Predicted=11, True=11
# Sample 474: Predicted=11, True=11
# Sample 475: Predicted=11, True=11
# Sample 476: Predicted=11, True=11
# Sample 477: Predicted=11, True=11
# Sample 478: Predicted=11, True=11
# Sample 479: Predicted=11, True=11
# Sample 480: Predicted=11, True=11
# Sample 481: Predicted=11, True=11
# Sample 482: Predicted=11, True=11
# Sample 483: Predicted=11, True=11
# Sample 484: Predicted=11, True=11
# Sample 485: Predicted=11, True=11
# Sample 486: Predicted=11, True=11
# Sample 487: Predicted=11, True=11
# Sample 488: Predicted=11, True=11
# Sample 489: Predicted=11, True=11
# Sample 490: Predicted=11, True=11
# Sample 491: Predicted=11, True=11
# Sample 492: Predicted=11, True=11
# Sample 493: Predicted=11, True=11
# Sample 494: Predicted=11, True=11
# Sample 495: Predicted=11, True=11
# Sample 496: Predicted=11, True=11
# Sample 497: Predicted=11, True=11
# Sample 498: Predicted=11, True=11
# Sample 499: Predicted=11, True=11
# Sample 500: Predicted=11, True=11
# Sample 501: Predicted=11, True=11
# Sample 502: Predicted=11, True=11
# Sample 503: Predicted=11, True=11
# Sample 504: Predicted=11, True=11
# Sample 505: Predicted=11, True=11
# Sample 506: Predicted=11, True=11
# Sample 507: Predicted=11, True=11
# Sample 508: Predicted=11, True=11
# Sample 509: Predicted=11, True=11
# Sample 510: Predicted=11, True=11
# Sample 511: Predicted=11, True=11
# Sample 512: Predicted=11, True=11
# Sample 513: Predicted=11, True=11
# Sample 514: Predicted=11, True=11
# Sample 515: Predicted=11, True=11
# Sample 516: Predicted=11, True=11
# Sample 517: Predicted=3, True=3
# Sample 518: Predicted=3, True=3
# Sample 519: Predicted=3, True=3
# Sample 520: Predicted=11, True=11
# Sample 521: Predicted=11, True=11
# Sample 522: Predicted=11, True=11
# Sample 523: Predicted=11, True=11
# Sample 524: Predicted=11, True=11
# Sample 525: Predicted=11, True=11
# Sample 526: Predicted=11, True=11
# Sample 527: Predicted=11, True=11
# Sample 528: Predicted=11, True=11
# Sample 529: Predicted=11, True=11
# Sample 530: Predicted=11, True=11
# Sample 531: Predicted=11, True=11
# Sample 532: Predicted=11, True=11
# Sample 533: Predicted=11, True=11
# Sample 534: Predicted=11, True=11
# Sample 535: Predicted=3, True=3
# Sample 536: Predicted=3, True=3
# Sample 537: Predicted=3, True=3
# Sample 538: Predicted=11, True=11
# Sample 539: Predicted=11, True=11
# Sample 540: Predicted=11, True=11
# Sample 541: Predicted=11, True=11
# Sample 542: Predicted=11, True=11
# Sample 543: Predicted=11, True=11
# Sample 544: Predicted=11, True=11
# Sample 545: Predicted=11, True=11
# Sample 546: Predicted=11, True=11
# Sample 547: Predicted=11, True=11
# Sample 548: Predicted=11, True=11
# Sample 549: Predicted=11, True=11
# Sample 550: Predicted=11, True=11
# Sample 551: Predicted=3, True=3
# Sample 552: Predicted=3, True=3
# Sample 553: Predicted=3, True=3
# Sample 554: Predicted=11, True=11
# Sample 555: Predicted=11, True=11
# Sample 556: Predicted=11, True=11
# Sample 557: Predicted=11, True=11
# Sample 558: Predicted=11, True=11
# Sample 559: Predicted=11, True=11
# Sample 560: Predicted=11, True=11
# Sample 561: Predicted=11, True=11
# Sample 562: Predicted=11, True=11
# Sample 563: Predicted=11, True=11
# Sample 564: Predicted=11, True=11
# Sample 565: Predicted=11, True=11
# Sample 566: Predicted=11, True=11
# Sample 567: Predicted=11, True=11
# Sample 568: Predicted=11, True=11
# Sample 569: Predicted=11, True=11
# Sample 570: Predicted=11, True=11
# Sample 571: Predicted=11, True=11
# Sample 572: Predicted=11, True=11
# Sample 573: Predicted=11, True=11
# Sample 574: Predicted=11, True=11
# Sample 575: Predicted=11, True=11
# Sample 576: Predicted=11, True=11
# Sample 577: Predicted=11, True=11
# Sample 578: Predicted=11, True=11
# Sample 579: Predicted=11, True=11
# Sample 580: Predicted=11, True=11
# Sample 581: Predicted=11, True=11
# Sample 582: Predicted=11, True=11
# Sample 583: Predicted=11, True=11
# Sample 584: Predicted=11, True=11
# Sample 585: Predicted=11, True=11
# Sample 586: Predicted=11, True=11
# Sample 587: Predicted=11, True=11
# Sample 588: Predicted=11, True=11
# Sample 589: Predicted=11, True=11
# Sample 590: Predicted=11, True=11
# Sample 591: Predicted=11, True=11
# Sample 592: Predicted=6, True=6
# Sample 593: Predicted=5, True=6
# Sample 594: Predicted=6, True=6
# Sample 595: Predicted=6, True=6
# Sample 596: Predicted=5, True=6
# Sample 597: Predicted=6, True=6
# Sample 598: Predicted=3, True=3
# Sample 599: Predicted=3, True=3
# Sample 600: Predicted=3, True=3
# Sample 601: Predicted=6, True=6
# Sample 602: Predicted=5, True=6
# Sample 603: Predicted=6, True=6
# Sample 604: Predicted=3, True=3
# Sample 605: Predicted=3, True=3
# Sample 606: Predicted=3, True=3
# Sample 607: Predicted=3, True=3
# Sample 608: Predicted=3, True=3
# Sample 609: Predicted=3, True=3
# Sample 610: Predicted=3, True=3
# Sample 611: Predicted=3, True=3
# Sample 612: Predicted=3, True=3
# Sample 613: Predicted=5, True=8
# Sample 614: Predicted=5, True=8
# Sample 615: Predicted=8, True=8
# Sample 616: Predicted=5, True=8
# Sample 617: Predicted=8, True=8
# Sample 618: Predicted=8, True=8
# Sample 619: Predicted=8, True=8
# Sample 620: Predicted=8, True=8
# Sample 621: Predicted=8, True=8
# Sample 622: Predicted=6, True=6
# Sample 623: Predicted=6, True=6
# Sample 624: Predicted=6, True=6
# Sample 625: Predicted=13, True=8
# Sample 626: Predicted=6, True=6
# Sample 627: Predicted=6, True=6
# Sample 628: Predicted=6, True=6
# Sample 629: Predicted=10, True=8
# Sample 630: Predicted=10, True=8
# Sample 631: Predicted=10, True=8
# Sample 632: Predicted=6, True=6
# Sample 633: Predicted=6, True=6
# Sample 634: Predicted=6, True=6
# Sample 635: Predicted=10, True=8
# Sample 636: Predicted=10, True=8
# Sample 637: Predicted=10, True=8
# Sample 638: Predicted=7, True=8
# Sample 639: Predicted=10, True=8
# Sample 640: Predicted=10, True=8
# Sample 641: Predicted=10, True=8
# Sample 642: Predicted=10, True=8
# Sample 643: Predicted=8, True=8
# Sample 644: Predicted=10, True=8
# Sample 645: Predicted=10, True=8
# Sample 646: Predicted=10, True=8
# Sample 647: Predicted=8, True=8
# Sample 648: Predicted=8, True=8
# Sample 649: Predicted=6, True=6
# Sample 650: Predicted=6, True=6
# Sample 651: Predicted=6, True=6
# Sample 652: Predicted=13, True=8
# Sample 653: Predicted=10, True=8
# Sample 654: Predicted=10, True=8
# Sample 655: Predicted=8, True=8
# Sample 656: Predicted=8, True=8
# Sample 657: Predicted=6, True=6
# Sample 658: Predicted=6, True=6
# Sample 659: Predicted=6, True=6
# Sample 660: Predicted=13, True=8
# Sample 661: Predicted=8, True=8
# Sample 662: Predicted=8, True=8
# Sample 663: Predicted=8, True=8
# Sample 664: Predicted=8, True=8
# Sample 665: Predicted=6, True=6
# Sample 666: Predicted=6, True=6
# Sample 667: Predicted=6, True=6
# Sample 668: Predicted=10, True=8
# Sample 669: Predicted=8, True=8
# Sample 670: Predicted=8, True=8
# Sample 671: Predicted=8, True=8
# Sample 672: Predicted=8, True=8
# Sample 673: Predicted=6, True=6
# Sample 674: Predicted=6, True=6
# Sample 675: Predicted=6, True=6
# Sample 676: Predicted=10, True=8
# Sample 677: Predicted=10, True=8
# Sample 678: Predicted=10, True=8
# Sample 679: Predicted=8, True=8
# Sample 680: Predicted=13, True=8
# Sample 681: Predicted=10, True=8
# Sample 682: Predicted=10, True=8
# Sample 683: Predicted=10, True=8
# Sample 684: Predicted=10, True=8
# Sample 685: Predicted=9, True=8
# Sample 686: Predicted=10, True=8
# Sample 687: Predicted=10, True=8
# Sample 688: Predicted=10, True=8
# Sample 689: Predicted=7, True=8
# Sample 690: Predicted=8, True=8
# Sample 691: Predicted=8, True=8
# Sample 692: Predicted=8, True=8
# Sample 693: Predicted=7, True=8
# Sample 694: Predicted=8, True=8
# Sample 695: Predicted=8, True=8
# Sample 696: Predicted=7, True=8
# Sample 697: Predicted=7, True=8
# Sample 698: Predicted=8, True=8
# Sample 699: Predicted=8, True=8
# Sample 700: Predicted=4, True=4
# Sample 701: Predicted=4, True=4
# Sample 702: Predicted=4, True=4
# Sample 703: Predicted=4, True=4
# Sample 704: Predicted=4, True=4
# Sample 705: Predicted=4, True=4
# Sample 706: Predicted=4, True=4
# Sample 707: Predicted=4, True=4
# Sample 708: Predicted=4, True=4
# Sample 709: Predicted=4, True=4
# Sample 710: Predicted=4, True=4
# Sample 711: Predicted=4, True=4
# Sample 712: Predicted=0, True=0
# Sample 713: Predicted=4, True=4
# Sample 714: Predicted=4, True=4
# Sample 715: Predicted=4, True=4
# Sample 716: Predicted=4, True=4
# Sample 717: Predicted=0, True=0
# Sample 718: Predicted=0, True=0
# Sample 719: Predicted=0, True=0
# Sample 720: Predicted=4, True=4
# Sample 721: Predicted=0, True=0
# Sample 722: Predicted=0, True=0
# Sample 723: Predicted=0, True=0
# Sample 724: Predicted=0, True=0
# Sample 725: Predicted=0, True=0
# Sample 726: Predicted=4, True=4
# Sample 727: Predicted=4, True=4
# Sample 728: Predicted=4, True=4
# Sample 729: Predicted=0, True=0
# Sample 730: Predicted=0, True=0
# Sample 731: Predicted=0, True=0
# Sample 732: Predicted=0, True=0
# Sample 733: Predicted=0, True=0
# Sample 734: Predicted=0, True=0
# Sample 735: Predicted=0, True=0
# Sample 736: Predicted=4, True=4
# Sample 737: Predicted=4, True=4
# Sample 738: Predicted=4, True=4
# Sample 739: Predicted=4, True=4
# Sample 740: Predicted=4, True=4
# Sample 741: Predicted=0, True=0
# Sample 742: Predicted=0, True=0
# Sample 743: Predicted=0, True=0
# Sample 744: Predicted=0, True=0
# Sample 745: Predicted=0, True=0
# Sample 746: Predicted=0, True=0
# Sample 747: Predicted=0, True=0
# Sample 748: Predicted=0, True=0
# Sample 749: Predicted=0, True=0
# Sample 750: Predicted=0, True=0
# Sample 751: Predicted=4, True=4
# Sample 752: Predicted=4, True=4
# Sample 753: Predicted=4, True=4
# Sample 754: Predicted=4, True=4
# Sample 755: Predicted=4, True=4
# Sample 756: Predicted=4, True=4
# Sample 757: Predicted=4, True=4
# Sample 758: Predicted=0, True=0
# Sample 759: Predicted=0, True=0
# Sample 760: Predicted=0, True=0
# Sample 761: Predicted=0, True=0
# Sample 762: Predicted=0, True=0
# Sample 763: Predicted=0, True=0
# Sample 764: Predicted=0, True=0
# Sample 765: Predicted=0, True=0
# Sample 766: Predicted=0, True=0
# Sample 767: Predicted=0, True=0
# Sample 768: Predicted=0, True=0
# Sample 769: Predicted=4, True=4
# Sample 770: Predicted=4, True=4
# Sample 771: Predicted=4, True=4
# Sample 772: Predicted=4, True=4
# Sample 773: Predicted=4, True=4
# Sample 774: Predicted=4, True=4
# Sample 775: Predicted=4, True=4
# Sample 776: Predicted=4, True=4
# Sample 777: Predicted=0, True=0
# Sample 778: Predicted=0, True=0
# Sample 779: Predicted=0, True=0
# Sample 780: Predicted=0, True=0
# Sample 781: Predicted=0, True=0
# Sample 782: Predicted=0, True=0
# Sample 783: Predicted=0, True=0
# Sample 784: Predicted=0, True=0
# Sample 785: Predicted=0, True=0
# Sample 786: Predicted=0, True=0
# Sample 787: Predicted=0, True=0
# Sample 788: Predicted=0, True=0
# Sample 789: Predicted=0, True=0
# Sample 790: Predicted=4, True=4
# Sample 791: Predicted=4, True=4
# Sample 792: Predicted=4, True=4
# Sample 793: Predicted=4, True=4
# Sample 794: Predicted=4, True=4
# Sample 795: Predicted=4, True=4
# Sample 796: Predicted=4, True=4
# Sample 797: Predicted=4, True=4
# Sample 798: Predicted=4, True=4
# Sample 799: Predicted=4, True=4
# Sample 800: Predicted=0, True=0
# Sample 801: Predicted=0, True=0
# Sample 802: Predicted=0, True=0
# Sample 803: Predicted=0, True=0
# Sample 804: Predicted=0, True=0
# Sample 805: Predicted=0, True=0
# Sample 806: Predicted=0, True=0
# Sample 807: Predicted=0, True=0
# Sample 808: Predicted=0, True=0
# Sample 809: Predicted=0, True=0
# Sample 810: Predicted=0, True=0
# Sample 811: Predicted=0, True=0
# Sample 812: Predicted=0, True=0
# Sample 813: Predicted=0, True=0
# Sample 814: Predicted=0, True=0
# Sample 815: Predicted=4, True=4
# Sample 816: Predicted=4, True=4
# Sample 817: Predicted=4, True=4
# Sample 818: Predicted=4, True=4
# Sample 819: Predicted=4, True=4
# Sample 820: Predicted=4, True=4
# Sample 821: Predicted=4, True=4
# Sample 822: Predicted=4, True=4
# Sample 823: Predicted=4, True=4
# Sample 824: Predicted=4, True=4
# Sample 825: Predicted=4, True=4
# Sample 826: Predicted=4, True=4
# Sample 827: Predicted=0, True=0
# Sample 828: Predicted=0, True=0
# Sample 829: Predicted=0, True=0
# Sample 830: Predicted=0, True=0
# Sample 831: Predicted=0, True=0
# Sample 832: Predicted=0, True=0
# Sample 833: Predicted=0, True=0
# Sample 834: Predicted=0, True=0
# Sample 835: Predicted=0, True=0
# Sample 836: Predicted=0, True=0
# Sample 837: Predicted=0, True=0
# Sample 838: Predicted=0, True=0
# Sample 839: Predicted=0, True=0
# Sample 840: Predicted=0, True=0
# Sample 841: Predicted=0, True=0
# Sample 842: Predicted=4, True=4
# Sample 843: Predicted=4, True=4
# Sample 844: Predicted=4, True=4
# Sample 845: Predicted=4, True=4
# Sample 846: Predicted=4, True=4
# Sample 847: Predicted=4, True=4
# Sample 848: Predicted=4, True=4
# Sample 849: Predicted=4, True=4
# Sample 850: Predicted=4, True=4
# Sample 851: Predicted=4, True=4
# Sample 852: Predicted=4, True=4
# Sample 853: Predicted=4, True=4
# Sample 854: Predicted=4, True=4
# Sample 855: Predicted=4, True=4
# Sample 856: Predicted=0, True=0
# Sample 857: Predicted=0, True=0
# Sample 858: Predicted=0, True=0
# Sample 859: Predicted=0, True=0
# Sample 860: Predicted=0, True=0
# Sample 861: Predicted=0, True=0
# Sample 862: Predicted=0, True=0
# Sample 863: Predicted=0, True=0
# Sample 864: Predicted=0, True=0
# Sample 865: Predicted=0, True=0
# Sample 866: Predicted=0, True=0
# Sample 867: Predicted=0, True=0
# Sample 868: Predicted=0, True=0
# Sample 869: Predicted=0, True=0
# Sample 870: Predicted=0, True=0
# Sample 871: Predicted=0, True=0
# Sample 872: Predicted=8, True=8
# Sample 873: Predicted=8, True=8
# Sample 874: Predicted=4, True=4
# Sample 875: Predicted=4, True=4
# Sample 876: Predicted=4, True=4
# Sample 877: Predicted=4, True=4
# Sample 878: Predicted=4, True=4
# Sample 879: Predicted=4, True=4
# Sample 880: Predicted=4, True=4
# Sample 881: Predicted=4, True=4
# Sample 882: Predicted=4, True=4
# Sample 883: Predicted=4, True=4
# Sample 884: Predicted=4, True=4
# Sample 885: Predicted=4, True=4
# Sample 886: Predicted=4, True=4
# Sample 887: Predicted=0, True=0
# Sample 888: Predicted=0, True=0
# Sample 889: Predicted=0, True=0
# Sample 890: Predicted=0, True=0
# Sample 891: Predicted=0, True=0
# Sample 892: Predicted=0, True=0
# Sample 893: Predicted=0, True=0
# Sample 894: Predicted=0, True=0
# Sample 895: Predicted=0, True=0
# Sample 896: Predicted=0, True=0
# Sample 897: Predicted=0, True=0
# Sample 898: Predicted=0, True=0
# Sample 899: Predicted=0, True=0
# Sample 900: Predicted=0, True=0
# Sample 901: Predicted=8, True=8
# Sample 902: Predicted=8, True=8
# Sample 903: Predicted=4, True=4
# Sample 904: Predicted=4, True=4
# Sample 905: Predicted=4, True=4
# Sample 906: Predicted=4, True=4
# Sample 907: Predicted=4, True=4
# Sample 908: Predicted=4, True=4
# Sample 909: Predicted=4, True=4
# Sample 910: Predicted=4, True=4
# Sample 911: Predicted=4, True=4
# Sample 912: Predicted=4, True=4
# Sample 913: Predicted=4, True=4
# Sample 914: Predicted=4, True=4
# Sample 915: Predicted=4, True=4
# Sample 916: Predicted=0, True=0
# Sample 917: Predicted=0, True=0
# Sample 918: Predicted=0, True=0
# Sample 919: Predicted=0, True=0
# Sample 920: Predicted=0, True=0
# Sample 921: Predicted=0, True=0
# Sample 922: Predicted=0, True=0
# Sample 923: Predicted=0, True=0
# Sample 924: Predicted=0, True=0
# Sample 925: Predicted=0, True=0
# Sample 926: Predicted=0, True=0
# Sample 927: Predicted=0, True=0
# Sample 928: Predicted=8, True=8
# Sample 929: Predicted=8, True=8
# Sample 930: Predicted=4, True=4
# Sample 931: Predicted=4, True=4
# Sample 932: Predicted=4, True=4
# Sample 933: Predicted=4, True=4
# Sample 934: Predicted=4, True=4
# Sample 935: Predicted=4, True=4
# Sample 936: Predicted=4, True=4
# Sample 937: Predicted=4, True=4
# Sample 938: Predicted=4, True=4
# Sample 939: Predicted=4, True=4
# Sample 940: Predicted=4, True=4
# Sample 941: Predicted=4, True=4
# Sample 942: Predicted=4, True=4
# Sample 943: Predicted=0, True=0
# Sample 944: Predicted=0, True=0
# Sample 945: Predicted=0, True=0
# Sample 946: Predicted=0, True=0
# Sample 947: Predicted=0, True=0
# Sample 948: Predicted=0, True=0
# Sample 949: Predicted=0, True=0
# Sample 950: Predicted=0, True=0
# Sample 951: Predicted=0, True=0
# Sample 952: Predicted=0, True=0
# Sample 953: Predicted=8, True=8
# Sample 954: Predicted=8, True=8
# Sample 955: Predicted=4, True=4
# Sample 956: Predicted=4, True=4
# Sample 957: Predicted=4, True=4
# Sample 958: Predicted=4, True=4
# Sample 959: Predicted=4, True=4
# Sample 960: Predicted=4, True=4
# Sample 961: Predicted=4, True=4
# Sample 962: Predicted=4, True=4
# Sample 963: Predicted=4, True=4
# Sample 964: Predicted=4, True=4
# Sample 965: Predicted=4, True=4
# Sample 966: Predicted=4, True=4
# Sample 967: Predicted=4, True=4
# Sample 968: Predicted=0, True=0
# Sample 969: Predicted=0, True=0
# Sample 970: Predicted=0, True=0
# Sample 971: Predicted=0, True=0
# Sample 972: Predicted=0, True=0
# Sample 973: Predicted=0, True=0
# Sample 974: Predicted=0, True=0
# Sample 975: Predicted=8, True=8
# Sample 976: Predicted=8, True=8
# Sample 977: Predicted=4, True=4
# Sample 978: Predicted=4, True=4
# Sample 979: Predicted=4, True=4
# Sample 980: Predicted=4, True=4
# Sample 981: Predicted=4, True=4
# Sample 982: Predicted=4, True=4
# Sample 983: Predicted=4, True=4
# Sample 984: Predicted=4, True=4
# Sample 985: Predicted=4, True=4
# Sample 986: Predicted=4, True=4
# Sample 987: Predicted=4, True=4
# Sample 988: Predicted=4, True=4
# Sample 989: Predicted=4, True=4
# Sample 990: Predicted=0, True=0
# Sample 991: Predicted=0, True=0
# Sample 992: Predicted=0, True=0
# Sample 993: Predicted=0, True=0
# Sample 994: Predicted=0, True=0
# Sample 995: Predicted=0, True=0
# Sample 996: Predicted=8, True=8
# Sample 997: Predicted=8, True=8
# Sample 998: Predicted=4, True=4
# Sample 999: Predicted=4, True=4
# Sample 1000: Predicted=4, True=4
# Sample 1001: Predicted=4, True=4
# Sample 1002: Predicted=4, True=4
# Sample 1003: Predicted=4, True=4
# Sample 1004: Predicted=4, True=4
# Sample 1005: Predicted=4, True=4
# Sample 1006: Predicted=4, True=4
# Sample 1007: Predicted=4, True=4
# Sample 1008: Predicted=4, True=4
# Sample 1009: Predicted=4, True=4
# Sample 1010: Predicted=4, True=4
# Sample 1011: Predicted=0, True=0
# Sample 1012: Predicted=0, True=0
# Sample 1013: Predicted=0, True=0
# Sample 1014: Predicted=8, True=8
# Sample 1015: Predicted=8, True=8
# Sample 1016: Predicted=4, True=4
# Sample 1017: Predicted=4, True=4
# Sample 1018: Predicted=4, True=4
# Sample 1019: Predicted=4, True=4
# Sample 1020: Predicted=4, True=4
# Sample 1021: Predicted=4, True=4
# Sample 1022: Predicted=4, True=4
# Sample 1023: Predicted=4, True=4
# Sample 1024: Predicted=4, True=4
# Sample 1025: Predicted=4, True=4
# Sample 1026: Predicted=4, True=4
# Sample 1027: Predicted=4, True=4
# Sample 1028: Predicted=4, True=4
# Sample 1029: Predicted=0, True=0
# Sample 1030: Predicted=8, True=8
# Sample 1031: Predicted=8, True=8
# Sample 1032: Predicted=4, True=4
# Sample 1033: Predicted=4, True=4
# Sample 1034: Predicted=4, True=4
# Sample 1035: Predicted=4, True=4
# Sample 1036: Predicted=4, True=4
# Sample 1037: Predicted=4, True=4
# Sample 1038: Predicted=4, True=4
# Sample 1039: Predicted=4, True=4
# Sample 1040: Predicted=4, True=4
# Sample 1041: Predicted=4, True=4
# Sample 1042: Predicted=4, True=4
# Sample 1043: Predicted=4, True=4
# Sample 1044: Predicted=4, True=4
# Sample 1045: Predicted=8, True=8
# Sample 1046: Predicted=8, True=8
# Sample 1047: Predicted=4, True=4
# Sample 1048: Predicted=4, True=4
# Sample 1049: Predicted=4, True=4
# Sample 1050: Predicted=4, True=4
# Sample 1051: Predicted=4, True=4
# Sample 1052: Predicted=4, True=4
# Sample 1053: Predicted=4, True=4
# Sample 1054: Predicted=4, True=4
# Sample 1055: Predicted=4, True=4
# Sample 1056: Predicted=4, True=4
# Sample 1057: Predicted=4, True=4
# Sample 1058: Predicted=4, True=4
# Sample 1059: Predicted=4, True=4
# Sample 1060: Predicted=8, True=8
# Sample 1061: Predicted=8, True=8
# Sample 1062: Predicted=8, True=8
# Sample 1063: Predicted=4, True=4
# Sample 1064: Predicted=4, True=4
# Sample 1065: Predicted=4, True=4
# Sample 1066: Predicted=4, True=4
# Sample 1067: Predicted=4, True=4
# Sample 1068: Predicted=4, True=4
# Sample 1069: Predicted=4, True=4
# Sample 1070: Predicted=4, True=4
# Sample 1071: Predicted=4, True=4
# Sample 1072: Predicted=4, True=4
# Sample 1073: Predicted=4, True=4
# Sample 1074: Predicted=4, True=4
# Sample 1075: Predicted=4, True=4
# Sample 1076: Predicted=8, True=8
# Sample 1077: Predicted=8, True=8
# Sample 1078: Predicted=4, True=4
# Sample 1079: Predicted=4, True=4
# Sample 1080: Predicted=4, True=4
# Sample 1081: Predicted=4, True=4
# Sample 1082: Predicted=4, True=4
# Sample 1083: Predicted=4, True=4
# Sample 1084: Predicted=4, True=4
# Sample 1085: Predicted=4, True=4
# Sample 1086: Predicted=4, True=4
# Sample 1087: Predicted=4, True=4
# Sample 1088: Predicted=4, True=4
# Sample 1089: Predicted=4, True=4
# Sample 1090: Predicted=4, True=4
# Sample 1091: Predicted=8, True=8
# Sample 1092: Predicted=8, True=8
# Sample 1093: Predicted=4, True=4
# Sample 1094: Predicted=4, True=4
# Sample 1095: Predicted=4, True=4
# Sample 1096: Predicted=4, True=4
# Sample 1097: Predicted=4, True=4
# Sample 1098: Predicted=4, True=4
# Sample 1099: Predicted=4, True=4
# Sample 1100: Predicted=4, True=4
# Sample 1101: Predicted=4, True=4
# Sample 1102: Predicted=4, True=4
# Sample 1103: Predicted=4, True=4
# Sample 1104: Predicted=4, True=4
# Sample 1105: Predicted=4, True=4
# Sample 1106: Predicted=8, True=8
# Sample 1107: Predicted=8, True=8
# Sample 1108: Predicted=8, True=8
# Sample 1109: Predicted=4, True=4
# Sample 1110: Predicted=4, True=4
# Sample 1111: Predicted=4, True=4
# Sample 1112: Predicted=4, True=4
# Sample 1113: Predicted=4, True=4
# Sample 1114: Predicted=4, True=4
# Sample 1115: Predicted=4, True=4
# Sample 1116: Predicted=4, True=4
# Sample 1117: Predicted=4, True=4
# Sample 1118: Predicted=4, True=4
# Sample 1119: Predicted=4, True=4
# Sample 1120: Predicted=4, True=4
# Sample 1121: Predicted=4, True=4
# Sample 1122: Predicted=8, True=8
# Sample 1123: Predicted=8, True=8
# Sample 1124: Predicted=4, True=4
# Sample 1125: Predicted=4, True=4
# Sample 1126: Predicted=4, True=4
# Sample 1127: Predicted=4, True=4
# Sample 1128: Predicted=4, True=4
# Sample 1129: Predicted=4, True=4
# Sample 1130: Predicted=4, True=4
# Sample 1131: Predicted=4, True=4
# Sample 1132: Predicted=4, True=4
# Sample 1133: Predicted=4, True=4
# Sample 1134: Predicted=4, True=4
# Sample 1135: Predicted=4, True=4
# Sample 1136: Predicted=4, True=4
# Sample 1137: Predicted=8, True=8
# Sample 1138: Predicted=8, True=8
# Sample 1139: Predicted=4, True=4
# Sample 1140: Predicted=4, True=4
# Sample 1141: Predicted=4, True=4
# Sample 1142: Predicted=4, True=4
# Sample 1143: Predicted=4, True=4
# Sample 1144: Predicted=4, True=4
# Sample 1145: Predicted=4, True=4
# Sample 1146: Predicted=4, True=4
# Sample 1147: Predicted=4, True=4
# Sample 1148: Predicted=4, True=4
# Sample 1149: Predicted=4, True=4
# Sample 1150: Predicted=4, True=4
# Sample 1151: Predicted=4, True=4
# Sample 1152: Predicted=8, True=8
# Sample 1153: Predicted=8, True=8
# Sample 1154: Predicted=8, True=8
# Sample 1155: Predicted=4, True=4
# Sample 1156: Predicted=4, True=4
# Sample 1157: Predicted=4, True=4
# Sample 1158: Predicted=4, True=4
# Sample 1159: Predicted=4, True=4
# Sample 1160: Predicted=4, True=4
# Sample 1161: Predicted=4, True=4
# Sample 1162: Predicted=4, True=4
# Sample 1163: Predicted=4, True=4
# Sample 1164: Predicted=4, True=4
# Sample 1165: Predicted=4, True=4
# Sample 1166: Predicted=4, True=4
# Sample 1167: Predicted=4, True=4
# Sample 1168: Predicted=4, True=4
# Sample 1169: Predicted=1, True=0
# Sample 1170: Predicted=8, True=8
# Sample 1171: Predicted=8, True=8
# Sample 1172: Predicted=4, True=4
# Sample 1173: Predicted=4, True=4
# Sample 1174: Predicted=4, True=4
# Sample 1175: Predicted=4, True=4
# Sample 1176: Predicted=4, True=4
# Sample 1177: Predicted=4, True=4
# Sample 1178: Predicted=4, True=4
# Sample 1179: Predicted=4, True=4
# Sample 1180: Predicted=4, True=4
# Sample 1181: Predicted=4, True=4
# Sample 1182: Predicted=4, True=4
# Sample 1183: Predicted=4, True=4
# Sample 1184: Predicted=4, True=4
# Sample 1185: Predicted=4, True=4
# Sample 1186: Predicted=4, True=4
# Sample 1187: Predicted=8, True=4
# Sample 1188: Predicted=0, True=0
# Sample 1189: Predicted=0, True=0
# Sample 1190: Predicted=1, True=0
# Sample 1191: Predicted=8, True=8
# Sample 1192: Predicted=8, True=8
# Sample 1193: Predicted=4, True=4
# Sample 1194: Predicted=4, True=4
# Sample 1195: Predicted=4, True=4
# Sample 1196: Predicted=4, True=4
# Sample 1197: Predicted=4, True=4
# Sample 1198: Predicted=4, True=4
# Sample 1199: Predicted=4, True=4
# Sample 1200: Predicted=4, True=4
# Sample 1201: Predicted=4, True=4
# Sample 1202: Predicted=4, True=4
# Sample 1203: Predicted=4, True=4
# Sample 1204: Predicted=4, True=4
# Sample 1205: Predicted=4, True=4
# Sample 1206: Predicted=4, True=4
# Sample 1207: Predicted=4, True=4
# Sample 1208: Predicted=4, True=4
# Sample 1209: Predicted=8, True=4
# Sample 1210: Predicted=8, True=4
# Sample 1211: Predicted=0, True=0
# Sample 1212: Predicted=0, True=0
# Sample 1213: Predicted=0, True=0
# Sample 1214: Predicted=0, True=0
# Sample 1215: Predicted=0, True=0
# Sample 1216: Predicted=1, True=1
# Sample 1217: Predicted=8, True=8
# Sample 1218: Predicted=8, True=8
# Sample 1219: Predicted=8, True=8
# Sample 1220: Predicted=4, True=4
# Sample 1221: Predicted=4, True=4
# Sample 1222: Predicted=4, True=4
# Sample 1223: Predicted=4, True=4
# Sample 1224: Predicted=4, True=4
# Sample 1225: Predicted=4, True=4
# Sample 1226: Predicted=4, True=4
# Sample 1227: Predicted=4, True=4
# Sample 1228: Predicted=4, True=4
# Sample 1229: Predicted=4, True=4
# Sample 1230: Predicted=4, True=4
# Sample 1231: Predicted=4, True=4
# Sample 1232: Predicted=4, True=4
# Sample 1233: Predicted=4, True=4
# Sample 1234: Predicted=4, True=4
# Sample 1235: Predicted=4, True=4
# Sample 1236: Predicted=4, True=4
# Sample 1237: Predicted=8, True=4
# Sample 1238: Predicted=8, True=4
# Sample 1239: Predicted=0, True=0
# Sample 1240: Predicted=0, True=0
# Sample 1241: Predicted=0, True=0
# Sample 1242: Predicted=0, True=0
# Sample 1243: Predicted=0, True=0
# Sample 1244: Predicted=0, True=0
# Sample 1245: Predicted=0, True=0
# Sample 1246: Predicted=1, True=1
# Sample 1247: Predicted=1, True=1
# Sample 1248: Predicted=8, True=8
# Sample 1249: Predicted=4, True=4
# Sample 1250: Predicted=4, True=4
# Sample 1251: Predicted=4, True=4
# Sample 1252: Predicted=4, True=4
# Sample 1253: Predicted=4, True=4
# Sample 1254: Predicted=4, True=4
# Sample 1255: Predicted=4, True=4
# Sample 1256: Predicted=4, True=4
# Sample 1257: Predicted=4, True=4
# Sample 1258: Predicted=4, True=4
# Sample 1259: Predicted=4, True=4
# Sample 1260: Predicted=4, True=4
# Sample 1261: Predicted=4, True=4
# Sample 1262: Predicted=4, True=4
# Sample 1263: Predicted=4, True=4
# Sample 1264: Predicted=4, True=4
# Sample 1265: Predicted=4, True=4
# Sample 1266: Predicted=13, True=4
# Sample 1267: Predicted=13, True=4
# Sample 1268: Predicted=0, True=0
# Sample 1269: Predicted=0, True=0
# Sample 1270: Predicted=0, True=0
# Sample 1271: Predicted=0, True=0
# Sample 1272: Predicted=0, True=0
# Sample 1273: Predicted=0, True=0
# Sample 1274: Predicted=0, True=0
# Sample 1275: Predicted=0, True=0
# Sample 1276: Predicted=1, True=1
# Sample 1277: Predicted=1, True=1
# Sample 1278: Predicted=1, True=1
# Sample 1279: Predicted=3, True=1
# Sample 1280: Predicted=4, True=4
# Sample 1281: Predicted=4, True=4
# Sample 1282: Predicted=4, True=4
# Sample 1283: Predicted=4, True=4
# Sample 1284: Predicted=4, True=4
# Sample 1285: Predicted=4, True=4
# Sample 1286: Predicted=4, True=4
# Sample 1287: Predicted=4, True=4
# Sample 1288: Predicted=4, True=4
# Sample 1289: Predicted=4, True=4
# Sample 1290: Predicted=4, True=4
# Sample 1291: Predicted=4, True=4
# Sample 1292: Predicted=4, True=4
# Sample 1293: Predicted=4, True=4
# Sample 1294: Predicted=4, True=4
# Sample 1295: Predicted=4, True=4
# Sample 1296: Predicted=4, True=4
# Sample 1297: Predicted=4, True=4
# Sample 1298: Predicted=13, True=4
# Sample 1299: Predicted=0, True=0
# Sample 1300: Predicted=0, True=0
# Sample 1301: Predicted=0, True=0
# Sample 1302: Predicted=0, True=0
# Sample 1303: Predicted=0, True=0
# Sample 1304: Predicted=0, True=0
# Sample 1305: Predicted=0, True=0
# Sample 1306: Predicted=0, True=0
# Sample 1307: Predicted=0, True=0
# Sample 1308: Predicted=0, True=0
# Sample 1309: Predicted=3, True=1
# Sample 1310: Predicted=1, True=1
# Sample 1311: Predicted=3, True=1
# Sample 1312: Predicted=4, True=4
# Sample 1313: Predicted=4, True=4
# Sample 1314: Predicted=4, True=4
# Sample 1315: Predicted=4, True=4
# Sample 1316: Predicted=4, True=4
# Sample 1317: Predicted=4, True=4
# Sample 1318: Predicted=4, True=4
# Sample 1319: Predicted=4, True=4
# Sample 1320: Predicted=4, True=4
# Sample 1321: Predicted=4, True=4
# Sample 1322: Predicted=4, True=4
# Sample 1323: Predicted=4, True=4
# Sample 1324: Predicted=4, True=4
# Sample 1325: Predicted=4, True=4
# Sample 1326: Predicted=4, True=4
# Sample 1327: Predicted=4, True=4
# Sample 1328: Predicted=4, True=4
# Sample 1329: Predicted=4, True=4
# Sample 1330: Predicted=13, True=4
# Sample 1331: Predicted=0, True=0
# Sample 1332: Predicted=0, True=0
# Sample 1333: Predicted=0, True=0
# Sample 1334: Predicted=0, True=0
# Sample 1335: Predicted=0, True=0
# Sample 1336: Predicted=0, True=0
# Sample 1337: Predicted=0, True=0
# Sample 1338: Predicted=0, True=0
# Sample 1339: Predicted=0, True=0
# Sample 1340: Predicted=0, True=0
# Sample 1341: Predicted=0, True=0
# Sample 1342: Predicted=4, True=4
# Sample 1343: Predicted=4, True=4
# Sample 1344: Predicted=4, True=4
# Sample 1345: Predicted=4, True=4
# Sample 1346: Predicted=4, True=4
# Sample 1347: Predicted=4, True=4
# Sample 1348: Predicted=4, True=4
# Sample 1349: Predicted=4, True=4
# Sample 1350: Predicted=4, True=4
# Sample 1351: Predicted=4, True=4
# Sample 1352: Predicted=4, True=4
# Sample 1353: Predicted=4, True=4
# Sample 1354: Predicted=4, True=4
# Sample 1355: Predicted=4, True=4
# Sample 1356: Predicted=4, True=4
# Sample 1357: Predicted=4, True=4
# Sample 1358: Predicted=4, True=4
# Sample 1359: Predicted=4, True=4
# Sample 1360: Predicted=4, True=4
# Sample 1361: Predicted=0, True=0
# Sample 1362: Predicted=0, True=0
# Sample 1363: Predicted=0, True=0
# Sample 1364: Predicted=0, True=0
# Sample 1365: Predicted=0, True=0
# Sample 1366: Predicted=0, True=0
# Sample 1367: Predicted=0, True=0
# Sample 1368: Predicted=0, True=0
# Sample 1369: Predicted=0, True=0
# Sample 1370: Predicted=0, True=0
# Sample 1371: Predicted=0, True=0
# Sample 1372: Predicted=4, True=4
# Sample 1373: Predicted=4, True=4
# Sample 1374: Predicted=4, True=4
# Sample 1375: Predicted=4, True=4
# Sample 1376: Predicted=4, True=4
# Sample 1377: Predicted=4, True=4
# Sample 1378: Predicted=4, True=4
# Sample 1379: Predicted=4, True=4
# Sample 1380: Predicted=4, True=4
# Sample 1381: Predicted=4, True=4
# Sample 1382: Predicted=4, True=4
# Sample 1383: Predicted=4, True=4
# Sample 1384: Predicted=4, True=4
# Sample 1385: Predicted=4, True=4
# Sample 1386: Predicted=4, True=4
# Sample 1387: Predicted=4, True=4
# Sample 1388: Predicted=4, True=4
# Sample 1389: Predicted=4, True=4
# Sample 1390: Predicted=13, True=4
# Sample 1391: Predicted=0, True=0
# Sample 1392: Predicted=0, True=0
# Sample 1393: Predicted=0, True=0
# Sample 1394: Predicted=0, True=0
# Sample 1395: Predicted=0, True=0
# Sample 1396: Predicted=0, True=0
# Sample 1397: Predicted=0, True=0
# Sample 1398: Predicted=0, True=0
# Sample 1399: Predicted=0, True=0
# Sample 1400: Predicted=0, True=0
# Sample 1401: Predicted=4, True=4
# Sample 1402: Predicted=4, True=4
# Sample 1403: Predicted=4, True=4
# Sample 1404: Predicted=4, True=4
# Sample 1405: Predicted=4, True=4
# Sample 1406: Predicted=4, True=4
# Sample 1407: Predicted=4, True=4
# Sample 1408: Predicted=4, True=4
# Sample 1409: Predicted=4, True=4
# Sample 1410: Predicted=4, True=4
# Sample 1411: Predicted=4, True=4
# Sample 1412: Predicted=4, True=4
# Sample 1413: Predicted=4, True=4
# Sample 1414: Predicted=4, True=4
# Sample 1415: Predicted=4, True=4
# Sample 1416: Predicted=4, True=4
# Sample 1417: Predicted=4, True=4
# Sample 1418: Predicted=4, True=4
# Sample 1419: Predicted=13, True=4
# Sample 1420: Predicted=0, True=0
# Sample 1421: Predicted=0, True=0
# Sample 1422: Predicted=0, True=0
# Sample 1423: Predicted=0, True=0
# Sample 1424: Predicted=0, True=0
# Sample 1425: Predicted=0, True=0
# Sample 1426: Predicted=0, True=0
# Sample 1427: Predicted=0, True=0
# Sample 1428: Predicted=0, True=0
# Sample 1429: Predicted=0, True=0
# Sample 1430: Predicted=0, True=0
# Sample 1431: Predicted=4, True=4
# Sample 1432: Predicted=4, True=4
# Sample 1433: Predicted=4, True=4
# Sample 1434: Predicted=4, True=4
# Sample 1435: Predicted=4, True=4
# Sample 1436: Predicted=4, True=4
# Sample 1437: Predicted=4, True=4
# Sample 1438: Predicted=4, True=4
# Sample 1439: Predicted=4, True=4
# Sample 1440: Predicted=4, True=4
# Sample 1441: Predicted=4, True=4
# Sample 1442: Predicted=4, True=4
# Sample 1443: Predicted=4, True=4
# Sample 1444: Predicted=4, True=4
# Sample 1445: Predicted=4, True=4
# Sample 1446: Predicted=4, True=4
# Sample 1447: Predicted=4, True=4
# Sample 1448: Predicted=4, True=4
# Sample 1449: Predicted=13, True=4
# Sample 1450: Predicted=0, True=0
# Sample 1451: Predicted=0, True=0
# Sample 1452: Predicted=0, True=0
# Sample 1453: Predicted=0, True=0
# Sample 1454: Predicted=0, True=0
# Sample 1455: Predicted=0, True=0
# Sample 1456: Predicted=0, True=0
# Sample 1457: Predicted=0, True=0
# Sample 1458: Predicted=0, True=0
# Sample 1459: Predicted=0, True=0
# Sample 1460: Predicted=0, True=0
# ...
# Sample 11733: Predicted=9, True=9
# Sample 11734: Predicted=9, True=9
# Sample 11735: Predicted=10, True=9
# Sample 11736: Predicted=10, True=9
# Sample 11737: Predicted=10, True=9
# Sample 11738: Predicted=9, True=9
# Sample 11739: Predicted=9, True=9
# Sample 11740: Predicted=10, True=9
# Sample 11741: Predicted=10, True=9
# Sample 11742: Predicted=9, True=8
# Sample 11743: Predicted=9, True=8
# Sample 11744: Predicted=8, True=8
# Sample 11745: Predicted=9, True=8
# Sample 11746: Predicted=9, True=9
# Sample 11747: Predicted=9, True=9
# Sample 11748: Predicted=9, True=9
# Sample 11749: Predicted=10, True=9
# Sample 11750: Predicted=10, True=9
# Sample 11751: Predicted=3, True=3
# Sample 11752: Predicted=3, True=3
# Sample 11753: Predicted=3, True=3
# Sample 11754: Predicted=3, True=3
# Sample 11755: Predicted=3, True=3
# Sample 11756: Predicted=3, True=3
# Sample 11757: Predicted=11, True=8
# Sample 11758: Predicted=9, True=8
# Sample 11759: Predicted=8, True=8
# Sample 11760: Predicted=8, True=8
# Sample 11761: Predicted=9, True=9
# Sample 11762: Predicted=9, True=9
# Sample 11763: Predicted=10, True=9
# Sample 11764: Predicted=10, True=9
# Sample 11765: Predicted=10, True=9
# Sample 11766: Predicted=3, True=3
# Sample 11767: Predicted=3, True=3
# Sample 11768: Predicted=3, True=3
# Sample 11769: Predicted=3, True=3
# Sample 11770: Predicted=3, True=3
# Sample 11771: Predicted=3, True=3
# Sample 11772: Predicted=11, True=8
# Sample 11773: Predicted=11, True=8
# Sample 11774: Predicted=8, True=8
# Sample 11775: Predicted=8, True=8
# Sample 11776: Predicted=9, True=9
# Sample 11777: Predicted=10, True=9
# Sample 11778: Predicted=10, True=9
# Sample 11779: Predicted=10, True=9
# Sample 11780: Predicted=9, True=9
# Sample 11781: Predicted=3, True=3
# Sample 11782: Predicted=3, True=3
# Sample 11783: Predicted=3, True=3
# Sample 11784: Predicted=3, True=3
# Sample 11785: Predicted=3, True=3
# Sample 11786: Predicted=3, True=3
# Sample 11787: Predicted=9, True=9
# Sample 11788: Predicted=9, True=9
# Sample 11789: Predicted=10, True=9
# Sample 11790: Predicted=10, True=9
# Sample 11791: Predicted=3, True=1
# Sample 11792: Predicted=1, True=1
# Sample 11793: Predicted=1, True=1
# Sample 11794: Predicted=1, True=1
# Sample 11795: Predicted=1, True=1
# Sample 11796: Predicted=3, True=3
# Sample 11797: Predicted=3, True=3
# Sample 11798: Predicted=3, True=3
# Sample 11799: Predicted=3, True=3
# Sample 11800: Predicted=3, True=3
# Sample 11801: Predicted=3, True=3
# Sample 11802: Predicted=10, True=9
# Sample 11803: Predicted=3, True=1
# Sample 11804: Predicted=1, True=1
# Sample 11805: Predicted=1, True=1
# Sample 11806: Predicted=1, True=1
# Sample 11807: Predicted=1, True=1
# Sample 11808: Predicted=3, True=3
# Sample 11809: Predicted=3, True=3
# Sample 11810: Predicted=3, True=3
# Sample 11811: Predicted=3, True=3
# Sample 11812: Predicted=3, True=3
# Sample 11813: Predicted=3, True=3
# Sample 11814: Predicted=10, True=9
# Sample 11815: Predicted=10, True=9
# Sample 11816: Predicted=10, True=9
# Sample 11817: Predicted=7, True=9
# Sample 11818: Predicted=3, True=1
# Sample 11819: Predicted=1, True=1
# Sample 11820: Predicted=1, True=1
# Sample 11821: Predicted=1, True=1
# Sample 11822: Predicted=1, True=1
# Sample 11823: Predicted=3, True=3
# Sample 11824: Predicted=3, True=3
# Sample 11825: Predicted=3, True=3
# Sample 11826: Predicted=3, True=3
# Sample 11827: Predicted=3, True=3
# Sample 11828: Predicted=3, True=3
# Sample 11829: Predicted=9, True=9
# Sample 11830: Predicted=10, True=9
# Sample 11831: Predicted=10, True=9
# Sample 11832: Predicted=10, True=9
# Sample 11833: Predicted=3, True=1
# Sample 11834: Predicted=1, True=1
# Sample 11835: Predicted=1, True=1
# Sample 11836: Predicted=1, True=1
# Sample 11837: Predicted=1, True=1
# Sample 11838: Predicted=9, True=9
# Sample 11839: Predicted=10, True=9
# Sample 11840: Predicted=10, True=9
# Sample 11841: Predicted=7, True=9
# Sample 11842: Predicted=3, True=1
# Sample 11843: Predicted=1, True=1
# Sample 11844: Predicted=1, True=1
# Sample 11845: Predicted=1, True=1
# Sample 11846: Predicted=1, True=1
# Sample 11847: Predicted=9, True=9
# Sample 11848: Predicted=9, True=9
# Sample 11849: Predicted=10, True=9
# Sample 11850: Predicted=7, True=9
# Sample 11851: Predicted=3, True=1
# Sample 11852: Predicted=1, True=1
# Sample 11853: Predicted=1, True=1
# Sample 11854: Predicted=1, True=1
# Sample 11855: Predicted=1, True=1
# Sample 11856: Predicted=9, True=9
# Sample 11857: Predicted=9, True=9
# Sample 11858: Predicted=7, True=9
# Sample 11859: Predicted=7, True=9
# Sample 11860: Predicted=3, True=1
# Sample 11861: Predicted=1, True=1
# Sample 11862: Predicted=1, True=1
# Sample 11863: Predicted=1, True=1
# Sample 11864: Predicted=1, True=1
# Sample 11865: Predicted=3, True=1
# Sample 11866: Predicted=1, True=1
# Sample 11867: Predicted=1, True=1
# Sample 11868: Predicted=1, True=1
# Sample 11869: Predicted=1, True=1
# Sample 11870: Predicted=3, True=1
# Sample 11871: Predicted=1, True=1
# Sample 11872: Predicted=1, True=1
# Sample 11873: Predicted=1, True=1
# Sample 11874: Predicted=1, True=1
# Sample 11875: Predicted=3, True=1
# Sample 11876: Predicted=1, True=1
# Sample 11877: Predicted=1, True=1
# Sample 11878: Predicted=1, True=1
# Sample 11879: Predicted=1, True=1
# Sample 11880: Predicted=7, True=7
# Sample 11881: Predicted=7, True=7
# Sample 11882: Predicted=7, True=7
# Sample 11883: Predicted=7, True=7
# Sample 11884: Predicted=7, True=7
# Sample 11885: Predicted=11, True=9
# Sample 11886: Predicted=7, True=7
# Sample 11887: Predicted=7, True=7
# Sample 11888: Predicted=7, True=7
# Sample 11889: Predicted=7, True=7
# Sample 11890: Predicted=7, True=7
# Sample 11891: Predicted=9, True=9
# Sample 11892: Predicted=9, True=9
# Sample 11893: Predicted=11, True=9
# Sample 11894: Predicted=11, True=9
# Sample 11895: Predicted=7, True=9
# Sample 11896: Predicted=7, True=9
# Sample 11897: Predicted=7, True=9
# Sample 11898: Predicted=9, True=9
# Sample 11899: Predicted=7, True=7
# Sample 11900: Predicted=7, True=7
# Sample 11901: Predicted=7, True=7
# Sample 11902: Predicted=7, True=7
# Sample 11903: Predicted=7, True=7
# Sample 11904: Predicted=9, True=9
# Sample 11905: Predicted=9, True=9
# Sample 11906: Predicted=9, True=9
# Sample 11907: Predicted=9, True=9
# Sample 11908: Predicted=10, True=9
# Sample 11909: Predicted=10, True=9
# Sample 11910: Predicted=7, True=9
# Sample 11911: Predicted=7, True=9
# Sample 11912: Predicted=7, True=9
# Sample 11913: Predicted=7, True=7
# Sample 11914: Predicted=7, True=7
# Sample 11915: Predicted=7, True=7
# Sample 11916: Predicted=12, True=7
# Sample 11917: Predicted=12, True=7
# Sample 11918: Predicted=9, True=9
# Sample 11919: Predicted=9, True=9
# Sample 11920: Predicted=9, True=9
# Sample 11921: Predicted=10, True=9
# Sample 11922: Predicted=9, True=9
# Sample 11923: Predicted=10, True=9
# Sample 11924: Predicted=10, True=9
# Sample 11925: Predicted=7, True=9
# Sample 11926: Predicted=7, True=9
# Sample 11927: Predicted=9, True=9
# Sample 11928: Predicted=9, True=9
# Sample 11929: Predicted=9, True=9
# Sample 11930: Predicted=9, True=9
# Sample 11931: Predicted=9, True=9
# Sample 11932: Predicted=10, True=9
# Sample 11933: Predicted=10, True=9
# Sample 11934: Predicted=7, True=9
# Sample 11935: Predicted=9, True=9
# Sample 11936: Predicted=9, True=9
# Sample 11937: Predicted=9, True=9
# Sample 11938: Predicted=10, True=9
# Sample 11939: Predicted=9, True=9
# Sample 11940: Predicted=9, True=9
# Sample 11941: Predicted=9, True=9
# Sample 11942: Predicted=10, True=9
# Sample 11943: Predicted=7, True=9
# Sample 11944: Predicted=9, True=9
# Sample 11945: Predicted=9, True=9
# Sample 11946: Predicted=10, True=9
# Sample 11947: Predicted=7, True=9
# Sample 11948: Predicted=9, True=9
# Sample 11949: Predicted=9, True=9
# Sample 11950: Predicted=10, True=9
# Sample 11951: Predicted=7, True=9
# Sample 11952: Predicted=9, True=9
# Sample 11953: Predicted=10, True=9
# Sample 11954: Predicted=10, True=9
# Sample 11955: Predicted=7, True=9
# Sample 11956: Predicted=9, True=9
# Sample 11957: Predicted=10, True=9
# Sample 11958: Predicted=11, True=7
# Sample 11959: Predicted=11, True=7
# Sample 11960: Predicted=11, True=7
# Sample 11961: Predicted=11, True=7
# Sample 11962: Predicted=11, True=7
# Sample 11963: Predicted=11, True=7
# Sample 11964: Predicted=11, True=7
# Sample 11965: Predicted=7, True=7
# Sample 11966: Predicted=7, True=7
# Sample 11967: Predicted=11, True=7
# Sample 11968: Predicted=11, True=7
# Sample 11969: Predicted=11, True=7
# Sample 11970: Predicted=11, True=7
# Sample 11971: Predicted=7, True=7
# Sample 11972: Predicted=11, True=7
# Sample 11973: Predicted=11, True=7
# Sample 11974: Predicted=11, True=7
# Sample 11975: Predicted=11, True=7
# Sample 11976: Predicted=13, True=8
# Sample 11977: Predicted=1, True=8
# Sample 11978: Predicted=11, True=7
# Sample 11979: Predicted=7, True=7
# Sample 11980: Predicted=11, True=7
# Sample 11981: Predicted=11, True=7
# Sample 11982: Predicted=11, True=7
# Sample 11983: Predicted=11, True=7
# Sample 11984: Predicted=6, True=6
# Sample 11985: Predicted=12, True=6
# Sample 11986: Predicted=13, True=8
# Sample 11987: Predicted=13, True=8
# Sample 11988: Predicted=13, True=8
# Sample 11989: Predicted=13, True=8
# Sample 11990: Predicted=1, True=8
# Sample 11991: Predicted=11, True=7
# Sample 11992: Predicted=7, True=7
# Sample 11993: Predicted=11, True=7
# Sample 11994: Predicted=11, True=7
# Sample 11995: Predicted=11, True=7
# Sample 11996: Predicted=11, True=7
# Sample 11997: Predicted=6, True=6
# Sample 11998: Predicted=6, True=6
# Sample 11999: Predicted=12, True=6
# Sample 12000: Predicted=12, True=6
# Sample 12001: Predicted=10, True=8
# Sample 12002: Predicted=13, True=8
# Sample 12003: Predicted=13, True=8
# Sample 12004: Predicted=8, True=8
# Sample 12005: Predicted=8, True=8
# Sample 12006: Predicted=1, True=8
# Sample 12007: Predicted=11, True=7
# Sample 12008: Predicted=11, True=7
# Sample 12009: Predicted=11, True=7
# Sample 12010: Predicted=11, True=7
# Sample 12011: Predicted=11, True=7
# Sample 12012: Predicted=11, True=7
# Sample 12013: Predicted=3, True=6
# Sample 12014: Predicted=6, True=6
# Sample 12015: Predicted=12, True=6
# Sample 12016: Predicted=10, True=8
# Sample 12017: Predicted=10, True=8
# Sample 12018: Predicted=10, True=8
# Sample 12019: Predicted=8, True=8
# Sample 12020: Predicted=6, True=6
# Sample 12021: Predicted=10, True=8
# Sample 12022: Predicted=11, True=7
# Sample 12023: Predicted=11, True=7
# Sample 12024: Predicted=11, True=7
# Sample 12025: Predicted=11, True=7
# Sample 12026: Predicted=11, True=7
# Sample 12027: Predicted=11, True=7
# Sample 12028: Predicted=11, True=7
# Sample 12029: Predicted=11, True=7
# Sample 12030: Predicted=11, True=7
# Sample 12031: Predicted=11, True=7
# Sample 12032: Predicted=11, True=7
# Sample 12033: Predicted=11, True=7
# Sample 12034: Predicted=11, True=7
# Sample 12035: Predicted=11, True=7
# Sample 12036: Predicted=11, True=7
# Sample 12037: Predicted=11, True=7
# Sample 12038: Predicted=11, True=7
# Sample 12039: Predicted=11, True=7
# Sample 12040: Predicted=11, True=7
# Sample 12041: Predicted=11, True=7
# Sample 12042: Predicted=11, True=7
# Sample 12043: Predicted=11, True=7
# Sample 12044: Predicted=11, True=7
# Sample 12045: Predicted=11, True=7
# Sample 12046: Predicted=11, True=7
# Sample 12047: Predicted=11, True=7
# Sample 12048: Predicted=11, True=7
# Sample 12049: Predicted=11, True=7
# Sample 12050: Predicted=11, True=7
# Sample 12051: Predicted=11, True=7
# Sample 12052: Predicted=10, True=9
# Sample 12053: Predicted=10, True=9
# Sample 12054: Predicted=10, True=9
# Sample 12055: Predicted=10, True=9
# Sample 12056: Predicted=9, True=9
# Sample 12057: Predicted=9, True=9
# Sample 12058: Predicted=10, True=9
# Sample 12059: Predicted=10, True=9
# Sample 12060: Predicted=10, True=9
# Sample 12061: Predicted=10, True=9
# Sample 12062: Predicted=9, True=9
# Sample 12063: Predicted=10, True=9
# Sample 12064: Predicted=10, True=9
# Sample 12065: Predicted=10, True=9
# Sample 12066: Predicted=10, True=9
# Sample 12067: Predicted=9, True=9
# Sample 12068: Predicted=10, True=9
# Sample 12069: Predicted=10, True=9
# Sample 12070: Predicted=10, True=9
# Sample 12071: Predicted=10, True=9
# Sample 12072: Predicted=9, True=9
# Sample 12073: Predicted=10, True=9
# Sample 12074: Predicted=10, True=9
# Sample 12075: Predicted=10, True=9
# Sample 12076: Predicted=10, True=9
# Sample 12077: Predicted=11, True=9
# Sample 12078: Predicted=9, True=9
# Sample 12079: Predicted=9, True=9
# Sample 12080: Predicted=9, True=9
# Sample 12081: Predicted=11, True=9
# Sample 12082: Predicted=11, True=9
# Sample 12083: Predicted=11, True=9
# Sample 12084: Predicted=9, True=9
# Sample 12085: Predicted=9, True=9
# Sample 12086: Predicted=11, True=9
# Sample 12087: Predicted=11, True=9
# Sample 12088: Predicted=11, True=9
# Sample 12089: Predicted=11, True=9
# Sample 12090: Predicted=11, True=9
# Sample 12091: Predicted=9, True=9
# Sample 12092: Predicted=11, True=9
# Sample 12093: Predicted=11, True=9
# Sample 12094: Predicted=11, True=9
# Sample 12095: Predicted=11, True=9
# Sample 12096: Predicted=11, True=9
# Sample 12097: Predicted=9, True=9
# Sample 12098: Predicted=11, True=9
# Sample 12099: Predicted=11, True=9
# Sample 12100: Predicted=11, True=9
# Sample 12101: Predicted=11, True=9
# Sample 12102: Predicted=11, True=9
# Sample 12103: Predicted=10, True=8
# Sample 12104: Predicted=11, True=9
# Sample 12105: Predicted=11, True=9
# Sample 12106: Predicted=11, True=9
# Sample 12107: Predicted=11, True=9
# Sample 12108: Predicted=1, True=8
# Sample 12109: Predicted=13, True=8
# Sample 12110: Predicted=1, True=8
# Sample 12111: Predicted=10, True=8
# Sample 12112: Predicted=11, True=9
# Sample 12113: Predicted=11, True=9
# Sample 12114: Predicted=10, True=8
# Sample 12115: Predicted=10, True=8
# Sample 12116: Predicted=10, True=8
# Sample 12117: Predicted=8, True=8
# Sample 12118: Predicted=8, True=8
# Sample 12119: Predicted=10, True=8
# Sample 12120: Predicted=10, True=8
# Sample 12121: Predicted=10, True=8
# Sample 12122: Predicted=8, True=8
# Sample 12123: Predicted=6, True=6
# Sample 12124: Predicted=6, True=6
# Sample 12125: Predicted=6, True=6
# Sample 12126: Predicted=6, True=8
# Sample 12127: Predicted=6, True=6
# Sample 12128: Predicted=6, True=6
# Sample 12129: Predicted=6, True=6
# Sample 12130: Predicted=6, True=6
# Sample 12131: Predicted=6, True=6
# Sample 12132: Predicted=6, True=6
# Sample 12133: Predicted=6, True=6
# Sample 12134: Predicted=6, True=6
# Sample 12135: Predicted=6, True=6
# Sample 12136: Predicted=6, True=6
# Sample 12137: Predicted=6, True=6
# Sample 12138: Predicted=6, True=6
# Sample 12139: Predicted=11, True=9
# Sample 12140: Predicted=11, True=9
# Sample 12141: Predicted=11, True=9
# Sample 12142: Predicted=11, True=9
# Sample 12143: Predicted=11, True=9
# Sample 12144: Predicted=11, True=9
# Sample 12145: Predicted=11, True=9
# Sample 12146: Predicted=11, True=9
# Sample 12147: Predicted=11, True=9
# Sample 12148: Predicted=11, True=9
# Sample 12149: Predicted=11, True=9
# Sample 12150: Predicted=11, True=9
# Sample 12151: Predicted=11, True=9
# Sample 12152: Predicted=11, True=9
# Sample 12153: Predicted=11, True=9
# Sample 12154: Predicted=11, True=9
# Sample 12155: Predicted=11, True=9
# Sample 12156: Predicted=9, True=9
# Sample 12157: Predicted=11, True=9
# Sample 12158: Predicted=11, True=9
# Sample 12159: Predicted=10, True=8
# Sample 12160: Predicted=8, True=8
# Sample 12161: Predicted=9, True=8
# Sample 12162: Predicted=10, True=8
# Sample 12163: Predicted=10, True=8
# Sample 12164: Predicted=10, True=8
# Sample 12165: Predicted=8, True=8
# Sample 12166: Predicted=8, True=8
# Sample 12167: Predicted=8, True=8
# Sample 12168: Predicted=8, True=8
# Sample 12169: Predicted=9, True=8
# Sample 12170: Predicted=9, True=8
# Sample 12171: Predicted=10, True=8
# Sample 12172: Predicted=10, True=8
# Sample 12173: Predicted=10, True=8
# Sample 12174: Predicted=10, True=8
# Sample 12175: Predicted=10, True=8
# Sample 12176: Predicted=8, True=8
# Sample 12177: Predicted=8, True=8
# Sample 12178: Predicted=8, True=8
# Sample 12179: Predicted=9, True=8
# Sample 12180: Predicted=9, True=8
# Sample 12181: Predicted=10, True=8
# Sample 12182: Predicted=10, True=8
# Sample 12183: Predicted=10, True=8
# Sample 12184: Predicted=10, True=8
# Sample 12185: Predicted=10, True=8
# Sample 12186: Predicted=8, True=8
# Sample 12187: Predicted=8, True=8
# Sample 12188: Predicted=10, True=8
# Sample 12189: Predicted=13, True=8
# Sample 12190: Predicted=10, True=8
# Sample 12191: Predicted=10, True=8
# Sample 12192: Predicted=10, True=8
# Sample 12193: Predicted=10, True=8
# Sample 12194: Predicted=10, True=8
# Sample 12195: Predicted=10, True=8
# Sample 12196: Predicted=10, True=8
