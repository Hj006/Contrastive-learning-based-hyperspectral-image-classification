# %%
import os
from pathlib import Path
import numpy as np
from scipy.sparse import coo_array
import skimage.exposure
from scipy.sparse import coo_matrix
import warnings
from io import StringIO

def _read_roi(path: Path, shape) -> coo_matrix:
    """
    读取 ENVI 软件导出 ROI 文件的 txt 文件，生成一个稀疏矩阵，表示每个像素点的类别标签。
    
    :param path: 文件路径，ENVI ROI 文件的路径
    :param shape: 图像的形状（height, width）
    :return: 一个稀疏矩阵，非零值表示像素点的类别标签
    """
    warnings.simplefilter("ignore", category=UserWarning)  # 忽略 loadtxt 的警告
    data = []
    rows = []
    cols = []
    current_label = 0
    buffer = ""

    with open(path, 'r') as f:
        for line in f:
            # 判断是否为新 ROI 的分割点
            if line.strip() == "" or line.startswith(";") or "ROI" in line:
                if buffer:  # 如果缓冲区有内容，解析为坐标数据
                    roi_data = np.loadtxt(StringIO(buffer), usecols=(2, 1), dtype=int)
                    if roi_data.size > 0:
                        r, c = roi_data.T
                        rows.extend(r)
                        cols.extend(c)
                        data.extend([current_label] * len(r))
                    buffer = ""  # 清空缓冲区
                # 如果遇到 ROI name 行，增加类别标签
                if "ROI name" in line:
                    current_label += 1
            else:
                buffer += line  # 将数据加入缓冲区

        # 处理最后一个 ROI
        if buffer:
            roi_data = np.loadtxt(StringIO(buffer), usecols=(2, 1), dtype=int)
            if roi_data.size > 0:
                r, c = roi_data.T
                rows.extend(r)
                cols.extend(c)
                data.extend([current_label] * len(r))

    warnings.resetwarnings()

    # 创建稀疏矩阵
    img = coo_matrix((data, (rows, cols)), shape=shape, dtype=int)
    return img


def load_houston2013(data_path: Path):
    """
    从本地路径加载 Houston2013 数据集。

    :param data_path: 数据集的根目录路径。
    :return: (casi, lidar, train_truth, test_truth, info)
    """
    FILES_PATH = data_path
    assert FILES_PATH.exists(), f"{FILES_PATH} does not exist. Please check the path."

    # 加载图像数据
    lidar = skimage.io.imread(FILES_PATH / '2013_IEEE_GRSS_DF_Contest_LiDAR.tif')[np.newaxis, :, :]  # (1, 349, 1905)
    casi = skimage.io.imread(FILES_PATH / '2013_IEEE_GRSS_DF_Contest_CASI.tif').transpose(2, 0, 1)   # (144, 349, 1905)

    # 加载训练集和测试集的真值
    train_truth = _read_roi(FILES_PATH / '2013_IEEE_GRSS_DF_Contest_Samples_TR.txt', (349, 1905))
    test_truth = _read_roi(FILES_PATH / '2013_IEEE_GRSS_DF_Contest_Samples_VA.txt', (349, 1905))

    # 数据集元信息
    info = {
        'n_band_casi': 144,
        'n_band_lidar': 1,
        'width': 1905,
        'height': 349,
        'label_dict': {
            1: 'Healthy grass',
            2: 'Stressed grass',
            3: 'Synthetic grass',
            4: 'Trees',
            5: 'Soil',
            6: 'Water',
            7: 'Residential',
            8: 'Commercial',
            9: 'Road',
            10: 'Highway',
            11: 'Railway',
            12: 'Parking Lot 1',
            13: 'Parking Lot 2',
            14: 'Tennis Court',
            15: 'Running Track',
        }
    }

    return casi, lidar, train_truth, test_truth, info


# 指定数据集路径
data_path = Path(r"E:\code\-\对比学习\fx\Houston2013\2013_DFTC")

# 加载数据集
casi, lidar, train_truth, test_truth, info = load_houston2013(data_path)

# 打印数据集基本信息
print(f"CASI shape: {casi.shape}")   # 高光谱图像 (144, 349, 1905)
print(f"LiDAR shape: {lidar.shape}")  # LiDAR 数据 (1, 349, 1905)
print(f"Train truth non-zero: {train_truth.count_nonzero()}")  # 训练集非零样本数
print(f"Test truth non-zero: {test_truth.count_nonzero()}")    # 测试集非零样本数
print(f"Label dictionary: {info['label_dict']}")
from scipy.sparse import coo_matrix

def merge_train_test(train_truth, test_truth, shape):
    """
    合并训练集和测试集稀疏矩阵为一个新的训练集矩阵。
    
    参数:
        train_truth: coo_matrix, 原始训练集稀疏矩阵
        test_truth: coo_matrix, 原始测试集稀疏矩阵
        shape: tuple, 数据的形状 (height, width)
        
    返回:
        merged_truth: coo_matrix, 合并后的训练集稀疏矩阵
    """
    # 合并行、列和数据
    merged_rows = np.concatenate([train_truth.row, test_truth.row])
    merged_cols = np.concatenate([train_truth.col, test_truth.col])
    merged_data = np.concatenate([train_truth.data, test_truth.data])
    
    # 创建新的稀疏矩阵
    merged_truth = coo_matrix((merged_data, (merged_rows, merged_cols)), shape=shape)
    return merged_truth

# 合并训练集和测试集为新的训练集
merged_train_truth = merge_train_test(train_truth, test_truth, (349, 1905))

from sklearn.decomposition import PCA
import numpy as np

def apply_pca_train_only(hsi_data, train_truth, num_components=40):
    """
    使用训练区域的光谱数据训练 PCA 模型，并应用到整个数据集。
    
    参数:
        hsi_data: numpy.ndarray, 高光谱图像数据, 形状为 [C, H, W]
        train_truth: coo_array, 训练区域的稀疏矩阵，表示训练样本的位置
        num_components: int, 保留的主成分数量
        
    返回:
        pca_data: numpy.ndarray, PCA 降维后的数据，形状为 [num_components, H, W]
        explained_variance_ratio: PCA 的累计解释方差比
    """
    c, h, w = hsi_data.shape  # 高光谱数据的形状
    rows, cols = train_truth.row, train_truth.col  # 提取训练区域的行列索引
    
    # 提取训练区域的光谱数据 [num_samples, num_channels]
    train_spectra = hsi_data[:, rows, cols].T  # 转置为 [num_samples, num_channels]
    
    # 在训练区域数据上拟合 PCA
    pca = PCA(n_components=num_components)
    pca.fit(train_spectra)  # 仅在训练区域数据上训练 PCA
    
    # 转换整个数据集 [C, H, W] -> [H×W, C]
    reshaped_data = hsi_data.reshape(c, -1).T  # [H×W, C]
    reduced_data = pca.transform(reshaped_data)  # 降维 [H×W, num_components]
    
    # 恢复为原始图像的形状 [num_components, H, W]
    pca_data = reduced_data.T.reshape(num_components, h, w)  # [num_components, H, W]
    
    return pca_data, pca.explained_variance_ratio_

# 应用 PCA 降维
pca_data, explained_variance_ratio = apply_pca_train_only(casi, merged_train_truth, num_components=40)

print(f"PCA 降维后的数据形状: {pca_data.shape}")  # (40, 349, 1905)
print(f"PCA 累计解释方差比: {np.sum(explained_variance_ratio):.4f}")  

# 获取训练区域的光谱数据降维结果
def extract_pca_train_samples(pca_data, merged_train_truth):
    rows, cols = merged_train_truth.row, merged_train_truth.col  # 提取训练样本位置
    train_samples_pca = pca_data[:, rows, cols].T  # 提取训练样本并转置
    return train_samples_pca

# 提取降维后的训练集样本
train_samples_pca = extract_pca_train_samples(pca_data, merged_train_truth)

# 输出训练集样本数量和降维后形状
print(f"降维后训练集样本数量: {train_samples_pca.shape[0]}")  # 样本数量
print(f"降维后训练集样本形状: {train_samples_pca.shape}")    # 样本形状
# Out:
# <tifffile.TiffPage 0 @2949772> parsing GDAL_NODATA tag raised ValueError('-3.4028234663852886e+38 is not castable to float32')
# CASI shape: (144, 349, 1905)
# LiDAR shape: (1, 349, 1905)
# Train truth non-zero: 2832
# Test truth non-zero: 12197
# Label dictionary: {1: 'Healthy grass', 2: 'Stressed grass', 3: 'Synthetic grass', 4: 'Trees', 5: 'Soil', 6: 'Water', 7: 'Residential', 8: 'Commercial', 9: 'Road', 10: 'Highway', 11: 'Railway', 12: 'Parking Lot 1', 13: 'Parking Lot 2', 14: 'Tennis Court', 15: 'Running Track'}
# PCA 降维后的数据形状: (40, 349, 1905)
# PCA 累计解释方差比: 1.0000
# 降维后训练集样本数量: 15029
# 降维后训练集样本形状: (15029, 40)

# %%
import torch
def split_cube(hsi_cube):
    """
    将高光谱立方块沿通道维度均匀切分。
    参数:
        hsi_cube: torch.Tensor, 形状为 [H, W, C]
    返回:
        hsi_cube_a, hsi_cube_b: 两个子立方块
    """
    _, _, c = hsi_cube.shape
    c1 = c // 2  # 每个子块保留一半的通道
    return hsi_cube[:, :, :c1], hsi_cube[:, :, c1:]

# 提取 11x11 的立方块
s = 11  # 立方块的宽和高
patch_size = (s, s)

def extract_cube(data, x, y, size):
    """
    从高光谱图像中提取一个立方块，并在边缘不足时进行填充。
    参数:
        data: 高光谱数据, 形状为 [C, H, W]
        x, y: 中心像素的坐标
        size: 立方块的大小 (s, s)
    返回:
        cube: 提取的立方块, 形状为 [C, s, s]
    """
    c, h, w = data.shape
    half_size = size[0] // 2
    x_min = max(0, x - half_size)
    x_max = min(h, x + half_size + 1)
    y_min = max(0, y - half_size)
    y_max = min(w, y + half_size + 1)
    
    cube = data[:, x_min:x_max, y_min:y_max]

    # 进行对称填充，确保形状为 (C, s, s)
    pad_width = [
        (0, 0),  # 不填充通道维度
        (max(0, half_size - x), max(0, x + half_size + 1 - h)),  # 高度填充
        (max(0, half_size - y), max(0, y + half_size + 1 - w)),  # 宽度填充
    ]
    cube = np.pad(cube, pad_width, mode="reflect")
    return cube

# 提取某像素点周围的立方块
x, y = 100, 100  # 中心像素位置
cube = extract_cube(pca_data, x, y, patch_size)
print("提取的立方块形状:", cube.shape)  # (40, 11, 11)
# 切分通道
cube_tensor = torch.tensor(cube).permute(1, 2, 0)  # 转换为 [H, W, C]
cube_a, cube_b = split_cube(cube_tensor)

print("子立方块 A 形状:", cube_a.shape)  # (11, 11, 20)
print("子立方块 B 形状:", cube_b.shape)  # (11, 11, 20)
import torch.nn as nn
import torch.nn.functional as F

class FeatureExtractor(nn.Module):
    def __init__(self, input_channels=20):
        """
        特征提取网络。
        参数:
            input_channels: 输入的通道数，例如 20。
        """
        super(FeatureExtractor, self).__init__()
        self.conv1 = nn.Conv2d(input_channels, 32, kernel_size=3, padding=1)  # 第一层卷积
        self.bn1 = nn.BatchNorm2d(32)
        
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)  # 第二层卷积
        self.bn2 = nn.BatchNorm2d(64)
        
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)  # 第三层卷积
        self.bn3 = nn.BatchNorm2d(128)
        
        self.pool = nn.MaxPool2d(2, 2)  # 最大池化层
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.pool(self.relu(self.bn1(self.conv1(x))))  # 卷积 + 批归一化 + 激活 + 池化
        x = self.pool(self.relu(self.bn2(self.conv2(x))))
        x = self.pool(self.relu(self.bn3(self.conv3(x))))
        return x.view(x.size(0), -1)  # 展平特征
# Out:
# 提取的立方块形状: (40, 11, 11)
# 子立方块 A 形状: torch.Size([11, 11, 20])
# 子立方块 B 形状: torch.Size([11, 11, 20])

# %%
# 初始化特征提取网络
feature_extractor = FeatureExtractor(input_channels=20).cuda()

# 输入子立方块
cube_a = cube_a.permute(2, 0, 1).unsqueeze(0).float().cuda()  # 转换为 [batch_size, channels, height, width]
cube_b = cube_b.permute(2, 0, 1).unsqueeze(0).float().cuda()

# 提取特征
features_a = feature_extractor(cube_a)  # 子块 A 的特征
features_b = feature_extractor(cube_b)  # 子块 B 的特征

print(f"Features A Shape: {features_a.shape}")  # 输出特征形状，例如 [batch_size, feature_dim]
print(f"Features B Shape: {features_b.shape}")
# Out:
# Features A Shape: torch.Size([1, 128])
# Features B Shape: torch.Size([1, 128])

# %%
class ProjectionHead(nn.Module):
    def __init__(self, input_dim=128, output_dim=8):
        """
        特征投影模块。
        参数:
            input_dim: 输入特征的维度，例如 128。
            output_dim: 投影后的维度，例如 8。
        """
        super(ProjectionHead, self).__init__()
        self.fc = nn.Linear(input_dim, output_dim)

    def forward(self, x):
        return F.normalize(self.fc(x), dim=1)  # 投影后的特征归一化


def contrastive_loss(features_a, features_b, temperature=1.0):
    """
    计算对比损失。
    参数:
        features_a, features_b: 投影后的特征，形状为 [batch_size, projection_dim]
        temperature: 温度系数
    返回:
        loss: 对比损失值
    """
    batch_size = features_a.size(0)
    features = torch.cat([features_a, features_b], dim=0)  # 拼接特征
    sim_matrix = F.cosine_similarity(features.unsqueeze(1), features.unsqueeze(0), dim=2)  # 计算相似度
    sim_matrix = sim_matrix / temperature

    # 构造标签
    labels = torch.arange(batch_size, device=features_a.device)
    labels = torch.cat([labels, labels], dim=0)

    # 使用交叉熵损失
    loss = F.cross_entropy(sim_matrix, labels)
    return loss

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt


# 自定义数据集类
class HyperspectralDataset(Dataset):
    def __init__(self, pca_data, patch_size=11, num_samples=1000):
        self.data = pca_data  # PCA 降维后的高光谱数据
        self.patch_size = patch_size
        self.num_samples = num_samples
        self.h, self.w = pca_data.shape[1], pca_data.shape[2]

    def __len__(self):
        return self.num_samples

    def __getitem__(self, idx):
        # 随机采样一个中心点
        x = torch.randint(self.patch_size // 2, self.h - self.patch_size // 2, (1,)).item()
        y = torch.randint(self.patch_size // 2, self.w - self.patch_size // 2, (1,)).item()
        
        # 提取立方块
        cube = extract_cube(self.data, x, y, (self.patch_size, self.patch_size))
        cube_tensor = torch.tensor(cube).permute(1, 2, 0)  # 转换为 [H, W, C]
        
        # 分割为子块
        cube_a, cube_b = split_cube(cube_tensor)
        cube_a = cube_a.permute(2, 0, 1)  # 转换为 [C, H, W]
        cube_b = cube_b.permute(2, 0, 1)  # 转换为 [C, H, W]
        
        return cube_a, cube_b

# 初始化数据集和数据加载器
pca_data_tensor = torch.tensor(pca_data).float()
dataset = HyperspectralDataset(pca_data_tensor)
dataloader = DataLoader(dataset, batch_size=256, shuffle=True)
# 创建保存模型的文件夹
os.makedirs('./pth', exist_ok=True)

# 训练参数配置
temperatures = [0.3, 0.5, 1.0]  # 3个温度参数
batch_sizes = [128, 256]  # 2个 batch size
epochs_list = [200, 400]  # 2个 epoch 设置
learning_rate = 1e-3  # 固定学习率

# 遍历所有组合
for temperature in temperatures:
    for batch_size in batch_sizes:
        for num_epochs in epochs_list:
            print(f"\nRunning Training: τ={temperature}, batch_size={batch_size}, epochs={num_epochs}")

            # 初始化数据加载器
            dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

            # 初始化网络
            feature_extractor = FeatureExtractor(input_channels=20).cuda()
            projection_head = ProjectionHead(input_dim=128, output_dim=8).cuda()
            optimizer = optim.Adam(
                list(feature_extractor.parameters()) + list(projection_head.parameters()), 
                lr=learning_rate
            )

            # 存储损失值
            loss_values = []

            # 训练循环
            for epoch in range(num_epochs):
                feature_extractor.train()
                projection_head.train()
                epoch_loss = 0

                for batch in dataloader:
                    cube_a, cube_b = batch
                    cube_a, cube_b = cube_a.cuda(), cube_b.cuda()

                    # 提取特征
                    features_a = feature_extractor(cube_a)
                    features_b = feature_extractor(cube_b)

                    # 投影到嵌入空间
                    proj_a = projection_head(features_a)
                    proj_b = projection_head(features_b)

                    # 计算对比损失
                    loss = contrastive_loss(proj_a, proj_b, temperature)

                    # 反向传播
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                    epoch_loss += loss.item()

                # 计算平均损失
                avg_loss = epoch_loss / len(dataloader)
                loss_values.append(avg_loss)

                # 每 100 轮打印信息
                if (epoch + 1) % 100 == 0:
                    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}")

            # 保存模型，命名格式为 23_10倍的温度参数_batchsize_epoch.pth
            model_filename = f"pth/23_{int(temperature * 10)}_batch{batch_size}_epoch{num_epochs}.pth"
            torch.save(
                {
                    'epoch': num_epochs,
                    'feature_extractor_state_dict': feature_extractor.state_dict(),
                    'projection_head_state_dict': projection_head.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'loss_values': loss_values,
                },
                model_filename
            )
            print(f"Model saved to {model_filename}")

            # 画损失曲线
            plt.figure(figsize=(8, 6))
            plt.plot(range(1, num_epochs + 1), loss_values, marker='o', label=f'Temp {temperature}, Batch {batch_size}, Epoch {num_epochs}')
            plt.xlabel('Epoch')
            plt.ylabel('Loss')
            plt.title(f'Training Loss Curve (τ={temperature}, Batch {batch_size}, Epoch {num_epochs})')
            plt.legend()
            plt.grid()
            loss_plot_filename = model_filename.replace('.pth', '.png')
            plt.savefig(loss_plot_filename)
            plt.close()
            print(f"Loss curve saved to {loss_plot_filename}")

# %%
def extract_labels(truth, label_dict):
    """
    从稀疏矩阵中提取标注数据，格式为 [(row, col, label), ...]。
    并将标签值映射到 [0, len(label_dict)-1] 的范围。
    """
    rows, cols, labels = truth.row, truth.col, truth.data
    # 创建从标签值到索引的映射
    label_to_index = {label_value: idx for idx, label_value in enumerate(label_dict.keys())}
    mapped_labels = [label_to_index[label] for label in labels if label in label_to_index]
    return [(row, col, label) for row, col, label in zip(rows, cols, mapped_labels)]


test_labels = extract_labels(test_truth, info['label_dict'])


print(f"Number of testing samples: {len(test_labels)}")
from collections import Counter


test_label_counts = Counter([label for _, _, label in test_labels])
# Out:
# Number of testing samples: 12197

# %%
from torch.utils.data import Dataset, DataLoader
import random
from collections import defaultdict
import numpy as np
import torch
from sklearn.decomposition import PCA

# 提取立方块函数
def extract_cube(data, x, y, size):
    """
    从高光谱图像中提取一个立方块，并在边缘不足时进行填充。
    参数:
        data: 高光谱数据, 形状为 [C, H, W]
        x, y: 中心像素的坐标
        size: 立方块的大小 (s, s)
    返回:
        cube: 提取的立方块, 形状为 [C, s, s]
    """
    c, h, w = data.shape
    half_size = size[0] // 2
    x_min = max(0, x - half_size)
    x_max = min(h, x + half_size + 1)
    y_min = max(0, y - half_size)
    y_max = min(w, y + half_size + 1)
    
    cube = data[:, x_min:x_max, y_min:y_max]

    # 对称填充，确保形状为 (C, s, s)
    pad_width = [
        (0, 0),  # 不填充通道维度
        (max(0, half_size - x), max(0, x + half_size + 1 - h)),  # 高度填充
        (max(0, half_size - y), max(0, y + half_size + 1 - w)),  # 宽度填充
    ]
    cube = np.pad(cube, pad_width, mode="reflect")
    return cube


# PCA 降维函数
def apply_pca_train_only(hsi_data, train_truth, num_components=20):
    """
    使用训练区域的光谱数据训练 PCA 模型，并应用到整个数据集。
    参数:
        hsi_data: 高光谱数据, 形状为 [C, H, W]
        train_truth: coo_array, 训练区域的稀疏矩阵，表示训练样本的位置
        num_components: 保留的主成分数量
    返回:
        pca_data: 降维后的数据, 形状为 [num_components, H, W]
        explained_variance_ratio: PCA 的累计解释方差比
    """
    c, h, w = hsi_data.shape
    rows, cols = train_truth.row, train_truth.col  # 提取训练区域的行列索引

    # 提取训练区域的光谱数据 [num_samples, num_channels]
    train_spectra = hsi_data[:, rows, cols].T  # 转置为 [num_samples, num_channels]

    # 在训练区域数据上拟合 PCA
    pca = PCA(n_components=num_components)
    pca.fit(train_spectra)  # 仅在训练区域数据上训练 PCA

    # 转换整个数据集
    reshaped_data = hsi_data.reshape(c, -1).T  # [H×W, C]
    reduced_data = pca.transform(reshaped_data)  # 降维 [H×W, num_components]

    # 恢复为原始图像的形状
    pca_data = reduced_data.T.reshape(num_components, h, w)  # [num_components, H, W]
    
    return pca_data, pca.explained_variance_ratio_


# 分类数据集定义
class ClassificationDataset(Dataset):
    def __init__(self, data, labels, patch_size=11):
        """
        构造分类数据集。
        参数:
            data: PCA 降维后的数据 [C, H, W]
            labels: [(row, col, label), ...]，标注的样本
            patch_size: 立方块大小 (patch_size, patch_size)
        """
        self.data = data
        self.labels = labels
        self.patch_size = patch_size

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        x, y, label = self.labels[idx]
        cube = extract_cube(self.data, x, y, (self.patch_size, self.patch_size))  # 提取立方块
        cube_tensor = torch.tensor(cube).float()  # 转换为浮点张量
        return cube_tensor, label


# 候选集生成函数
def create_candidate_dataset(train_labels, num_classes, samples_per_class):
    """
    从训练样本中按每类抽取指定数量的样本，构造候选集。
    参数:
        train_labels: 原始训练样本 [(row, col, label), ...]
        num_classes: 类别数量
        samples_per_class: 每个类别抽取的样本数量
    返回:
        candidate_labels: 候选样本 [(row, col, label), ...]
    """
    class_samples = defaultdict(list)
    for sample in train_labels:
        class_samples[sample[2]].append(sample)

    candidate_labels = []
    for cls in range(num_classes):
        if cls in class_samples:
            samples = class_samples[cls]
            if len(samples) < samples_per_class:
                print(f"Warning: Class {cls} has only {len(samples)} samples, less than {samples_per_class}.")
            candidate_labels.extend(random.sample(samples, min(samples_per_class, len(samples))))
        else:
            print(f"Warning: Class {cls} has no samples in training set.")
    return candidate_labels


# 应用 PCA 并重新构造数据集
ptest_data, explained_variance_ratio = apply_pca_train_only(casi, test_truth, num_components=20)

test_dataset = ClassificationDataset(ptest_data, test_labels, patch_size=11)
candidate_labels = create_candidate_dataset(test_labels, num_classes=len(info['label_dict']), samples_per_class=10)
candidate_dataset = ClassificationDataset(ptest_data, candidate_labels, patch_size=11)

# 定义数据加载器
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
candidate_loader = DataLoader(candidate_dataset, batch_size=64, shuffle=True)

# 打印样本数量信息
print(f"PCA 降维后的数据形状: {ptest_data.shape}")
print(f"Number of candidate samples: {len(candidate_loader.dataset)}")
print(f"Number of testing samples: {len(test_loader.dataset)}")
# Out:
# PCA 降维后的数据形状: (20, 349, 1905)
# Number of candidate samples: 150
# Number of testing samples: 12197

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# 定义特征提取器
class FeatureExtractor(nn.Module):
    def __init__(self, input_channels):
        super().__init__()
        self.conv1 = nn.Conv2d(input_channels, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(128)
        self.pool = nn.MaxPool2d(2, 2)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.pool(self.relu(self.bn1(self.conv1(x))))
        x = self.pool(self.relu(self.bn2(self.conv2(x))))
        x = self.pool(self.relu(self.bn3(self.conv3(x))))
        return x.view(x.size(0), -1)  # Flatten to [batch_size, features]
    

# 定义分类头
class ClassificationHead(nn.Module):
    def __init__(self, input_dim, num_classes):
        super(ClassificationHead, self).__init__()
        self.fc = nn.Linear(input_dim, num_classes)

    def forward(self, x):
        return self.fc(x)


from sklearn.metrics import cohen_kappa_score
import numpy as np

def evaluate_classification_model_with_details(feature_extractor, classification_head, test_loader, num_classes):
    """
    评估分类模型的性能，并输出详细预测结果和分布。

    参数:
        feature_extractor: 冻结的特征提取器
        classification_head: 分类头
        test_loader: 测试数据加载器
        num_classes: 总类别数
    """
    feature_extractor.eval()
    classification_head.eval()

    correct = 0
    total = 0

    # 初始化预测计数，并移动到 GPU
    prediction_counts = torch.zeros(num_classes, dtype=torch.int64).cuda()
    class_correct = torch.zeros(num_classes, dtype=torch.int64).cuda()
    class_total = torch.zeros(num_classes, dtype=torch.int64).cuda()

    all_predictions = []
    all_labels = []

    with torch.no_grad():
        for cubes, labels in test_loader:
            cubes, labels = cubes.cuda(), labels.cuda()

            # 提取特征并进行预测
            features = feature_extractor(cubes)
            outputs = classification_head(features)
            _, predicted = torch.max(outputs, 1)

            # 更新统计信息
            correct += (predicted == labels).sum().item()
            total += labels.size(0)
            prediction_counts += torch.bincount(predicted, minlength=num_classes).cuda()

            for i in range(labels.size(0)):
                label = labels[i].item()
                pred = predicted[i].item()
                class_total[label] += 1
                if label == pred:
                    class_correct[label] += 1

            # 保存详细信息
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Overall Accuracy
    overall_accuracy = correct / total

    # Average Accuracy (每个类别的平均准确率)
    average_accuracy = (class_correct.float() / class_total.float()).mean().item()

    # Kappa 系数
    kappa = cohen_kappa_score(all_labels, all_predictions)

    print(f"Overall Accuracy: {overall_accuracy:.4f}")
    print(f"Average Accuracy: {average_accuracy:.4f}")
    print(f"Kappa Coefficient: {kappa:.4f}")

    print("\nPrediction Distribution:")
    for cls, count in enumerate(prediction_counts.cpu()):  # 将分布从 GPU 移回 CPU
        print(f"Class {cls}: {count} predictions")

    return overall_accuracy, average_accuracy, kappa, all_predictions, all_labels

# 训练分类头和特征提取器
def train_classification_model(feature_extractor, classification_head, train_loader, optimizer, criterion, num_epochs=50):
    feature_extractor.train()  # 微调特征提取器
    classification_head.train()  # 训练分类头

    for epoch in range(num_epochs):
        epoch_loss = 0
        for cubes, labels in train_loader:
            cubes, labels = cubes.cuda(), labels.cuda()

            # 提取特征
            features = feature_extractor(cubes)

            # 分类头进行训练
            outputs = classification_head(features)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss/len(train_loader):.4f}")


overall_accuracies = []
average_accuracies = []

# 加载对比学习的模型权重
#checkpoint_path = "./pth/model_epoch_160.pth"  # 修改为对比学习模型的路径
checkpoint_path =  [
    "pth/23_3_batch128_epoch200.pth",
    "pth/23_3_batch128_epoch400.pth",
    "pth/23_3_batch256_epoch400.pth",
    "pth/23_5_batch128_epoch200.pth",
    "pth/23_5_batch128_epoch400.pth",
    "pth/23_5_batch256_epoch400.pth",
    "pth/23_10_batch128_epoch200.pth",
    "pth/23_10_batch128_epoch400.pth",
    "pth/23_10_batch256_epoch400.pth",
    "pth/original.pth"
]

for i in checkpoint_path:

    checkpoint = torch.load(i)

    # 确保权重文件中包含特征提取器的权重
    if 'feature_extractor_state_dict' not in checkpoint:
        raise KeyError("Checkpoint does not contain 'feature_extractor_state_dict'. Please check the file.")

    # 初始化特征提取器（与对比学习阶段一致的输入通道数为 20）
    feature_extractor = FeatureExtractor(input_channels=20).cuda()

    # 加载所有预训练权重
    feature_extractor.load_state_dict(checkpoint['feature_extractor_state_dict'])
    print("Loaded pre-trained weights for the entire feature extractor.")

    # 检查冻结状态（设置所有层参数为可微调）
    for param in feature_extractor.parameters():
        param.requires_grad = True  # 解冻所有参数


    # 修改输入维度为 128（特征提取器的输出维度）
    classification_head = ClassificationHead(input_dim=128, num_classes=15).cuda()


    # 定义优化器
    optimizer = optim.Adam([
        {"params": feature_extractor.parameters(), "lr": 1e-4},  # 微调特征提取器
        {"params": classification_head.parameters(), "lr": 1e-3},  # 分类头
    ])

    # 定义损失函数
    criterion = nn.CrossEntropyLoss()



    # 运行训练函数
    train_classification_model(feature_extractor, classification_head, candidate_loader, optimizer, criterion, num_epochs=200)


    # 再次评估模型
    overall_accuracy, average_accuracy, kappa, all_predictions, all_labels = evaluate_classification_model_with_details(
        feature_extractor, classification_head, test_loader, num_classes=15
    )
    overall_accuracies.append(overall_accuracy)
    average_accuracies.append(average_accuracy)

# 绘制柱状图对比
plt.figure(figsize=(12, 6))

# Overall Accuracy 柱状图
plt.subplot(1, 2, 1)
bars1 = plt.bar(range(len(checkpoint_path)), overall_accuracies, tick_label=[p.split('/')[-1] for p in checkpoint_path])
plt.xticks(rotation=45, ha='right')
plt.ylabel("Overall Accuracy")
plt.title("Overall Accuracy Comparison")

# 在柱子上添加数值标签
for bar in bars1:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, f"{yval:.2f}", ha='center', va='bottom')

# Average Accuracy 柱状图
plt.subplot(1, 2, 2)
bars2 = plt.bar(range(len(checkpoint_path)), average_accuracies, tick_label=[p.split('/')[-1] for p in checkpoint_path])
plt.xticks(rotation=45, ha='right')
plt.ylabel("Average Accuracy")
plt.title("Average Accuracy Comparison")

# 在柱子上添加数值标签
for bar in bars2:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, f"{yval:.2f}", ha='center', va='bottom')

# 调整布局
plt.tight_layout()
plt.show()
# Out:
# Loaded pre-trained weights for the entire feature extractor.
# Epoch [1/200], Loss: 2.7964
# Epoch [2/200], Loss: 2.6626
# Epoch [3/200], Loss: 2.4903
# Epoch [4/200], Loss: 2.3924
# Epoch [5/200], Loss: 2.2663
# Epoch [6/200], Loss: 2.2091
# Epoch [7/200], Loss: 2.1195
# Epoch [8/200], Loss: 1.9840
# Epoch [9/200], Loss: 1.9235
# Epoch [10/200], Loss: 1.7961
# Epoch [11/200], Loss: 1.7090
# Epoch [12/200], Loss: 1.6450
# Epoch [13/200], Loss: 1.5444
# Epoch [14/200], Loss: 1.4871
# Epoch [15/200], Loss: 1.4203
# Epoch [16/200], Loss: 1.3851
# Epoch [17/200], Loss: 1.2862
# Epoch [18/200], Loss: 1.2172
# Epoch [19/200], Loss: 1.1528
# Epoch [20/200], Loss: 1.2074
# Epoch [21/200], Loss: 1.0904
# Epoch [22/200], Loss: 1.0210
# Epoch [23/200], Loss: 1.0052
# Epoch [24/200], Loss: 0.9985
# Epoch [25/200], Loss: 0.9946
# Epoch [26/200], Loss: 0.9328
# Epoch [27/200], Loss: 0.8471
# Epoch [28/200], Loss: 0.8494
# Epoch [29/200], Loss: 0.7877
# Epoch [30/200], Loss: 0.8526
# Epoch [31/200], Loss: 0.7685
# Epoch [32/200], Loss: 0.7491
# Epoch [33/200], Loss: 0.6869
# Epoch [34/200], Loss: 0.6409
# Epoch [35/200], Loss: 0.6706
# Epoch [36/200], Loss: 0.6051
# Epoch [37/200], Loss: 0.5891
# Epoch [38/200], Loss: 0.5765
# Epoch [39/200], Loss: 0.5461
# Epoch [40/200], Loss: 0.5215
# Epoch [41/200], Loss: 0.4625
# Epoch [42/200], Loss: 0.4651
# Epoch [43/200], Loss: 0.4714
# Epoch [44/200], Loss: 0.4610
# Epoch [45/200], Loss: 0.5183
# Epoch [46/200], Loss: 0.4390
# Epoch [47/200], Loss: 0.4276
# Epoch [48/200], Loss: 0.3437
# Epoch [49/200], Loss: 0.3634
# Epoch [50/200], Loss: 0.3657
# Epoch [51/200], Loss: 0.3196
# Epoch [52/200], Loss: 0.3390
# Epoch [53/200], Loss: 0.3650
# Epoch [54/200], Loss: 0.3125
# Epoch [55/200], Loss: 0.2974
# Epoch [56/200], Loss: 0.2848
# Epoch [57/200], Loss: 0.2775
# Epoch [58/200], Loss: 0.2632
# Epoch [59/200], Loss: 0.2386
# Epoch [60/200], Loss: 0.2508
# Epoch [61/200], Loss: 0.2128
# Epoch [62/200], Loss: 0.2812
# Epoch [63/200], Loss: 0.2112
# Epoch [64/200], Loss: 0.2509
# Epoch [65/200], Loss: 0.1934
# Epoch [66/200], Loss: 0.1912
# Epoch [67/200], Loss: 0.1996
# Epoch [68/200], Loss: 0.1665
# Epoch [69/200], Loss: 0.1959
# Epoch [70/200], Loss: 0.1456
# Epoch [71/200], Loss: 0.1488
# Epoch [72/200], Loss: 0.1420
# Epoch [73/200], Loss: 0.1427
# Epoch [74/200], Loss: 0.1388
# Epoch [75/200], Loss: 0.1334
# Epoch [76/200], Loss: 0.1166
# Epoch [77/200], Loss: 0.1570
# Epoch [78/200], Loss: 0.1124
# Epoch [79/200], Loss: 0.1049
# Epoch [80/200], Loss: 0.1387
# Epoch [81/200], Loss: 0.1157
# Epoch [82/200], Loss: 0.1032
# Epoch [83/200], Loss: 0.1524
# Epoch [84/200], Loss: 0.1146
# Epoch [85/200], Loss: 0.1172
# Epoch [86/200], Loss: 0.0978
# Epoch [87/200], Loss: 0.0931
# Epoch [88/200], Loss: 0.0948
# Epoch [89/200], Loss: 0.0882
# Epoch [90/200], Loss: 0.1284
# Epoch [91/200], Loss: 0.0738
# Epoch [92/200], Loss: 0.0659
# Epoch [93/200], Loss: 0.0704
# Epoch [94/200], Loss: 0.1328
# Epoch [95/200], Loss: 0.0999
# Epoch [96/200], Loss: 0.1175
# Epoch [97/200], Loss: 0.0668
# Epoch [98/200], Loss: 0.0899
# Epoch [99/200], Loss: 0.0926
# Epoch [100/200], Loss: 0.0558
# Epoch [101/200], Loss: 0.0973
# Epoch [102/200], Loss: 0.0769
# Epoch [103/200], Loss: 0.0642
# Epoch [104/200], Loss: 0.1113
# Epoch [105/200], Loss: 0.0533
# Epoch [106/200], Loss: 0.1254
# Epoch [107/200], Loss: 0.0641
# Epoch [108/200], Loss: 0.0609
# Epoch [109/200], Loss: 0.0839
# Epoch [110/200], Loss: 0.0473
# Epoch [111/200], Loss: 0.0696
# Epoch [112/200], Loss: 0.0392
# Epoch [113/200], Loss: 0.0496
# Epoch [114/200], Loss: 0.0605
# Epoch [115/200], Loss: 0.0391
# Epoch [116/200], Loss: 0.0759
# Epoch [117/200], Loss: 0.0396
# Epoch [118/200], Loss: 0.0467
# Epoch [119/200], Loss: 0.0369
# Epoch [120/200], Loss: 0.0373
# Epoch [121/200], Loss: 0.0347
# Epoch [122/200], Loss: 0.0376
# Epoch [123/200], Loss: 0.0339
# Epoch [124/200], Loss: 0.0621
# Epoch [125/200], Loss: 0.0462
# Epoch [126/200], Loss: 0.0270
# Epoch [127/200], Loss: 0.0245
# Epoch [128/200], Loss: 0.0401
# Epoch [129/200], Loss: 0.0289
# Epoch [130/200], Loss: 0.0263
# Epoch [131/200], Loss: 0.0612
# Epoch [132/200], Loss: 0.0317
# Epoch [133/200], Loss: 0.0311
# Epoch [134/200], Loss: 0.0322
# Epoch [135/200], Loss: 0.0292
# Epoch [136/200], Loss: 0.0236
# Epoch [137/200], Loss: 0.0456
# Epoch [138/200], Loss: 0.0366
# Epoch [139/200], Loss: 0.0317
# Epoch [140/200], Loss: 0.0336
# Epoch [141/200], Loss: 0.0291
# Epoch [142/200], Loss: 0.0239
# Epoch [143/200], Loss: 0.0264
# Epoch [144/200], Loss: 0.0238
# Epoch [145/200], Loss: 0.0311
# Epoch [146/200], Loss: 0.0268
# Epoch [147/200], Loss: 0.0195
# Epoch [148/200], Loss: 0.0225
# Epoch [149/200], Loss: 0.0184
# Epoch [150/200], Loss: 0.0185
# Epoch [151/200], Loss: 0.0191
# Epoch [152/200], Loss: 0.0196
# Epoch [153/200], Loss: 0.0352
# Epoch [154/200], Loss: 0.0197
# Epoch [155/200], Loss: 0.0188
# Epoch [156/200], Loss: 0.0203
# Epoch [157/200], Loss: 0.0254
# Epoch [158/200], Loss: 0.0420
# Epoch [159/200], Loss: 0.0162
# Epoch [160/200], Loss: 0.0255
# Epoch [161/200], Loss: 0.0211
# Epoch [162/200], Loss: 0.0257
# Epoch [163/200], Loss: 0.0162
# Epoch [164/200], Loss: 0.0143
# Epoch [165/200], Loss: 0.0219
# Epoch [166/200], Loss: 0.0165
# Epoch [167/200], Loss: 0.0131
# Epoch [168/200], Loss: 0.0131
# Epoch [169/200], Loss: 0.0117
# Epoch [170/200], Loss: 0.0141
# Epoch [171/200], Loss: 0.0219
# Epoch [172/200], Loss: 0.0357
# Epoch [173/200], Loss: 0.0194
# Epoch [174/200], Loss: 0.0177
# Epoch [175/200], Loss: 0.0189
# Epoch [176/200], Loss: 0.0193
# Epoch [177/200], Loss: 0.0193
# Epoch [178/200], Loss: 0.0183
# Epoch [179/200], Loss: 0.0201
# Epoch [180/200], Loss: 0.0440
# Epoch [181/200], Loss: 0.0190
# Epoch [182/200], Loss: 0.0142
# Epoch [183/200], Loss: 0.0218
# Epoch [184/200], Loss: 0.0139
# Epoch [185/200], Loss: 0.0206
# Epoch [186/200], Loss: 0.0147
# Epoch [187/200], Loss: 0.0116
# Epoch [188/200], Loss: 0.0117
# Epoch [189/200], Loss: 0.0128
# Epoch [190/200], Loss: 0.0330
# Epoch [191/200], Loss: 0.0152
# Epoch [192/200], Loss: 0.0138
# Epoch [193/200], Loss: 0.0135
# Epoch [194/200], Loss: 0.0184
# Epoch [195/200], Loss: 0.0152
# Epoch [196/200], Loss: 0.0112
# Epoch [197/200], Loss: 0.0252
# Epoch [198/200], Loss: 0.0120
# Epoch [199/200], Loss: 0.0093
# Epoch [200/200], Loss: 0.0109
# Overall Accuracy: 0.8372
# Average Accuracy: 0.8607
# Kappa Coefficient: 0.8234
#
# Prediction Distribution:
# Class 0: 879 predictions
# Class 1: 1355 predictions
# Class 2: 450 predictions
# Class 3: 1067 predictions
# Class 4: 1050 predictions
# Class 5: 225 predictions
# Class 6: 792 predictions
# Class 7: 862 predictions
# Class 8: 816 predictions
# Class 9: 1472 predictions
# Class 10: 1113 predictions
# Class 11: 1018 predictions
# Class 12: 338 predictions
# Class 13: 250 predictions
# Class 14: 510 predictions
# Loaded pre-trained weights for the entire feature extractor.
# Epoch [1/200], Loss: 2.9049
# Epoch [2/200], Loss: 2.7201
# Epoch [3/200], Loss: 2.5515
# Epoch [4/200], Loss: 2.4057
# Epoch [5/200], Loss: 2.2941
# Epoch [6/200], Loss: 2.1381
# Epoch [7/200], Loss: 2.0352
# Epoch [8/200], Loss: 1.9902
# Epoch [9/200], Loss: 1.8968
# Epoch [10/200], Loss: 1.7551
# Epoch [11/200], Loss: 1.6856
# Epoch [12/200], Loss: 1.5942
# Epoch [13/200], Loss: 1.5744
# Epoch [14/200], Loss: 1.5221
# Epoch [15/200], Loss: 1.3907
# Epoch [16/200], Loss: 1.3250
# Epoch [17/200], Loss: 1.2829
# Epoch [18/200], Loss: 1.2279
# Epoch [19/200], Loss: 1.2282
# Epoch [20/200], Loss: 1.0845
# Epoch [21/200], Loss: 1.0680
# Epoch [22/200], Loss: 1.0572
# Epoch [23/200], Loss: 0.9684
# Epoch [24/200], Loss: 0.9806
# Epoch [25/200], Loss: 0.8624
# Epoch [26/200], Loss: 0.8817
# Epoch [27/200], Loss: 0.8305
# Epoch [28/200], Loss: 0.8220
# Epoch [29/200], Loss: 0.7453
# Epoch [30/200], Loss: 0.7473
# Epoch [31/200], Loss: 0.7146
# Epoch [32/200], Loss: 0.7226
# Epoch [33/200], Loss: 0.6404
# Epoch [34/200], Loss: 0.6618
# Epoch [35/200], Loss: 0.6051
# Epoch [36/200], Loss: 0.5619
# Epoch [37/200], Loss: 0.5965
# Epoch [38/200], Loss: 0.6058
# Epoch [39/200], Loss: 0.5397
# Epoch [40/200], Loss: 0.5746
# Epoch [41/200], Loss: 0.4704
# Epoch [42/200], Loss: 0.4808
# Epoch [43/200], Loss: 0.4834
# Epoch [44/200], Loss: 0.4512
# Epoch [45/200], Loss: 0.4756
# Epoch [46/200], Loss: 0.4127
# Epoch [47/200], Loss: 0.3913
# Epoch [48/200], Loss: 0.4097
# Epoch [49/200], Loss: 0.3759
# Epoch [50/200], Loss: 0.4073
# Epoch [51/200], Loss: 0.3529
# Epoch [52/200], Loss: 0.3145
# Epoch [53/200], Loss: 0.3483
# Epoch [54/200], Loss: 0.3721
# Epoch [55/200], Loss: 0.3168
# Epoch [56/200], Loss: 0.3518
# Epoch [57/200], Loss: 0.3183
# Epoch [58/200], Loss: 0.2697
# Epoch [59/200], Loss: 0.2664
# Epoch [60/200], Loss: 0.2463
# Epoch [61/200], Loss: 0.3122
# Epoch [62/200], Loss: 0.2843
# Epoch [63/200], Loss: 0.2227
# Epoch [64/200], Loss: 0.2518
# Epoch [65/200], Loss: 0.2458
# Epoch [66/200], Loss: 0.2235
# Epoch [67/200], Loss: 0.3215
# Epoch [68/200], Loss: 0.1927
# Epoch [69/200], Loss: 0.2112
# Epoch [70/200], Loss: 0.1777
# Epoch [71/200], Loss: 0.2079
# Epoch [72/200], Loss: 0.2146
# Epoch [73/200], Loss: 0.1921
# Epoch [74/200], Loss: 0.1743
# Epoch [75/200], Loss: 0.1795
# Epoch [76/200], Loss: 0.1646
# Epoch [77/200], Loss: 0.1425
# Epoch [78/200], Loss: 0.1509
# Epoch [79/200], Loss: 0.1408
# Epoch [80/200], Loss: 0.1551
# Epoch [81/200], Loss: 0.1785
# Epoch [82/200], Loss: 0.1740
# Epoch [83/200], Loss: 0.1333
# Epoch [84/200], Loss: 0.1357
# Epoch [85/200], Loss: 0.1396
# Epoch [86/200], Loss: 0.1655
# Epoch [87/200], Loss: 0.1213
# Epoch [88/200], Loss: 0.1460
# Epoch [89/200], Loss: 0.1272
# Epoch [90/200], Loss: 0.1524
# Epoch [91/200], Loss: 0.0908
# Epoch [92/200], Loss: 0.1241
# Epoch [93/200], Loss: 0.1073
# Epoch [94/200], Loss: 0.1294
# Epoch [95/200], Loss: 0.1086
# Epoch [96/200], Loss: 0.0885
# Epoch [97/200], Loss: 0.0972
# Epoch [98/200], Loss: 0.0787
# Epoch [99/200], Loss: 0.0918
# Epoch [100/200], Loss: 0.0870
# Epoch [101/200], Loss: 0.1122
# Epoch [102/200], Loss: 0.0800
# Epoch [103/200], Loss: 0.1114
# Epoch [104/200], Loss: 0.1205
# Epoch [105/200], Loss: 0.0834
# Epoch [106/200], Loss: 0.0905
# Epoch [107/200], Loss: 0.0678
# Epoch [108/200], Loss: 0.0653
# Epoch [109/200], Loss: 0.0678
# Epoch [110/200], Loss: 0.0791
# Epoch [111/200], Loss: 0.0498
# Epoch [112/200], Loss: 0.0512
# Epoch [113/200], Loss: 0.0810
# Epoch [114/200], Loss: 0.1078
# Epoch [115/200], Loss: 0.0547
# Epoch [116/200], Loss: 0.0666
# Epoch [117/200], Loss: 0.0568
# Epoch [118/200], Loss: 0.0413
# Epoch [119/200], Loss: 0.0808
# Epoch [120/200], Loss: 0.0576
# Epoch [121/200], Loss: 0.0649
# Epoch [122/200], Loss: 0.0510
# Epoch [123/200], Loss: 0.0527
# Epoch [124/200], Loss: 0.0446
# Epoch [125/200], Loss: 0.0479
# Epoch [126/200], Loss: 0.0496
# Epoch [127/200], Loss: 0.0631
# Epoch [128/200], Loss: 0.0417
# Epoch [129/200], Loss: 0.0477
# Epoch [130/200], Loss: 0.0406
# Epoch [131/200], Loss: 0.0465
# Epoch [132/200], Loss: 0.0381
# Epoch [133/200], Loss: 0.0433
# Epoch [134/200], Loss: 0.0377
# Epoch [135/200], Loss: 0.0499
# Epoch [136/200], Loss: 0.0360
# Epoch [137/200], Loss: 0.0416
# Epoch [138/200], Loss: 0.0339
# Epoch [139/200], Loss: 0.0394
# Epoch [140/200], Loss: 0.0403
# Epoch [141/200], Loss: 0.0306
# Epoch [142/200], Loss: 0.0328
# Epoch [143/200], Loss: 0.0427
# Epoch [144/200], Loss: 0.0376
# Epoch [145/200], Loss: 0.0295
# Epoch [146/200], Loss: 0.0383
# Epoch [147/200], Loss: 0.0263
# Epoch [148/200], Loss: 0.0345
# Epoch [149/200], Loss: 0.0420
# Epoch [150/200], Loss: 0.0301
# Epoch [151/200], Loss: 0.0227
# Epoch [152/200], Loss: 0.0317
# Epoch [153/200], Loss: 0.0282
# Epoch [154/200], Loss: 0.0309
# Epoch [155/200], Loss: 0.0335
# Epoch [156/200], Loss: 0.0268
# Epoch [157/200], Loss: 0.0377
# Epoch [158/200], Loss: 0.0281
# Epoch [159/200], Loss: 0.0215
# Epoch [160/200], Loss: 0.0203
# Epoch [161/200], Loss: 0.0268
# Epoch [162/200], Loss: 0.0206
# Epoch [163/200], Loss: 0.0164
# Epoch [164/200], Loss: 0.0297
# Epoch [165/200], Loss: 0.0214
# Epoch [166/200], Loss: 0.0239
# Epoch [167/200], Loss: 0.0189
# Epoch [168/200], Loss: 0.0222
# Epoch [169/200], Loss: 0.0213
# Epoch [170/200], Loss: 0.0634
# Epoch [171/200], Loss: 0.0237
# Epoch [172/200], Loss: 0.0176
# Epoch [173/200], Loss: 0.0146
# Epoch [174/200], Loss: 0.0221
# Epoch [175/200], Loss: 0.0176
# Epoch [176/200], Loss: 0.0210
# Epoch [177/200], Loss: 0.0532
# Epoch [178/200], Loss: 0.0213
# Epoch [179/200], Loss: 0.0173
# Epoch [180/200], Loss: 0.0344
# Epoch [181/200], Loss: 0.0294
# Epoch [182/200], Loss: 0.0160
# Epoch [183/200], Loss: 0.0212
# Epoch [184/200], Loss: 0.0188
# Epoch [185/200], Loss: 0.0209
# Epoch [186/200], Loss: 0.0201
# Epoch [187/200], Loss: 0.0456
# Epoch [188/200], Loss: 0.0148
# Epoch [189/200], Loss: 0.1473
# Epoch [190/200], Loss: 0.0214
# Epoch [191/200], Loss: 0.0210
# Epoch [192/200], Loss: 0.0170
# Epoch [193/200], Loss: 0.0184
# Epoch [194/200], Loss: 0.0254
# Epoch [195/200], Loss: 0.0170
# Epoch [196/200], Loss: 0.0177
# Epoch [197/200], Loss: 0.0242
# Epoch [198/200], Loss: 0.0171
# Epoch [199/200], Loss: 0.0186
# Epoch [200/200], Loss: 0.0200
# Overall Accuracy: 0.8152
# Average Accuracy: 0.8471
# Kappa Coefficient: 0.7995
#
# Prediction Distribution:
# Class 0: 877 predictions
# Class 1: 1164 predictions
# Class 2: 440 predictions
# Class 3: 1238 predictions
# Class 4: 1028 predictions
# Class 5: 183 predictions
# Class 6: 785 predictions
# Class 7: 855 predictions
# Class 8: 796 predictions
# Class 9: 1403 predictions
# Class 10: 1127 predictions
# Class 11: 1165 predictions
# Class 12: 346 predictions
# Class 13: 291 predictions
# Class 14: 499 predictions
# Loaded pre-trained weights for the entire feature extractor.
# Epoch [1/200], Loss: 2.8670
# Epoch [2/200], Loss: 2.6804
# Epoch [3/200], Loss: 2.5265
# Epoch [4/200], Loss: 2.3613
# Epoch [5/200], Loss: 2.2681
# Epoch [6/200], Loss: 2.1667
# Epoch [7/200], Loss: 2.0946
# Epoch [8/200], Loss: 2.0115
# Epoch [9/200], Loss: 1.8596
# Epoch [10/200], Loss: 1.8727
# Epoch [11/200], Loss: 1.7904
# Epoch [12/200], Loss: 1.6743
# Epoch [13/200], Loss: 1.5940
# Epoch [14/200], Loss: 1.5146
# Epoch [15/200], Loss: 1.4582
# Epoch [16/200], Loss: 1.4045
# Epoch [17/200], Loss: 1.2932
# Epoch [18/200], Loss: 1.2847
# Epoch [19/200], Loss: 1.1641
# Epoch [20/200], Loss: 1.1434
# Epoch [21/200], Loss: 1.0925
# Epoch [22/200], Loss: 1.0240
# Epoch [23/200], Loss: 1.0413
# Epoch [24/200], Loss: 0.9552
# Epoch [25/200], Loss: 0.9300
# Epoch [26/200], Loss: 0.8965
# Epoch [27/200], Loss: 0.8207
# Epoch [28/200], Loss: 0.8085
# Epoch [29/200], Loss: 0.7235
# Epoch [30/200], Loss: 0.7082
# Epoch [31/200], Loss: 0.7749
# Epoch [32/200], Loss: 0.6558
# Epoch [33/200], Loss: 0.7109
# Epoch [34/200], Loss: 0.5639
# Epoch [35/200], Loss: 0.5934
# Epoch [36/200], Loss: 0.5650
# Epoch [37/200], Loss: 0.5821
# Epoch [38/200], Loss: 0.4886
# Epoch [39/200], Loss: 0.5072
# Epoch [40/200], Loss: 0.4743
# Epoch [41/200], Loss: 0.4248
# Epoch [42/200], Loss: 0.4395
# Epoch [43/200], Loss: 0.4147
# Epoch [44/200], Loss: 0.4010
# Epoch [45/200], Loss: 0.4000
# Epoch [46/200], Loss: 0.3631
# Epoch [47/200], Loss: 0.3416
# Epoch [48/200], Loss: 0.3471
# Epoch [49/200], Loss: 0.3504
# Epoch [50/200], Loss: 0.3208
# Epoch [51/200], Loss: 0.2660
# Epoch [52/200], Loss: 0.2728
# Epoch [53/200], Loss: 0.2631
# Epoch [54/200], Loss: 0.2803
# Epoch [55/200], Loss: 0.2569
# Epoch [56/200], Loss: 0.2208
# Epoch [57/200], Loss: 0.2367
# Epoch [58/200], Loss: 0.2152
# Epoch [59/200], Loss: 0.2090
# Epoch [60/200], Loss: 0.2179
# Epoch [61/200], Loss: 0.2266
# Epoch [62/200], Loss: 0.2116
# Epoch [63/200], Loss: 0.2201
# Epoch [64/200], Loss: 0.1674
# Epoch [65/200], Loss: 0.1941
# Epoch [66/200], Loss: 0.1825
# Epoch [67/200], Loss: 0.1767
# Epoch [68/200], Loss: 0.1543
# Epoch [69/200], Loss: 0.1417
# Epoch [70/200], Loss: 0.1156
# Epoch [71/200], Loss: 0.1374
# Epoch [72/200], Loss: 0.1175
# Epoch [73/200], Loss: 0.1135
# Epoch [74/200], Loss: 0.1610
# Epoch [75/200], Loss: 0.1170
# Epoch [76/200], Loss: 0.1348
# Epoch [77/200], Loss: 0.0959
# Epoch [78/200], Loss: 0.1073
# Epoch [79/200], Loss: 0.1084
# Epoch [80/200], Loss: 0.1376
# Epoch [81/200], Loss: 0.0994
# Epoch [82/200], Loss: 0.0749
# Epoch [83/200], Loss: 0.1017
# Epoch [84/200], Loss: 0.0922
# Epoch [85/200], Loss: 0.1075
# Epoch [86/200], Loss: 0.1298
# Epoch [87/200], Loss: 0.1143
# Epoch [88/200], Loss: 0.0964
# Epoch [89/200], Loss: 0.0823
# Epoch [90/200], Loss: 0.0999
# Epoch [91/200], Loss: 0.0755
# Epoch [92/200], Loss: 0.0748
# Epoch [93/200], Loss: 0.0853
# Epoch [94/200], Loss: 0.1112
# Epoch [95/200], Loss: 0.0661
# Epoch [96/200], Loss: 0.0567
# Epoch [97/200], Loss: 0.0629
# Epoch [98/200], Loss: 0.0749
# Epoch [99/200], Loss: 0.0606
# Epoch [100/200], Loss: 0.0846
# Epoch [101/200], Loss: 0.0414
# Epoch [102/200], Loss: 0.0471
# Epoch [103/200], Loss: 0.0455
# Epoch [104/200], Loss: 0.0631
# Epoch [105/200], Loss: 0.0552
# Epoch [106/200], Loss: 0.0454
# Epoch [107/200], Loss: 0.0468
# Epoch [108/200], Loss: 0.0515
# Epoch [109/200], Loss: 0.0553
# Epoch [110/200], Loss: 0.0506
# Epoch [111/200], Loss: 0.0395
# Epoch [112/200], Loss: 0.0530
# Epoch [113/200], Loss: 0.0703
# Epoch [114/200], Loss: 0.0367
# Epoch [115/200], Loss: 0.0345
# Epoch [116/200], Loss: 0.0302
# Epoch [117/200], Loss: 0.0267
# Epoch [118/200], Loss: 0.0292
# Epoch [119/200], Loss: 0.0320
# Epoch [120/200], Loss: 0.0376
# Epoch [121/200], Loss: 0.0320
# Epoch [122/200], Loss: 0.0571
# Epoch [123/200], Loss: 0.0273
# Epoch [124/200], Loss: 0.0358
# Epoch [125/200], Loss: 0.0282
# Epoch [126/200], Loss: 0.0403
# Epoch [127/200], Loss: 0.0262
# Epoch [128/200], Loss: 0.0370
# Epoch [129/200], Loss: 0.0350
# Epoch [130/200], Loss: 0.0295
# Epoch [131/200], Loss: 0.0306
# Epoch [132/200], Loss: 0.0253
# Epoch [133/200], Loss: 0.0308
# Epoch [134/200], Loss: 0.0314
# Epoch [135/200], Loss: 0.0358
# Epoch [136/200], Loss: 0.0298
# Epoch [137/200], Loss: 0.0246
# Epoch [138/200], Loss: 0.0293
# Epoch [139/200], Loss: 0.0260
# Epoch [140/200], Loss: 0.0325
# Epoch [141/200], Loss: 0.0359
# Epoch [142/200], Loss: 0.0190
# Epoch [143/200], Loss: 0.0341
# Epoch [144/200], Loss: 0.0353
# Epoch [145/200], Loss: 0.0207
# Epoch [146/200], Loss: 0.0440
# Epoch [147/200], Loss: 0.0248
# Epoch [148/200], Loss: 0.0234
# Epoch [149/200], Loss: 0.0271
# Epoch [150/200], Loss: 0.0313
# Epoch [151/200], Loss: 0.0164
# Epoch [152/200], Loss: 0.0219
# Epoch [153/200], Loss: 0.0244
# Epoch [154/200], Loss: 0.0326
# Epoch [155/200], Loss: 0.0272
# Epoch [156/200], Loss: 0.0156
# Epoch [157/200], Loss: 0.0165
# Epoch [158/200], Loss: 0.0258
# Epoch [159/200], Loss: 0.0189
# Epoch [160/200], Loss: 0.0181
# Epoch [161/200], Loss: 0.0157
# Epoch [162/200], Loss: 0.0176
# Epoch [163/200], Loss: 0.0165
# Epoch [164/200], Loss: 0.0148
# Epoch [165/200], Loss: 0.0177
# Epoch [166/200], Loss: 0.0152
# Epoch [167/200], Loss: 0.0135
# Epoch [168/200], Loss: 0.0514
# Epoch [169/200], Loss: 0.0127
# Epoch [170/200], Loss: 0.0175
# Epoch [171/200], Loss: 0.0377
# Epoch [172/200], Loss: 0.0215
# Epoch [173/200], Loss: 0.0190
# Epoch [174/200], Loss: 0.0129
# Epoch [175/200], Loss: 0.0276
# Epoch [176/200], Loss: 0.0170
# Epoch [177/200], Loss: 0.0218
# Epoch [178/200], Loss: 0.0129
# Epoch [179/200], Loss: 0.0178
# Epoch [180/200], Loss: 0.0140
# Epoch [181/200], Loss: 0.0196
# Epoch [182/200], Loss: 0.0120
# Epoch [183/200], Loss: 0.0170
# Epoch [184/200], Loss: 0.0131
# Epoch [185/200], Loss: 0.0447
# Epoch [186/200], Loss: 0.0099
# Epoch [187/200], Loss: 0.0351
# Epoch [188/200], Loss: 0.0215
# Epoch [189/200], Loss: 0.0110
# Epoch [190/200], Loss: 0.0207
# Epoch [191/200], Loss: 0.0159
# Epoch [192/200], Loss: 0.0112
# Epoch [193/200], Loss: 0.0115
# Epoch [194/200], Loss: 0.0117
# Epoch [195/200], Loss: 0.0129
# Epoch [196/200], Loss: 0.0213
# Epoch [197/200], Loss: 0.0118
# Epoch [198/200], Loss: 0.0131
# Epoch [199/200], Loss: 0.0091
# Epoch [200/200], Loss: 0.0161
# Overall Accuracy: 0.8262
# Average Accuracy: 0.8562
# Kappa Coefficient: 0.8115
#
# Prediction Distribution:
# Class 0: 910 predictions
# Class 1: 1329 predictions
# Class 2: 455 predictions
# Class 3: 1121 predictions
# Class 4: 1059 predictions
# Class 5: 221 predictions
# Class 6: 833 predictions
# Class 7: 859 predictions
# Class 8: 876 predictions
# Class 9: 1377 predictions
# Class 10: 1124 predictions
# Class 11: 884 predictions
# Class 12: 365 predictions
# Class 13: 283 predictions
# Class 14: 501 predictions
# Loaded pre-trained weights for the entire feature extractor.
# Epoch [1/200], Loss: 2.9154
# Epoch [2/200], Loss: 2.6728
# Epoch [3/200], Loss: 2.5119
# Epoch [4/200], Loss: 2.3886
# Epoch [5/200], Loss: 2.2693
# Epoch [6/200], Loss: 2.2104
# Epoch [7/200], Loss: 2.1513
# Epoch [8/200], Loss: 2.0271
# Epoch [9/200], Loss: 1.9538
# Epoch [10/200], Loss: 1.8457
# Epoch [11/200], Loss: 1.8040
# Epoch [12/200], Loss: 1.7267
# Epoch [13/200], Loss: 1.6065
# Epoch [14/200], Loss: 1.5825
# Epoch [15/200], Loss: 1.4820
# Epoch [16/200], Loss: 1.4048
# Epoch [17/200], Loss: 1.3762
# Epoch [18/200], Loss: 1.2383
# Epoch [19/200], Loss: 1.2171
# Epoch [20/200], Loss: 1.1805
# Epoch [21/200], Loss: 1.0887
# Epoch [22/200], Loss: 1.0908
# Epoch [23/200], Loss: 1.0193
# Epoch [24/200], Loss: 1.0182
# Epoch [25/200], Loss: 0.9304
# Epoch [26/200], Loss: 0.9056
# Epoch [27/200], Loss: 0.8360
# Epoch [28/200], Loss: 0.9084
# Epoch [29/200], Loss: 0.8261
# Epoch [30/200], Loss: 0.7961
# Epoch [31/200], Loss: 0.7698
# Epoch [32/200], Loss: 0.7316
# Epoch [33/200], Loss: 0.6270
# Epoch [34/200], Loss: 0.6691
# Epoch [35/200], Loss: 0.6187
# Epoch [36/200], Loss: 0.6140
# Epoch [37/200], Loss: 0.5954
# Epoch [38/200], Loss: 0.5212
# Epoch [39/200], Loss: 0.5737
# Epoch [40/200], Loss: 0.5330
# Epoch [41/200], Loss: 0.5101
# Epoch [42/200], Loss: 0.5014
# Epoch [43/200], Loss: 0.5214
# Epoch [44/200], Loss: 0.4265
# Epoch [45/200], Loss: 0.4253
# Epoch [46/200], Loss: 0.4546
# Epoch [47/200], Loss: 0.4447
# Epoch [48/200], Loss: 0.4624
# Epoch [49/200], Loss: 0.3813
# Epoch [50/200], Loss: 0.3850
# Epoch [51/200], Loss: 0.3778
# Epoch [52/200], Loss: 0.3263
# Epoch [53/200], Loss: 0.3738
# Epoch [54/200], Loss: 0.3403
# Epoch [55/200], Loss: 0.3355
# Epoch [56/200], Loss: 0.3303
# Epoch [57/200], Loss: 0.3534
# Epoch [58/200], Loss: 0.3196
# Epoch [59/200], Loss: 0.2885
# Epoch [60/200], Loss: 0.2687
# Epoch [61/200], Loss: 0.2832
# Epoch [62/200], Loss: 0.2512
# Epoch [63/200], Loss: 0.3026
# Epoch [64/200], Loss: 0.2584
# Epoch [65/200], Loss: 0.3070
# Epoch [66/200], Loss: 0.2298
# Epoch [67/200], Loss: 0.2325
# Epoch [68/200], Loss: 0.2484
# Epoch [69/200], Loss: 0.1929
# Epoch [70/200], Loss: 0.2139
# Epoch [71/200], Loss: 0.2208
# Epoch [72/200], Loss: 0.2142
# Epoch [73/200], Loss: 0.2099
# Epoch [74/200], Loss: 0.2263
# Epoch [75/200], Loss: 0.1739
# Epoch [76/200], Loss: 0.1787
# Epoch [77/200], Loss: 0.1695
# Epoch [78/200], Loss: 0.1581
# Epoch [79/200], Loss: 0.1558
# Epoch [80/200], Loss: 0.1441
# Epoch [81/200], Loss: 0.1617
# Epoch [82/200], Loss: 0.1440
# Epoch [83/200], Loss: 0.1507
# Epoch [84/200], Loss: 0.1341
# Epoch [85/200], Loss: 0.1201
# Epoch [86/200], Loss: 0.1272
# Epoch [87/200], Loss: 0.1274
# Epoch [88/200], Loss: 0.1098
# Epoch [89/200], Loss: 0.1348
# Epoch [90/200], Loss: 0.1111
# Epoch [91/200], Loss: 0.0991
# Epoch [92/200], Loss: 0.1368
# Epoch [93/200], Loss: 0.0913
# Epoch [94/200], Loss: 0.0987
# Epoch [95/200], Loss: 0.0938
# Epoch [96/200], Loss: 0.1038
# Epoch [97/200], Loss: 0.0853
# Epoch [98/200], Loss: 0.1002
# Epoch [99/200], Loss: 0.0744
# Epoch [100/200], Loss: 0.1056
# Epoch [101/200], Loss: 0.1271
# Epoch [102/200], Loss: 0.0901
# Epoch [103/200], Loss: 0.0941
# Epoch [104/200], Loss: 0.0845
# Epoch [105/200], Loss: 0.0716
# Epoch [106/200], Loss: 0.0764
# Epoch [107/200], Loss: 0.0637
# Epoch [108/200], Loss: 0.1076
# Epoch [109/200], Loss: 0.0664
# Epoch [110/200], Loss: 0.0669
# Epoch [111/200], Loss: 0.0523
# Epoch [112/200], Loss: 0.0551
# Epoch [113/200], Loss: 0.0522
# Epoch [114/200], Loss: 0.0535
# Epoch [115/200], Loss: 0.0634
# Epoch [116/200], Loss: 0.0470
# Epoch [117/200], Loss: 0.0718
# Epoch [118/200], Loss: 0.0708
# Epoch [119/200], Loss: 0.0548
# Epoch [120/200], Loss: 0.0474
# Epoch [121/200], Loss: 0.0439
# Epoch [122/200], Loss: 0.0559
# Epoch [123/200], Loss: 0.0432
# Epoch [124/200], Loss: 0.0506
# Epoch [125/200], Loss: 0.0601
# Epoch [126/200], Loss: 0.0465
# Epoch [127/200], Loss: 0.0478
# Epoch [128/200], Loss: 0.0400
# Epoch [129/200], Loss: 0.0368
# Epoch [130/200], Loss: 0.0432
# Epoch [131/200], Loss: 0.0335
# Epoch [132/200], Loss: 0.0363
# Epoch [133/200], Loss: 0.0357
# Epoch [134/200], Loss: 0.0575
# Epoch [135/200], Loss: 0.0643
# Epoch [136/200], Loss: 0.0369
# Epoch [137/200], Loss: 0.0417
# Epoch [138/200], Loss: 0.0446
# Epoch [139/200], Loss: 0.0428
# Epoch [140/200], Loss: 0.0399
# Epoch [141/200], Loss: 0.0330
# Epoch [142/200], Loss: 0.0312
# Epoch [143/200], Loss: 0.0320
# Epoch [144/200], Loss: 0.0234
# Epoch [145/200], Loss: 0.0451
# Epoch [146/200], Loss: 0.0340
# Epoch [147/200], Loss: 0.0299
# Epoch [148/200], Loss: 0.0301
# Epoch [149/200], Loss: 0.0340
# Epoch [150/200], Loss: 0.0246
# Epoch [151/200], Loss: 0.0229
# Epoch [152/200], Loss: 0.0273
# Epoch [153/200], Loss: 0.0231
# Epoch [154/200], Loss: 0.0227
# Epoch [155/200], Loss: 0.0212
# Epoch [156/200], Loss: 0.0219
# Epoch [157/200], Loss: 0.0219
# Epoch [158/200], Loss: 0.0198
# Epoch [159/200], Loss: 0.0241
# Epoch [160/200], Loss: 0.0263
# Epoch [161/200], Loss: 0.0246
# Epoch [162/200], Loss: 0.0393
# Epoch [163/200], Loss: 0.0451
# Epoch [164/200], Loss: 0.0177
# Epoch [165/200], Loss: 0.0160
# Epoch [166/200], Loss: 0.0222
# Epoch [167/200], Loss: 0.0279
# Epoch [168/200], Loss: 0.0188
# Epoch [169/200], Loss: 0.0180
# Epoch [170/200], Loss: 0.0261
# Epoch [171/200], Loss: 0.0201
# Epoch [172/200], Loss: 0.0206
# Epoch [173/200], Loss: 0.0178
# Epoch [174/200], Loss: 0.0153
# Epoch [175/200], Loss: 0.0159
# Epoch [176/200], Loss: 0.0147
# Epoch [177/200], Loss: 0.0207
# Epoch [178/200], Loss: 0.0155
# Epoch [179/200], Loss: 0.0135
# Epoch [180/200], Loss: 0.0185
# Epoch [181/200], Loss: 0.0392
# Epoch [182/200], Loss: 0.0189
# Epoch [183/200], Loss: 0.0659
# Epoch [184/200], Loss: 0.0239
# Epoch [185/200], Loss: 0.0252
# Epoch [186/200], Loss: 0.0135
# Epoch [187/200], Loss: 0.0180
# Epoch [188/200], Loss: 0.0212
# Epoch [189/200], Loss: 0.0150
# Epoch [190/200], Loss: 0.0129
# Epoch [191/200], Loss: 0.0150
# Epoch [192/200], Loss: 0.0127
# Epoch [193/200], Loss: 0.0205
# Epoch [194/200], Loss: 0.0119
# Epoch [195/200], Loss: 0.0170
# Epoch [196/200], Loss: 0.0241
# Epoch [197/200], Loss: 0.0110
# Epoch [198/200], Loss: 0.0116
# Epoch [199/200], Loss: 0.0136
# Epoch [200/200], Loss: 0.0086
# Overall Accuracy: 0.8230
# Average Accuracy: 0.8535
# Kappa Coefficient: 0.8079
#
# Prediction Distribution:
# Class 0: 901 predictions
# Class 1: 1246 predictions
# Class 2: 436 predictions
# Class 3: 1165 predictions
# Class 4: 1027 predictions
# Class 5: 164 predictions
# Class 6: 803 predictions
# Class 7: 793 predictions
# Class 8: 771 predictions
# Class 9: 1561 predictions
# Class 10: 1089 predictions
# Class 11: 1089 predictions
# Class 12: 353 predictions
# Class 13: 281 predictions
# Class 14: 518 predictions
# Loaded pre-trained weights for the entire feature extractor.
# Epoch [1/200], Loss: 2.9119
# Epoch [2/200], Loss: 2.6741
# Epoch [3/200], Loss: 2.5105
# Epoch [4/200], Loss: 2.4268
# Epoch [5/200], Loss: 2.3114
# Epoch [6/200], Loss: 2.2001
# Epoch [7/200], Loss: 2.0554
# Epoch [8/200], Loss: 2.0463
# Epoch [9/200], Loss: 1.9251
# Epoch [10/200], Loss: 1.8492
# Epoch [11/200], Loss: 1.7821
# Epoch [12/200], Loss: 1.7277
# Epoch [13/200], Loss: 1.6126
# Epoch [14/200], Loss: 1.5715
# Epoch [15/200], Loss: 1.4843
# Epoch [16/200], Loss: 1.4132
# Epoch [17/200], Loss: 1.3746
# Epoch [18/200], Loss: 1.3249
# Epoch [19/200], Loss: 1.2840
# Epoch [20/200], Loss: 1.2600
# Epoch [21/200], Loss: 1.2050
# Epoch [22/200], Loss: 1.1549
# Epoch [23/200], Loss: 1.0707
# Epoch [24/200], Loss: 1.0555
# Epoch [25/200], Loss: 1.0162
# Epoch [26/200], Loss: 0.9687
# Epoch [27/200], Loss: 0.9858
# Epoch [28/200], Loss: 0.9231
# Epoch [29/200], Loss: 0.8566
# Epoch [30/200], Loss: 0.8321
# Epoch [31/200], Loss: 0.7927
# Epoch [32/200], Loss: 0.7883
# Epoch [33/200], Loss: 0.7457
# Epoch [34/200], Loss: 0.7074
# Epoch [35/200], Loss: 0.6587
# Epoch [36/200], Loss: 0.7281
# Epoch [37/200], Loss: 0.6703
# Epoch [38/200], Loss: 0.6253
# Epoch [39/200], Loss: 0.5873
# Epoch [40/200], Loss: 0.6167
# Epoch [41/200], Loss: 0.5598
# Epoch [42/200], Loss: 0.5412
# Epoch [43/200], Loss: 0.5121
# Epoch [44/200], Loss: 0.4649
# Epoch [45/200], Loss: 0.4635
# Epoch [46/200], Loss: 0.4494
# Epoch [47/200], Loss: 0.4186
# Epoch [48/200], Loss: 0.4325
# Epoch [49/200], Loss: 0.3882
# Epoch [50/200], Loss: 0.4918
# Epoch [51/200], Loss: 0.3858
# Epoch [52/200], Loss: 0.3898
# Epoch [53/200], Loss: 0.3904
# Epoch [54/200], Loss: 0.3444
# Epoch [55/200], Loss: 0.3615
# Epoch [56/200], Loss: 0.3361
# Epoch [57/200], Loss: 0.3735
# Epoch [58/200], Loss: 0.2984
# Epoch [59/200], Loss: 0.3119
# Epoch [60/200], Loss: 0.2732
# Epoch [61/200], Loss: 0.2368
# Epoch [62/200], Loss: 0.2519
# Epoch [63/200], Loss: 0.3141
# Epoch [64/200], Loss: 0.2820
# Epoch [65/200], Loss: 0.2647
# Epoch [66/200], Loss: 0.2541
# Epoch [67/200], Loss: 0.2211
# Epoch [68/200], Loss: 0.2330
# Epoch [69/200], Loss: 0.2524
# Epoch [70/200], Loss: 0.1769
# Epoch [71/200], Loss: 0.2001
# Epoch [72/200], Loss: 0.1730
# Epoch [73/200], Loss: 0.1919
# Epoch [74/200], Loss: 0.1653
# Epoch [75/200], Loss: 0.1632
# Epoch [76/200], Loss: 0.1867
# Epoch [77/200], Loss: 0.1829
# Epoch [78/200], Loss: 0.1548
# Epoch [79/200], Loss: 0.1558
# Epoch [80/200], Loss: 0.1518
# Epoch [81/200], Loss: 0.1417
# Epoch [82/200], Loss: 0.1877
# Epoch [83/200], Loss: 0.1586
# Epoch [84/200], Loss: 0.1956
# Epoch [85/200], Loss: 0.1464
# Epoch [86/200], Loss: 0.1642
# Epoch [87/200], Loss: 0.1342
# Epoch [88/200], Loss: 0.1206
# Epoch [89/200], Loss: 0.0949
# Epoch [90/200], Loss: 0.0971
# Epoch [91/200], Loss: 0.1043
# Epoch [92/200], Loss: 0.0854
# Epoch [93/200], Loss: 0.1149
# Epoch [94/200], Loss: 0.1386
# Epoch [95/200], Loss: 0.0777
# Epoch [96/200], Loss: 0.0893
# Epoch [97/200], Loss: 0.1042
# Epoch [98/200], Loss: 0.0853
# Epoch [99/200], Loss: 0.1028
# Epoch [100/200], Loss: 0.0889
# Epoch [101/200], Loss: 0.0841
# Epoch [102/200], Loss: 0.0661
# Epoch [103/200], Loss: 0.1059
# Epoch [104/200], Loss: 0.0769
# Epoch [105/200], Loss: 0.0720
# Epoch [106/200], Loss: 0.0713
# Epoch [107/200], Loss: 0.0626
# Epoch [108/200], Loss: 0.0602
# Epoch [109/200], Loss: 0.0627
# Epoch [110/200], Loss: 0.0745
# Epoch [111/200], Loss: 0.0672
# Epoch [112/200], Loss: 0.0671
# Epoch [113/200], Loss: 0.0551
# Epoch [114/200], Loss: 0.0556
# Epoch [115/200], Loss: 0.0556
# Epoch [116/200], Loss: 0.1204
# Epoch [117/200], Loss: 0.0867
# Epoch [118/200], Loss: 0.0572
# Epoch [119/200], Loss: 0.0521
# Epoch [120/200], Loss: 0.0663
# Epoch [121/200], Loss: 0.0626
# Epoch [122/200], Loss: 0.0431
# Epoch [123/200], Loss: 0.0643
# Epoch [124/200], Loss: 0.0471
# Epoch [125/200], Loss: 0.0628
# Epoch [126/200], Loss: 0.0518
# Epoch [127/200], Loss: 0.0425
# Epoch [128/200], Loss: 0.0675
# Epoch [129/200], Loss: 0.0453
# Epoch [130/200], Loss: 0.0430
# Epoch [131/200], Loss: 0.0442
# Epoch [132/200], Loss: 0.0656
# Epoch [133/200], Loss: 0.0376
# Epoch [134/200], Loss: 0.0788
# Epoch [135/200], Loss: 0.0558
# Epoch [136/200], Loss: 0.0330
# Epoch [137/200], Loss: 0.0418
# Epoch [138/200], Loss: 0.0323
# Epoch [139/200], Loss: 0.0468
# Epoch [140/200], Loss: 0.0297
# Epoch [141/200], Loss: 0.0481
# Epoch [142/200], Loss: 0.0517
# Epoch [143/200], Loss: 0.0699
# Epoch [144/200], Loss: 0.0328
# Epoch [145/200], Loss: 0.0511
# Epoch [146/200], Loss: 0.0506
# Epoch [147/200], Loss: 0.0312
# Epoch [148/200], Loss: 0.0399
# Epoch [149/200], Loss: 0.0409
# Epoch [150/200], Loss: 0.0329
# Epoch [151/200], Loss: 0.0265
# Epoch [152/200], Loss: 0.0293
# Epoch [153/200], Loss: 0.0776
# Epoch [154/200], Loss: 0.0348
# Epoch [155/200], Loss: 0.0269
# Epoch [156/200], Loss: 0.0287
# Epoch [157/200], Loss: 0.0530
# Epoch [158/200], Loss: 0.0310
# Epoch [159/200], Loss: 0.0271
# Epoch [160/200], Loss: 0.0711
# Epoch [161/200], Loss: 0.0288
# Epoch [162/200], Loss: 0.0221
# Epoch [163/200], Loss: 0.0505
# Epoch [164/200], Loss: 0.0189
# Epoch [165/200], Loss: 0.0250
# Epoch [166/200], Loss: 0.0319
# Epoch [167/200], Loss: 0.0172
# Epoch [168/200], Loss: 0.0218
# Epoch [169/200], Loss: 0.0175
# Epoch [170/200], Loss: 0.0319
# Epoch [171/200], Loss: 0.0198
# Epoch [172/200], Loss: 0.0188
# Epoch [173/200], Loss: 0.0460
# Epoch [174/200], Loss: 0.0381
# Epoch [175/200], Loss: 0.0184
# Epoch [176/200], Loss: 0.0325
# Epoch [177/200], Loss: 0.0186
# Epoch [178/200], Loss: 0.0177
# Epoch [179/200], Loss: 0.0229
# Epoch [180/200], Loss: 0.0215
# Epoch [181/200], Loss: 0.0174
# Epoch [182/200], Loss: 0.0140
# Epoch [183/200], Loss: 0.0169
# Epoch [184/200], Loss: 0.0116
# Epoch [185/200], Loss: 0.0221
# Epoch [186/200], Loss: 0.0165
# Epoch [187/200], Loss: 0.0212
# Epoch [188/200], Loss: 0.0164
# Epoch [189/200], Loss: 0.0175
# Epoch [190/200], Loss: 0.0127
# Epoch [191/200], Loss: 0.0206
# Epoch [192/200], Loss: 0.0689
# Epoch [193/200], Loss: 0.0377
# Epoch [194/200], Loss: 0.0186
# Epoch [195/200], Loss: 0.0213
# Epoch [196/200], Loss: 0.0155
# Epoch [197/200], Loss: 0.0172
# Epoch [198/200], Loss: 0.0261
# Epoch [199/200], Loss: 0.0157
# Epoch [200/200], Loss: 0.0126
# Overall Accuracy: 0.8429
# Average Accuracy: 0.8690
# Kappa Coefficient: 0.8296
#
# Prediction Distribution:
# Class 0: 891 predictions
# Class 1: 1309 predictions
# Class 2: 459 predictions
# Class 3: 1041 predictions
# Class 4: 1059 predictions
# Class 5: 204 predictions
# Class 6: 901 predictions
# Class 7: 888 predictions
# Class 8: 849 predictions
# Class 9: 1494 predictions
# Class 10: 948 predictions
# Class 11: 1002 predictions
# Class 12: 345 predictions
# Class 13: 307 predictions
# Class 14: 500 predictions
# Loaded pre-trained weights for the entire feature extractor.
# Epoch [1/200], Loss: 2.8015
# Epoch [2/200], Loss: 2.5558
# Epoch [3/200], Loss: 2.4189
# Epoch [4/200], Loss: 2.3307
# Epoch [5/200], Loss: 2.2348
# Epoch [6/200], Loss: 2.1079
# Epoch [7/200], Loss: 2.0928
# Epoch [8/200], Loss: 1.9363
# Epoch [9/200], Loss: 1.8856
# Epoch [10/200], Loss: 1.8049
# Epoch [11/200], Loss: 1.7662
# Epoch [12/200], Loss: 1.6098
# Epoch [13/200], Loss: 1.6102
# Epoch [14/200], Loss: 1.5347
# Epoch [15/200], Loss: 1.4963
# Epoch [16/200], Loss: 1.4780
# Epoch [17/200], Loss: 1.4083
# Epoch [18/200], Loss: 1.2950
# Epoch [19/200], Loss: 1.2966
# Epoch [20/200], Loss: 1.2778
# Epoch [21/200], Loss: 1.1371
# Epoch [22/200], Loss: 1.1765
# Epoch [23/200], Loss: 1.1105
# Epoch [24/200], Loss: 1.0169
# Epoch [25/200], Loss: 0.9512
# Epoch [26/200], Loss: 0.9069
# Epoch [27/200], Loss: 0.8916
# Epoch [28/200], Loss: 0.8633
# Epoch [29/200], Loss: 0.8216
# Epoch [30/200], Loss: 0.8446
# Epoch [31/200], Loss: 0.7990
# Epoch [32/200], Loss: 0.6829
# Epoch [33/200], Loss: 0.7144
# Epoch [34/200], Loss: 0.6825
# Epoch [35/200], Loss: 0.6599
# Epoch [36/200], Loss: 0.6334
# Epoch [37/200], Loss: 0.6150
# Epoch [38/200], Loss: 0.6007
# Epoch [39/200], Loss: 0.5862
# Epoch [40/200], Loss: 0.5724
# Epoch [41/200], Loss: 0.5201
# Epoch [42/200], Loss: 0.4966
# Epoch [43/200], Loss: 0.5255
# Epoch [44/200], Loss: 0.4678
# Epoch [45/200], Loss: 0.4455
# Epoch [46/200], Loss: 0.4298
# Epoch [47/200], Loss: 0.4210
# Epoch [48/200], Loss: 0.3921
# Epoch [49/200], Loss: 0.3708
# Epoch [50/200], Loss: 0.3509
# Epoch [51/200], Loss: 0.3847
# Epoch [52/200], Loss: 0.3615
# Epoch [53/200], Loss: 0.3518
# Epoch [54/200], Loss: 0.3433
# Epoch [55/200], Loss: 0.3298
# Epoch [56/200], Loss: 0.2864
# Epoch [57/200], Loss: 0.2829
# Epoch [58/200], Loss: 0.2852
# Epoch [59/200], Loss: 0.2899
# Epoch [60/200], Loss: 0.2523
# Epoch [61/200], Loss: 0.2650
# Epoch [62/200], Loss: 0.2638
# Epoch [63/200], Loss: 0.2485
# Epoch [64/200], Loss: 0.2330
# Epoch [65/200], Loss: 0.2692
# Epoch [66/200], Loss: 0.1778
# Epoch [67/200], Loss: 0.2073
# Epoch [68/200], Loss: 0.1582
# Epoch [69/200], Loss: 0.2155
# Epoch [70/200], Loss: 0.1777
# Epoch [71/200], Loss: 0.2108
# Epoch [72/200], Loss: 0.1673
# Epoch [73/200], Loss: 0.1596
# Epoch [74/200], Loss: 0.1572
# Epoch [75/200], Loss: 0.1375
# Epoch [76/200], Loss: 0.1612
# Epoch [77/200], Loss: 0.1534
# Epoch [78/200], Loss: 0.1611
# Epoch [79/200], Loss: 0.1523
# Epoch [80/200], Loss: 0.1384
# Epoch [81/200], Loss: 0.1224
# Epoch [82/200], Loss: 0.1516
# Epoch [83/200], Loss: 0.1430
# Epoch [84/200], Loss: 0.1086
# Epoch [85/200], Loss: 0.1062
# Epoch [86/200], Loss: 0.1072
# Epoch [87/200], Loss: 0.1034
# Epoch [88/200], Loss: 0.1011
# Epoch [89/200], Loss: 0.1196
# Epoch [90/200], Loss: 0.1063
# Epoch [91/200], Loss: 0.1273
# Epoch [92/200], Loss: 0.1010
# Epoch [93/200], Loss: 0.0964
# Epoch [94/200], Loss: 0.0745
# Epoch [95/200], Loss: 0.0981
# Epoch [96/200], Loss: 0.1078
# Epoch [97/200], Loss: 0.0783
# Epoch [98/200], Loss: 0.0810
# Epoch [99/200], Loss: 0.0736
# Epoch [100/200], Loss: 0.0673
# Epoch [101/200], Loss: 0.0569
# Epoch [102/200], Loss: 0.0721
# Epoch [103/200], Loss: 0.0577
# Epoch [104/200], Loss: 0.0597
# Epoch [105/200], Loss: 0.0601
# Epoch [106/200], Loss: 0.0818
# Epoch [107/200], Loss: 0.0580
# Epoch [108/200], Loss: 0.0727
# Epoch [109/200], Loss: 0.0564
# Epoch [110/200], Loss: 0.0579
# Epoch [111/200], Loss: 0.0546
# Epoch [112/200], Loss: 0.0522
# Epoch [113/200], Loss: 0.0430
# Epoch [114/200], Loss: 0.0625
# Epoch [115/200], Loss: 0.0397
# Epoch [116/200], Loss: 0.0327
# Epoch [117/200], Loss: 0.0423
# Epoch [118/200], Loss: 0.0421
# Epoch [119/200], Loss: 0.0425
# Epoch [120/200], Loss: 0.0375
# Epoch [121/200], Loss: 0.0323
# Epoch [122/200], Loss: 0.0361
# Epoch [123/200], Loss: 0.0505
# Epoch [124/200], Loss: 0.0306
# Epoch [125/200], Loss: 0.0380
# Epoch [126/200], Loss: 0.0308
# Epoch [127/200], Loss: 0.0382
# Epoch [128/200], Loss: 0.0330
# Epoch [129/200], Loss: 0.0311
# Epoch [130/200], Loss: 0.0271
# Epoch [131/200], Loss: 0.0400
# Epoch [132/200], Loss: 0.0286
# Epoch [133/200], Loss: 0.0447
# Epoch [134/200], Loss: 0.0347
# Epoch [135/200], Loss: 0.0460
# Epoch [136/200], Loss: 0.0283
# Epoch [137/200], Loss: 0.0461
# Epoch [138/200], Loss: 0.0345
# Epoch [139/200], Loss: 0.0307
# Epoch [140/200], Loss: 0.0280
# Epoch [141/200], Loss: 0.0254
# Epoch [142/200], Loss: 0.0297
# Epoch [143/200], Loss: 0.0262
# Epoch [144/200], Loss: 0.0221
# Epoch [145/200], Loss: 0.0259
# Epoch [146/200], Loss: 0.0277
# Epoch [147/200], Loss: 0.0607
# Epoch [148/200], Loss: 0.0242
# Epoch [149/200], Loss: 0.0257
# Epoch [150/200], Loss: 0.0261
# Epoch [151/200], Loss: 0.0180
# Epoch [152/200], Loss: 0.0314
# Epoch [153/200], Loss: 0.0314
# Epoch [154/200], Loss: 0.0284
# Epoch [155/200], Loss: 0.0238
# Epoch [156/200], Loss: 0.0204
# Epoch [157/200], Loss: 0.0199
# Epoch [158/200], Loss: 0.0293
# Epoch [159/200], Loss: 0.0205
# Epoch [160/200], Loss: 0.0280
# Epoch [161/200], Loss: 0.0358
# Epoch [162/200], Loss: 0.0140
# Epoch [163/200], Loss: 0.0156
# Epoch [164/200], Loss: 0.0169
# Epoch [165/200], Loss: 0.0154
# Epoch [166/200], Loss: 0.0193
# Epoch [167/200], Loss: 0.0438
# Epoch [168/200], Loss: 0.0182
# Epoch [169/200], Loss: 0.0117
# Epoch [170/200], Loss: 0.0227
# Epoch [171/200], Loss: 0.0168
# Epoch [172/200], Loss: 0.0413
# Epoch [173/200], Loss: 0.0139
# Epoch [174/200], Loss: 0.0165
# Epoch [175/200], Loss: 0.0184
# Epoch [176/200], Loss: 0.0266
# Epoch [177/200], Loss: 0.0406
# Epoch [178/200], Loss: 0.0156
# Epoch [179/200], Loss: 0.0308
# Epoch [180/200], Loss: 0.0184
# Epoch [181/200], Loss: 0.0147
# Epoch [182/200], Loss: 0.0148
# Epoch [183/200], Loss: 0.0164
# Epoch [184/200], Loss: 0.0257
# Epoch [185/200], Loss: 0.0142
# Epoch [186/200], Loss: 0.0126
# Epoch [187/200], Loss: 0.0137
# Epoch [188/200], Loss: 0.0140
# Epoch [189/200], Loss: 0.0112
# Epoch [190/200], Loss: 0.0212
# Epoch [191/200], Loss: 0.0118
# Epoch [192/200], Loss: 0.0126
# Epoch [193/200], Loss: 0.0102
# Epoch [194/200], Loss: 0.0211
# Epoch [195/200], Loss: 0.0129
# Epoch [196/200], Loss: 0.0121
# Epoch [197/200], Loss: 0.0178
# Epoch [198/200], Loss: 0.0091
# Epoch [199/200], Loss: 0.0086
# Epoch [200/200], Loss: 0.0121
# Overall Accuracy: 0.8135
# Average Accuracy: 0.8431
# Kappa Coefficient: 0.7977
#
# Prediction Distribution:
# Class 0: 887 predictions
# Class 1: 1188 predictions
# Class 2: 441 predictions
# Class 3: 1199 predictions
# Class 4: 1024 predictions
# Class 5: 208 predictions
# Class 6: 899 predictions
# Class 7: 863 predictions
# Class 8: 814 predictions
# Class 9: 1575 predictions
# Class 10: 924 predictions
# Class 11: 1040 predictions
# Class 12: 346 predictions
# Class 13: 307 predictions
# Class 14: 482 predictions
# Loaded pre-trained weights for the entire feature extractor.
# Epoch [1/200], Loss: 2.9277
# Epoch [2/200], Loss: 2.6735
# Epoch [3/200], Loss: 2.4839
# Epoch [4/200], Loss: 2.3635
# Epoch [5/200], Loss: 2.2721
# Epoch [6/200], Loss: 2.1667
# Epoch [7/200], Loss: 2.1059
# Epoch [8/200], Loss: 2.0026
# Epoch [9/200], Loss: 1.8997
# Epoch [10/200], Loss: 1.8345
# Epoch [11/200], Loss: 1.8051
# Epoch [12/200], Loss: 1.6909
# Epoch [13/200], Loss: 1.5957
# Epoch [14/200], Loss: 1.5580
# Epoch [15/200], Loss: 1.5072
# Epoch [16/200], Loss: 1.4567
# Epoch [17/200], Loss: 1.3920
# Epoch [18/200], Loss: 1.3238
# Epoch [19/200], Loss: 1.3108
# Epoch [20/200], Loss: 1.2444
# Epoch [21/200], Loss: 1.1727
# Epoch [22/200], Loss: 1.1335
# Epoch [23/200], Loss: 1.0817
# Epoch [24/200], Loss: 1.0404
# Epoch [25/200], Loss: 1.0235
# Epoch [26/200], Loss: 0.9780
# Epoch [27/200], Loss: 0.9728
# Epoch [28/200], Loss: 0.8678
# Epoch [29/200], Loss: 0.8808
# Epoch [30/200], Loss: 0.8498
# Epoch [31/200], Loss: 0.7925
# Epoch [32/200], Loss: 0.7443
# Epoch [33/200], Loss: 0.7559
# Epoch [34/200], Loss: 0.6965
# Epoch [35/200], Loss: 0.6811
# Epoch [36/200], Loss: 0.6441
# Epoch [37/200], Loss: 0.6166
# Epoch [38/200], Loss: 0.6099
# Epoch [39/200], Loss: 0.5871
# Epoch [40/200], Loss: 0.6150
# Epoch [41/200], Loss: 0.5887
# Epoch [42/200], Loss: 0.5951
# Epoch [43/200], Loss: 0.5232
# Epoch [44/200], Loss: 0.4803
# Epoch [45/200], Loss: 0.4764
# Epoch [46/200], Loss: 0.4716
# Epoch [47/200], Loss: 0.4584
# Epoch [48/200], Loss: 0.4314
# Epoch [49/200], Loss: 0.4581
# Epoch [50/200], Loss: 0.3896
# Epoch [51/200], Loss: 0.3873
# Epoch [52/200], Loss: 0.3969
# Epoch [53/200], Loss: 0.3861
# Epoch [54/200], Loss: 0.3380
# Epoch [55/200], Loss: 0.3277
# Epoch [56/200], Loss: 0.3508
# Epoch [57/200], Loss: 0.3431
# Epoch [58/200], Loss: 0.2919
# Epoch [59/200], Loss: 0.3284
# Epoch [60/200], Loss: 0.2843
# Epoch [61/200], Loss: 0.2926
# Epoch [62/200], Loss: 0.3057
# Epoch [63/200], Loss: 0.2895
# Epoch [64/200], Loss: 0.2547
# Epoch [65/200], Loss: 0.2508
# Epoch [66/200], Loss: 0.2263
# Epoch [67/200], Loss: 0.2382
# Epoch [68/200], Loss: 0.2117
# Epoch [69/200], Loss: 0.2041
# Epoch [70/200], Loss: 0.2110
# Epoch [71/200], Loss: 0.1954
# Epoch [72/200], Loss: 0.1862
# Epoch [73/200], Loss: 0.1761
# Epoch [74/200], Loss: 0.1967
# Epoch [75/200], Loss: 0.1849
# Epoch [76/200], Loss: 0.2321
# Epoch [77/200], Loss: 0.1979
# Epoch [78/200], Loss: 0.2066
# Epoch [79/200], Loss: 0.1476
# Epoch [80/200], Loss: 0.1481
# Epoch [81/200], Loss: 0.1839
# Epoch [82/200], Loss: 0.1442
# Epoch [83/200], Loss: 0.1397
# Epoch [84/200], Loss: 0.1190
# Epoch [85/200], Loss: 0.1075
# Epoch [86/200], Loss: 0.1247
# Epoch [87/200], Loss: 0.1997
# Epoch [88/200], Loss: 0.1195
# Epoch [89/200], Loss: 0.1178
# Epoch [90/200], Loss: 0.1124
# Epoch [91/200], Loss: 0.1557
# Epoch [92/200], Loss: 0.1113
# Epoch [93/200], Loss: 0.1199
# Epoch [94/200], Loss: 0.1322
# Epoch [95/200], Loss: 0.0944
# Epoch [96/200], Loss: 0.1153
# Epoch [97/200], Loss: 0.0852
# Epoch [98/200], Loss: 0.0865
# Epoch [99/200], Loss: 0.0679
# Epoch [100/200], Loss: 0.0966
# Epoch [101/200], Loss: 0.0617
# Epoch [102/200], Loss: 0.0641
# Epoch [103/200], Loss: 0.0585
# Epoch [104/200], Loss: 0.0802
# Epoch [105/200], Loss: 0.0672
# Epoch [106/200], Loss: 0.1106
# Epoch [107/200], Loss: 0.0704
# Epoch [108/200], Loss: 0.0533
# Epoch [109/200], Loss: 0.0520
# Epoch [110/200], Loss: 0.1122
# Epoch [111/200], Loss: 0.0551
# Epoch [112/200], Loss: 0.0478
# Epoch [113/200], Loss: 0.0533
# Epoch [114/200], Loss: 0.0593
# Epoch [115/200], Loss: 0.0455
# Epoch [116/200], Loss: 0.0808
# Epoch [117/200], Loss: 0.0465
# Epoch [118/200], Loss: 0.0550
# Epoch [119/200], Loss: 0.0505
# Epoch [120/200], Loss: 0.0483
# Epoch [121/200], Loss: 0.0608
# Epoch [122/200], Loss: 0.0822
# Epoch [123/200], Loss: 0.0449
# Epoch [124/200], Loss: 0.0496
# Epoch [125/200], Loss: 0.0449
# Epoch [126/200], Loss: 0.0846
# Epoch [127/200], Loss: 0.0335
# Epoch [128/200], Loss: 0.0281
# Epoch [129/200], Loss: 0.0553
# Epoch [130/200], Loss: 0.0301
# Epoch [131/200], Loss: 0.0353
# Epoch [132/200], Loss: 0.0325
# Epoch [133/200], Loss: 0.0439
# Epoch [134/200], Loss: 0.0323
# Epoch [135/200], Loss: 0.0309
# Epoch [136/200], Loss: 0.0393
# Epoch [137/200], Loss: 0.0250
# Epoch [138/200], Loss: 0.0331
# Epoch [139/200], Loss: 0.0293
# Epoch [140/200], Loss: 0.0251
# Epoch [141/200], Loss: 0.0263
# Epoch [142/200], Loss: 0.0287
# Epoch [143/200], Loss: 0.0302
# Epoch [144/200], Loss: 0.0331
# Epoch [145/200], Loss: 0.0426
# Epoch [146/200], Loss: 0.0269
# Epoch [147/200], Loss: 0.0199
# Epoch [148/200], Loss: 0.0225
# Epoch [149/200], Loss: 0.0265
# Epoch [150/200], Loss: 0.0315
# Epoch [151/200], Loss: 0.0406
# Epoch [152/200], Loss: 0.0198
# Epoch [153/200], Loss: 0.0235
# Epoch [154/200], Loss: 0.0200
# Epoch [155/200], Loss: 0.0217
# Epoch [156/200], Loss: 0.0252
# Epoch [157/200], Loss: 0.0217
# Epoch [158/200], Loss: 0.0185
# Epoch [159/200], Loss: 0.0218
# Epoch [160/200], Loss: 0.0325
# Epoch [161/200], Loss: 0.0164
# Epoch [162/200], Loss: 0.0282
# Epoch [163/200], Loss: 0.0193
# Epoch [164/200], Loss: 0.0180
# Epoch [165/200], Loss: 0.0279
# Epoch [166/200], Loss: 0.0230
# Epoch [167/200], Loss: 0.0338
# Epoch [168/200], Loss: 0.0203
# Epoch [169/200], Loss: 0.0197
# Epoch [170/200], Loss: 0.0209
# Epoch [171/200], Loss: 0.0201
# Epoch [172/200], Loss: 0.0163
# Epoch [173/200], Loss: 0.0284
# Epoch [174/200], Loss: 0.0143
# Epoch [175/200], Loss: 0.0147
# Epoch [176/200], Loss: 0.0315
# Epoch [177/200], Loss: 0.0173
# Epoch [178/200], Loss: 0.0118
# Epoch [179/200], Loss: 0.0179
# Epoch [180/200], Loss: 0.0170
# Epoch [181/200], Loss: 0.0294
# Epoch [182/200], Loss: 0.0192
# Epoch [183/200], Loss: 0.0186
# Epoch [184/200], Loss: 0.0170
# Epoch [185/200], Loss: 0.0147
# Epoch [186/200], Loss: 0.0124
# Epoch [187/200], Loss: 0.0176
# Epoch [188/200], Loss: 0.0109
# Epoch [189/200], Loss: 0.0115
# Epoch [190/200], Loss: 0.0100
# Epoch [191/200], Loss: 0.0360
# Epoch [192/200], Loss: 0.0150
# Epoch [193/200], Loss: 0.0096
# Epoch [194/200], Loss: 0.0122
# Epoch [195/200], Loss: 0.0129
# Epoch [196/200], Loss: 0.0193
# Epoch [197/200], Loss: 0.0106
# Epoch [198/200], Loss: 0.0100
# Epoch [199/200], Loss: 0.0135
# Epoch [200/200], Loss: 0.0106
# Overall Accuracy: 0.8242
# Average Accuracy: 0.8527
# Kappa Coefficient: 0.8094
#
# Prediction Distribution:
# Class 0: 880 predictions
# Class 1: 1317 predictions
# Class 2: 454 predictions
# Class 3: 1044 predictions
# Class 4: 1038 predictions
# Class 5: 200 predictions
# Class 6: 791 predictions
# Class 7: 902 predictions
# Class 8: 813 predictions
# Class 9: 1588 predictions
# Class 10: 999 predictions
# Class 11: 932 predictions
# Class 12: 382 predictions
# Class 13: 348 predictions
# Class 14: 509 predictions
# Loaded pre-trained weights for the entire feature extractor.
# Epoch [1/200], Loss: 2.9647
# Epoch [2/200], Loss: 2.8571
# Epoch [3/200], Loss: 2.6283
# Epoch [4/200], Loss: 2.4905
# Epoch [5/200], Loss: 2.3688
# Epoch [6/200], Loss: 2.2803
# Epoch [7/200], Loss: 2.1574
# Epoch [8/200], Loss: 2.1029
# Epoch [9/200], Loss: 1.9967
# Epoch [10/200], Loss: 1.9287
# Epoch [11/200], Loss: 1.9146
# Epoch [12/200], Loss: 1.7813
# Epoch [13/200], Loss: 1.7117
# Epoch [14/200], Loss: 1.6621
# Epoch [15/200], Loss: 1.6253
# Epoch [16/200], Loss: 1.5957
# Epoch [17/200], Loss: 1.5237
# Epoch [18/200], Loss: 1.4703
# Epoch [19/200], Loss: 1.3771
# Epoch [20/200], Loss: 1.3569
# Epoch [21/200], Loss: 1.2837
# Epoch [22/200], Loss: 1.2852
# Epoch [23/200], Loss: 1.1830
# Epoch [24/200], Loss: 1.1591
# Epoch [25/200], Loss: 1.1282
# Epoch [26/200], Loss: 1.0724
# Epoch [27/200], Loss: 1.0243
# Epoch [28/200], Loss: 0.9996
# Epoch [29/200], Loss: 1.0727
# Epoch [30/200], Loss: 0.9301
# Epoch [31/200], Loss: 0.8693
# Epoch [32/200], Loss: 0.8327
# Epoch [33/200], Loss: 0.8691
# Epoch [34/200], Loss: 0.7520
# Epoch [35/200], Loss: 0.7669
# Epoch [36/200], Loss: 0.7004
# Epoch [37/200], Loss: 0.6899
# Epoch [38/200], Loss: 0.6424
# Epoch [39/200], Loss: 0.6829
# Epoch [40/200], Loss: 0.6128
# Epoch [41/200], Loss: 0.5748
# Epoch [42/200], Loss: 0.5677
# Epoch [43/200], Loss: 0.5140
# Epoch [44/200], Loss: 0.6097
# Epoch [45/200], Loss: 0.5493
# Epoch [46/200], Loss: 0.4874
# Epoch [47/200], Loss: 0.4938
# Epoch [48/200], Loss: 0.4573
# Epoch [49/200], Loss: 0.4287
# Epoch [50/200], Loss: 0.3918
# Epoch [51/200], Loss: 0.4138
# Epoch [52/200], Loss: 0.4055
# Epoch [53/200], Loss: 0.3931
# Epoch [54/200], Loss: 0.3619
# Epoch [55/200], Loss: 0.3684
# Epoch [56/200], Loss: 0.3596
# Epoch [57/200], Loss: 0.3217
# Epoch [58/200], Loss: 0.2874
# Epoch [59/200], Loss: 0.2972
# Epoch [60/200], Loss: 0.3019
# Epoch [61/200], Loss: 0.3291
# Epoch [62/200], Loss: 0.3491
# Epoch [63/200], Loss: 0.2676
# Epoch [64/200], Loss: 0.2864
# Epoch [65/200], Loss: 0.2453
# Epoch [66/200], Loss: 0.2503
# Epoch [67/200], Loss: 0.2331
# Epoch [68/200], Loss: 0.2561
# Epoch [69/200], Loss: 0.2401
# Epoch [70/200], Loss: 0.2168
# Epoch [71/200], Loss: 0.1912
# Epoch [72/200], Loss: 0.2370
# Epoch [73/200], Loss: 0.1684
# Epoch [74/200], Loss: 0.1856
# Epoch [75/200], Loss: 0.2417
# Epoch [76/200], Loss: 0.1533
# Epoch [77/200], Loss: 0.1750
# Epoch [78/200], Loss: 0.2959
# Epoch [79/200], Loss: 0.1888
# Epoch [80/200], Loss: 0.1890
# Epoch [81/200], Loss: 0.1726
# Epoch [82/200], Loss: 0.1554
# Epoch [83/200], Loss: 0.1363
# Epoch [84/200], Loss: 0.1312
# Epoch [85/200], Loss: 0.1100
# Epoch [86/200], Loss: 0.1390
# Epoch [87/200], Loss: 0.1275
# Epoch [88/200], Loss: 0.1154
# Epoch [89/200], Loss: 0.1104
# Epoch [90/200], Loss: 0.1163
# Epoch [91/200], Loss: 0.1072
# Epoch [92/200], Loss: 0.0822
# Epoch [93/200], Loss: 0.0963
# Epoch [94/200], Loss: 0.0866
# Epoch [95/200], Loss: 0.0981
# Epoch [96/200], Loss: 0.0958
# Epoch [97/200], Loss: 0.0801
# Epoch [98/200], Loss: 0.0694
# ...
# Epoch [114/200], Loss: 0.0740
# Epoch [115/200], Loss: 0.0712
# Epoch [116/200], Loss: 0.0720
# Epoch [117/200], Loss: 0.0724
# Epoch [118/200], Loss: 0.0532
# Epoch [119/200], Loss: 0.1045
# Epoch [120/200], Loss: 0.0737
# Epoch [121/200], Loss: 0.0529
# Epoch [122/200], Loss: 0.0689
# Epoch [123/200], Loss: 0.0403
# Epoch [124/200], Loss: 0.0402
# Epoch [125/200], Loss: 0.0436
# Epoch [126/200], Loss: 0.0516
# Epoch [127/200], Loss: 0.0561
# Epoch [128/200], Loss: 0.0734
# Epoch [129/200], Loss: 0.0458
# Epoch [130/200], Loss: 0.0327
# Epoch [131/200], Loss: 0.0403
# Epoch [132/200], Loss: 0.0330
# Epoch [133/200], Loss: 0.0408
# Epoch [134/200], Loss: 0.0443
# Epoch [135/200], Loss: 0.0349
# Epoch [136/200], Loss: 0.0468
# Epoch [137/200], Loss: 0.0503
# Epoch [138/200], Loss: 0.0393
# Epoch [139/200], Loss: 0.0285
# Epoch [140/200], Loss: 0.0310
# Epoch [141/200], Loss: 0.0660
# Epoch [142/200], Loss: 0.0249
# Epoch [143/200], Loss: 0.0266
# Epoch [144/200], Loss: 0.0355
# Epoch [145/200], Loss: 0.0333
# Epoch [146/200], Loss: 0.0350
# Epoch [147/200], Loss: 0.0232
# Epoch [148/200], Loss: 0.0407
# Epoch [149/200], Loss: 0.0386
# Epoch [150/200], Loss: 0.0245
# Epoch [151/200], Loss: 0.0237
# Epoch [152/200], Loss: 0.0501
# Epoch [153/200], Loss: 0.0189
# Epoch [154/200], Loss: 0.0485
# Epoch [155/200], Loss: 0.0186
# Epoch [156/200], Loss: 0.0368
# Epoch [157/200], Loss: 0.0357
# Epoch [158/200], Loss: 0.0198
# Epoch [159/200], Loss: 0.0282
# Epoch [160/200], Loss: 0.0387
# Epoch [161/200], Loss: 0.0372
# Epoch [162/200], Loss: 0.0222
# Epoch [163/200], Loss: 0.0579
# Epoch [164/200], Loss: 0.0164
# Epoch [165/200], Loss: 0.0313
# Epoch [166/200], Loss: 0.0366
# Epoch [167/200], Loss: 0.0360
# Epoch [168/200], Loss: 0.0355
# Epoch [169/200], Loss: 0.0266
# Epoch [170/200], Loss: 0.0324
# Epoch [171/200], Loss: 0.0429
# Epoch [172/200], Loss: 0.0155
# Epoch [173/200], Loss: 0.0144
# Epoch [174/200], Loss: 0.0406
# Epoch [175/200], Loss: 0.0197
# Epoch [176/200], Loss: 0.0162
# Epoch [177/200], Loss: 0.0167
# Epoch [178/200], Loss: 0.0213
# Epoch [179/200], Loss: 0.0307
# Epoch [180/200], Loss: 0.0250
# Epoch [181/200], Loss: 0.0247
# Epoch [182/200], Loss: 0.0119
# Epoch [183/200], Loss: 0.0127
# Epoch [184/200], Loss: 0.0140
# Epoch [185/200], Loss: 0.0191
# Epoch [186/200], Loss: 0.0130
# Epoch [187/200], Loss: 0.0182
# Epoch [188/200], Loss: 0.0253
# Epoch [189/200], Loss: 0.0161
# Epoch [190/200], Loss: 0.0184
# Epoch [191/200], Loss: 0.0137
# Epoch [192/200], Loss: 0.0368
# Epoch [193/200], Loss: 0.0234
# Epoch [194/200], Loss: 0.0248
# Epoch [195/200], Loss: 0.0185
# Epoch [196/200], Loss: 0.1304
# Epoch [197/200], Loss: 0.0168
# Epoch [198/200], Loss: 0.0239
# Epoch [199/200], Loss: 0.0161
# Epoch [200/200], Loss: 0.0198
# Overall Accuracy: 0.8198
# Average Accuracy: 0.8447
# Kappa Coefficient: 0.8046
#
# Prediction Distribution:
# Class 0: 899 predictions
# Class 1: 1302 predictions
# Class 2: 432 predictions
# Class 3: 1012 predictions
# Class 4: 1027 predictions
# Class 5: 255 predictions
# Class 6: 870 predictions
# Class 7: 888 predictions
# Class 8: 811 predictions
# Class 9: 1439 predictions
# Class 10: 1207 predictions
# Class 11: 923 predictions
# Class 12: 332 predictions
# Class 13: 303 predictions
# Class 14: 497 predictions
# Loaded pre-trained weights for the entire feature extractor.
# Epoch [1/200], Loss: 2.7382
# Epoch [2/200], Loss: 2.6028
# Epoch [3/200], Loss: 2.4720
# Epoch [4/200], Loss: 2.3847
# Epoch [5/200], Loss: 2.2531
# Epoch [6/200], Loss: 2.1066
# Epoch [7/200], Loss: 2.0653
# Epoch [8/200], Loss: 1.9389
# Epoch [9/200], Loss: 1.9016
# Epoch [10/200], Loss: 1.7681
# Epoch [11/200], Loss: 1.7529
# Epoch [12/200], Loss: 1.6474
# Epoch [13/200], Loss: 1.6306
# Epoch [14/200], Loss: 1.5077
# Epoch [15/200], Loss: 1.4222
# Epoch [16/200], Loss: 1.4333
# Epoch [17/200], Loss: 1.3729
# Epoch [18/200], Loss: 1.3046
# Epoch [19/200], Loss: 1.2210
# Epoch [20/200], Loss: 1.2024
# Epoch [21/200], Loss: 1.0909
# Epoch [22/200], Loss: 1.0909
# Epoch [23/200], Loss: 1.0337
# Epoch [24/200], Loss: 1.0042
# Epoch [25/200], Loss: 1.0255
# Epoch [26/200], Loss: 0.9207
# Epoch [27/200], Loss: 0.8703
# Epoch [28/200], Loss: 0.8443
# Epoch [29/200], Loss: 0.8110
# Epoch [30/200], Loss: 0.7544
# Epoch [31/200], Loss: 0.7545
# Epoch [32/200], Loss: 0.7138
# Epoch [33/200], Loss: 0.6523
# Epoch [34/200], Loss: 0.6644
# Epoch [35/200], Loss: 0.6093
# Epoch [36/200], Loss: 0.6407
# Epoch [37/200], Loss: 0.5620
# Epoch [38/200], Loss: 0.5347
# Epoch [39/200], Loss: 0.5325
# Epoch [40/200], Loss: 0.4855
# Epoch [41/200], Loss: 0.4701
# Epoch [42/200], Loss: 0.5194
# Epoch [43/200], Loss: 0.4313
# Epoch [44/200], Loss: 0.4236
# Epoch [45/200], Loss: 0.4228
# Epoch [46/200], Loss: 0.5052
# Epoch [47/200], Loss: 0.3815
# Epoch [48/200], Loss: 0.3918
# Epoch [49/200], Loss: 0.3845
# Epoch [50/200], Loss: 0.3251
# Epoch [51/200], Loss: 0.3683
# Epoch [52/200], Loss: 0.3284
# Epoch [53/200], Loss: 0.4604
# Epoch [54/200], Loss: 0.3052
# Epoch [55/200], Loss: 0.3113
# Epoch [56/200], Loss: 0.2734
# Epoch [57/200], Loss: 0.2753
# Epoch [58/200], Loss: 0.2637
# Epoch [59/200], Loss: 0.2535
# Epoch [60/200], Loss: 0.2615
# Epoch [61/200], Loss: 0.2625
# Epoch [62/200], Loss: 0.2926
# Epoch [63/200], Loss: 0.2118
# Epoch [64/200], Loss: 0.2211
# Epoch [65/200], Loss: 0.2628
# Epoch [66/200], Loss: 0.2140
# Epoch [67/200], Loss: 0.2062
# Epoch [68/200], Loss: 0.2011
# Epoch [69/200], Loss: 0.2111
# Epoch [70/200], Loss: 0.2161
# Epoch [71/200], Loss: 0.2144
# Epoch [72/200], Loss: 0.1554
# Epoch [73/200], Loss: 0.2532
# Epoch [74/200], Loss: 0.1388
# Epoch [75/200], Loss: 0.2153
# Epoch [76/200], Loss: 0.1452
# Epoch [77/200], Loss: 0.1465
# Epoch [78/200], Loss: 0.1466
# Epoch [79/200], Loss: 0.1785
# Epoch [80/200], Loss: 0.1418
# Epoch [81/200], Loss: 0.1382
# Epoch [82/200], Loss: 0.1576
# Epoch [83/200], Loss: 0.1280
# Epoch [84/200], Loss: 0.1305
# Epoch [85/200], Loss: 0.1157
# Epoch [86/200], Loss: 0.1146
# Epoch [87/200], Loss: 0.1577
# Epoch [88/200], Loss: 0.1284
# Epoch [89/200], Loss: 0.1203
# Epoch [90/200], Loss: 0.1147
# Epoch [91/200], Loss: 0.0992
# Epoch [92/200], Loss: 0.0910
# Epoch [93/200], Loss: 0.0911
# Epoch [94/200], Loss: 0.1255
# Epoch [95/200], Loss: 0.0961
# Epoch [96/200], Loss: 0.1247
# Epoch [97/200], Loss: 0.0918
# Epoch [98/200], Loss: 0.1067
# Epoch [99/200], Loss: 0.0817
# Epoch [100/200], Loss: 0.1359
# Epoch [101/200], Loss: 0.0815
# Epoch [102/200], Loss: 0.0653
# Epoch [103/200], Loss: 0.0744
# Epoch [104/200], Loss: 0.0542
# Epoch [105/200], Loss: 0.0667
# Epoch [106/200], Loss: 0.0834
# Epoch [107/200], Loss: 0.0778
# Epoch [108/200], Loss: 0.0598
# Epoch [109/200], Loss: 0.0626
# Epoch [110/200], Loss: 0.1490
# Epoch [111/200], Loss: 0.0605
# Epoch [112/200], Loss: 0.0677
# Epoch [113/200], Loss: 0.0619
# Epoch [114/200], Loss: 0.0695
# Epoch [115/200], Loss: 0.0726
# Epoch [116/200], Loss: 0.0771
# Epoch [117/200], Loss: 0.0492
# Epoch [118/200], Loss: 0.0502
# Epoch [119/200], Loss: 0.0457
# Epoch [120/200], Loss: 0.0494
# Epoch [121/200], Loss: 0.0373
# Epoch [122/200], Loss: 0.0386
# Epoch [123/200], Loss: 0.0390
# Epoch [124/200], Loss: 0.0357
# Epoch [125/200], Loss: 0.0567
# Epoch [126/200], Loss: 0.0289
# Epoch [127/200], Loss: 0.0379
# Epoch [128/200], Loss: 0.0312
# Epoch [129/200], Loss: 0.0370
# Epoch [130/200], Loss: 0.0408
# Epoch [131/200], Loss: 0.0297
# Epoch [132/200], Loss: 0.0297
# Epoch [133/200], Loss: 0.0290
# Epoch [134/200], Loss: 0.0322
# Epoch [135/200], Loss: 0.0308
# Epoch [136/200], Loss: 0.0578
# Epoch [137/200], Loss: 0.0364
# Epoch [138/200], Loss: 0.0529
# Epoch [139/200], Loss: 0.0338
# Epoch [140/200], Loss: 0.0429
# Epoch [141/200], Loss: 0.0370
# Epoch [142/200], Loss: 0.0523
# Epoch [143/200], Loss: 0.0283
# Epoch [144/200], Loss: 0.0260
# Epoch [145/200], Loss: 0.0346
# Epoch [146/200], Loss: 0.0642
# Epoch [147/200], Loss: 0.0365
# Epoch [148/200], Loss: 0.0247
# Epoch [149/200], Loss: 0.0311
# Epoch [150/200], Loss: 0.0205
# Epoch [151/200], Loss: 0.0273
# Epoch [152/200], Loss: 0.0237
# Epoch [153/200], Loss: 0.0203
# Epoch [154/200], Loss: 0.0235
# Epoch [155/200], Loss: 0.0255
# Epoch [156/200], Loss: 0.0332
# Epoch [157/200], Loss: 0.0172
# Epoch [158/200], Loss: 0.0172
# Epoch [159/200], Loss: 0.0176
# Epoch [160/200], Loss: 0.0274
# Epoch [161/200], Loss: 0.0176
# Epoch [162/200], Loss: 0.0149
# Epoch [163/200], Loss: 0.0214
# Epoch [164/200], Loss: 0.0216
# Epoch [165/200], Loss: 0.0196
# Epoch [166/200], Loss: 0.0217
# Epoch [167/200], Loss: 0.0188
# Epoch [168/200], Loss: 0.0139
# Epoch [169/200], Loss: 0.0163
# Epoch [170/200], Loss: 0.0175
# Epoch [171/200], Loss: 0.0173
# Epoch [172/200], Loss: 0.0199
# Epoch [173/200], Loss: 0.0198
# Epoch [174/200], Loss: 0.0125
# Epoch [175/200], Loss: 0.0137
# Epoch [176/200], Loss: 0.0178
# Epoch [177/200], Loss: 0.0202
# Epoch [178/200], Loss: 0.0179
# Epoch [179/200], Loss: 0.0159
# Epoch [180/200], Loss: 0.0267
# Epoch [181/200], Loss: 0.0142
# Epoch [182/200], Loss: 0.0189
# Epoch [183/200], Loss: 0.0255
# Epoch [184/200], Loss: 0.0168
# Epoch [185/200], Loss: 0.0192
# Epoch [186/200], Loss: 0.0133
# Epoch [187/200], Loss: 0.0148
# Epoch [188/200], Loss: 0.0168
# Epoch [189/200], Loss: 0.0143
# Epoch [190/200], Loss: 0.0533
# Epoch [191/200], Loss: 0.0124
# Epoch [192/200], Loss: 0.0125
# Epoch [193/200], Loss: 0.0159
# Epoch [194/200], Loss: 0.0138
# Epoch [195/200], Loss: 0.0225
# Epoch [196/200], Loss: 0.0162
# Epoch [197/200], Loss: 0.0165
# Epoch [198/200], Loss: 0.0116
# Epoch [199/200], Loss: 0.0123
# Epoch [200/200], Loss: 0.0121
# Overall Accuracy: 0.8277
# Average Accuracy: 0.8544
# Kappa Coefficient: 0.8131
#
# Prediction Distribution:
# Class 0: 890 predictions
# Class 1: 1430 predictions
# Class 2: 461 predictions
# Class 3: 1043 predictions
# Class 4: 1051 predictions
# Class 5: 204 predictions
# Class 6: 814 predictions
# Class 7: 1047 predictions
# Class 8: 781 predictions
# Class 9: 1350 predictions
# Class 10: 987 predictions
# Class 11: 1003 predictions
# Class 12: 323 predictions
# Class 13: 314 predictions
# Class 14: 499 predictions
# Loaded pre-trained weights for the entire feature extractor.
# Epoch [1/200], Loss: 2.7830
# Epoch [2/200], Loss: 2.5424
# Epoch [3/200], Loss: 2.3689
# Epoch [4/200], Loss: 2.2155
# Epoch [5/200], Loss: 2.0887
# Epoch [6/200], Loss: 1.9946
# Epoch [7/200], Loss: 1.8481
# Epoch [8/200], Loss: 1.8190
# Epoch [9/200], Loss: 1.7209
# Epoch [10/200], Loss: 1.6206
# Epoch [11/200], Loss: 1.5238
# Epoch [12/200], Loss: 1.4097
# Epoch [13/200], Loss: 1.3394
# Epoch [14/200], Loss: 1.2743
# Epoch [15/200], Loss: 1.1946
# Epoch [16/200], Loss: 1.1822
# Epoch [17/200], Loss: 1.1019
# Epoch [18/200], Loss: 1.0531
# Epoch [19/200], Loss: 0.9599
# Epoch [20/200], Loss: 0.9181
# Epoch [21/200], Loss: 0.9182
# Epoch [22/200], Loss: 0.8487
# Epoch [23/200], Loss: 0.8379
# Epoch [24/200], Loss: 0.8017
# Epoch [25/200], Loss: 0.7284
# Epoch [26/200], Loss: 0.7211
# Epoch [27/200], Loss: 0.6758
# Epoch [28/200], Loss: 0.6266
# Epoch [29/200], Loss: 0.5819
# Epoch [30/200], Loss: 0.5575
# Epoch [31/200], Loss: 0.5469
# Epoch [32/200], Loss: 0.5051
# Epoch [33/200], Loss: 0.4639
# Epoch [34/200], Loss: 0.4822
# Epoch [35/200], Loss: 0.4509
# Epoch [36/200], Loss: 0.4626
# Epoch [37/200], Loss: 0.4404
# Epoch [38/200], Loss: 0.4264
# Epoch [39/200], Loss: 0.3636
# Epoch [40/200], Loss: 0.4027
# Epoch [41/200], Loss: 0.4241
# Epoch [42/200], Loss: 0.3646
# Epoch [43/200], Loss: 0.3468
# Epoch [44/200], Loss: 0.3165
# Epoch [45/200], Loss: 0.3495
# Epoch [46/200], Loss: 0.2980
# Epoch [47/200], Loss: 0.2684
# Epoch [48/200], Loss: 0.3264
# Epoch [49/200], Loss: 0.2925
# Epoch [50/200], Loss: 0.2766
# Epoch [51/200], Loss: 0.2260
# Epoch [52/200], Loss: 0.2355
# Epoch [53/200], Loss: 0.2267
# Epoch [54/200], Loss: 0.2023
# Epoch [55/200], Loss: 0.2185
# Epoch [56/200], Loss: 0.2030
# Epoch [57/200], Loss: 0.1834
# Epoch [58/200], Loss: 0.1878
# Epoch [59/200], Loss: 0.1844
# Epoch [60/200], Loss: 0.1622
# Epoch [61/200], Loss: 0.1709
# Epoch [62/200], Loss: 0.1559
# Epoch [63/200], Loss: 0.1627
# Epoch [64/200], Loss: 0.1745
# Epoch [65/200], Loss: 0.1637
# Epoch [66/200], Loss: 0.1584
# Epoch [67/200], Loss: 0.1359
# Epoch [68/200], Loss: 0.1365
# Epoch [69/200], Loss: 0.1202
# Epoch [70/200], Loss: 0.1239
# Epoch [71/200], Loss: 0.1047
# Epoch [72/200], Loss: 0.1245
# Epoch [73/200], Loss: 0.0979
# Epoch [74/200], Loss: 0.1204
# Epoch [75/200], Loss: 0.0980
# Epoch [76/200], Loss: 0.0893
# Epoch [77/200], Loss: 0.0769
# Epoch [78/200], Loss: 0.0883
# Epoch [79/200], Loss: 0.0699
# Epoch [80/200], Loss: 0.0902
# Epoch [81/200], Loss: 0.0641
# Epoch [82/200], Loss: 0.0818
# Epoch [83/200], Loss: 0.0714
# Epoch [84/200], Loss: 0.0717
# Epoch [85/200], Loss: 0.0607
# Epoch [86/200], Loss: 0.0586
# Epoch [87/200], Loss: 0.0576
# Epoch [88/200], Loss: 0.1110
# Epoch [89/200], Loss: 0.0591
# Epoch [90/200], Loss: 0.0679
# Epoch [91/200], Loss: 0.0692
# Epoch [92/200], Loss: 0.0765
# Epoch [93/200], Loss: 0.0732
# Epoch [94/200], Loss: 0.0762
# Epoch [95/200], Loss: 0.0511
# Epoch [96/200], Loss: 0.0501
# Epoch [97/200], Loss: 0.0431
# Epoch [98/200], Loss: 0.0392
# Epoch [99/200], Loss: 0.0391
# Epoch [100/200], Loss: 0.0944
# Epoch [101/200], Loss: 0.0361
# Epoch [102/200], Loss: 0.0557
# Epoch [103/200], Loss: 0.0499
# Epoch [104/200], Loss: 0.0500
# Epoch [105/200], Loss: 0.0460
# Epoch [106/200], Loss: 0.0470
# Epoch [107/200], Loss: 0.0335
# Epoch [108/200], Loss: 0.0525
# Epoch [109/200], Loss: 0.0391
# Epoch [110/200], Loss: 0.0374
# Epoch [111/200], Loss: 0.0322
# Epoch [112/200], Loss: 0.0426
# Epoch [113/200], Loss: 0.0383
# Epoch [114/200], Loss: 0.0316
# Epoch [115/200], Loss: 0.0300
# Epoch [116/200], Loss: 0.0332
# Epoch [117/200], Loss: 0.0331
# Epoch [118/200], Loss: 0.0242
# Epoch [119/200], Loss: 0.0213
# Epoch [120/200], Loss: 0.0246
# Epoch [121/200], Loss: 0.0206
# Epoch [122/200], Loss: 0.0269
# Epoch [123/200], Loss: 0.0482
# Epoch [124/200], Loss: 0.0243
# Epoch [125/200], Loss: 0.0441
# Epoch [126/200], Loss: 0.0251
# Epoch [127/200], Loss: 0.0277
# Epoch [128/200], Loss: 0.0372
# Epoch [129/200], Loss: 0.0356
# Epoch [130/200], Loss: 0.0235
# Epoch [131/200], Loss: 0.0170
# Epoch [132/200], Loss: 0.0225
# Epoch [133/200], Loss: 0.0339
# Epoch [134/200], Loss: 0.0253
# Epoch [135/200], Loss: 0.0395
# Epoch [136/200], Loss: 0.0350
# Epoch [137/200], Loss: 0.0181
# Epoch [138/200], Loss: 0.0216
# Epoch [139/200], Loss: 0.0189
# Epoch [140/200], Loss: 0.0184
# Epoch [141/200], Loss: 0.0196
# Epoch [142/200], Loss: 0.0209
# Epoch [143/200], Loss: 0.0144
# Epoch [144/200], Loss: 0.0182
# Epoch [145/200], Loss: 0.0133
# Epoch [146/200], Loss: 0.0184
# Epoch [147/200], Loss: 0.0172
# Epoch [148/200], Loss: 0.0143
# Epoch [149/200], Loss: 0.0154
# Epoch [150/200], Loss: 0.0175
# Epoch [151/200], Loss: 0.0238
# Epoch [152/200], Loss: 0.0160
# Epoch [153/200], Loss: 0.0112
# Epoch [154/200], Loss: 0.0159
# Epoch [155/200], Loss: 0.0118
# Epoch [156/200], Loss: 0.0124
# Epoch [157/200], Loss: 0.0114
# Epoch [158/200], Loss: 0.0279
# Epoch [159/200], Loss: 0.0157
# Epoch [160/200], Loss: 0.0127
# Epoch [161/200], Loss: 0.0121
# Epoch [162/200], Loss: 0.0200
# Epoch [163/200], Loss: 0.0157
# Epoch [164/200], Loss: 0.0101
# Epoch [165/200], Loss: 0.0179
# Epoch [166/200], Loss: 0.0135
# Epoch [167/200], Loss: 0.0084
# Epoch [168/200], Loss: 0.0202
# Epoch [169/200], Loss: 0.0107
# Epoch [170/200], Loss: 0.0087
# Epoch [171/200], Loss: 0.0118
# Epoch [172/200], Loss: 0.0104
# Epoch [173/200], Loss: 0.0186
# Epoch [174/200], Loss: 0.0134
# Epoch [175/200], Loss: 0.0151
# Epoch [176/200], Loss: 0.0120
# Epoch [177/200], Loss: 0.0244
# Epoch [178/200], Loss: 0.0149
# Epoch [179/200], Loss: 0.0104
# Epoch [180/200], Loss: 0.0118
# Epoch [181/200], Loss: 0.0102
# Epoch [182/200], Loss: 0.0168
# Epoch [183/200], Loss: 0.0116
# Epoch [184/200], Loss: 0.0159
# Epoch [185/200], Loss: 0.0112
# Epoch [186/200], Loss: 0.0072
# Epoch [187/200], Loss: 0.0095
# Epoch [188/200], Loss: 0.0083
# Epoch [189/200], Loss: 0.0107
# Epoch [190/200], Loss: 0.0068
# Epoch [191/200], Loss: 0.0081
# Epoch [192/200], Loss: 0.0080
# Epoch [193/200], Loss: 0.0112
# Epoch [194/200], Loss: 0.0409
# Epoch [195/200], Loss: 0.0090
# Epoch [196/200], Loss: 0.0219
# Epoch [197/200], Loss: 0.0174
# Epoch [198/200], Loss: 0.0277
# Epoch [199/200], Loss: 0.0114
# Epoch [200/200], Loss: 0.0100
# Overall Accuracy: 0.8169
# Average Accuracy: 0.8451
# Kappa Coefficient: 0.8014
#
# Prediction Distribution:
# Class 0: 800 predictions
# Class 1: 1326 predictions
# Class 2: 450 predictions
# Class 3: 1139 predictions
# Class 4: 1039 predictions
# Class 5: 168 predictions
# Class 6: 901 predictions
# Class 7: 795 predictions
# Class 8: 853 predictions
# Class 9: 1716 predictions
# Class 10: 814 predictions
# Class 11: 1035 predictions
# Class 12: 348 predictions
# Class 13: 309 predictions
# Class 14: 504 predictions

# %%
import matplotlib.pyplot as plt

# 设置图像大小
plt.figure(figsize=(12, 6))

# Overall Accuracy 柱状图
plt.subplot(1, 2, 1)
bars1 = plt.bar(range(len(checkpoint_path)), overall_accuracies, tick_label=[p.split('/')[-1] for p in checkpoint_path])
plt.xticks(rotation=45, ha='right')
plt.ylabel("Overall Accuracy")
plt.title("Overall Accuracy Comparison")

# 在柱子上添加数值标签
for bar in bars1:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, f"{yval:.2f}", ha='center', va='bottom')

# Average Accuracy 柱状图
plt.subplot(1, 2, 2)
bars2 = plt.bar(range(len(checkpoint_path)), average_accuracies, tick_label=[p.split('/')[-1] for p in checkpoint_path])
plt.xticks(rotation=45, ha='right')
plt.ylabel("Average Accuracy")
plt.title("Average Accuracy Comparison")

# 在柱子上添加数值标签
for bar in bars2:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, f"{yval:.2f}", ha='center', va='bottom')

# 调整布局
plt.tight_layout()
plt.show()
